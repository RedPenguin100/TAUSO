# %%
from notebooks.preprocessing import *
from notebooks.features.feature_extraction import save_feature

# %%
from notebooks.consts import PROCESSED_CSV

aso_data = preprocess_aso_data(csv_path=PROCESSED_CSV)
# Out:
# Preprocessing complete. Final valid rows: 18153

# %%
from tauso.genome.read_human_genome import get_locus_to_data_dict

# 1. Identify unique genes in our clean dataset
genes_u = get_unique_genes(aso_data)

# 2. Load Gene Locus Objects (Contains raw genomic sequence/introns)
gene_to_data = get_locus_to_data_dict(include_introns=True, gene_subset=genes_u)
# Out:
# Elapsed DB:  0.0003008842468261719
# Elapsed Fasta:  0.0003008842468261719
# Length:  3267117988

# %%
from tauso.new_model.populate.populate_sense_accessibility import calculate_sense_accessibility_batch

configurations = [
    {"flank": 120, "access": 20, "seeds": [13]},
    {"flank": 120, "access": 13, "seeds": [4, 6, 8]},
    {"flank": 120, "access": 20, "seeds": [4, 6, 8]},
    {"flank": 120, "access": 13, "seeds": [13, 26, 39]}
]

df_work = aso_data.copy()

feature_names = []
for config in configurations:
    c_flank = config["flank"]
    c_access = config["access"]
    c_seeds = config["seeds"]

    print(f"Running: Flank={c_flank}, Access={c_access}, Seeds={c_seeds})...")

    df_work, feature_name = calculate_sense_accessibility_batch(
        df_work,
        gene_to_data,
        batch_size=1000,
        flank_size=c_flank,
        access_size=c_access,
        seed_sizes=c_seeds,
        n_jobs=32
    )
    try:
        save_feature(df=df_work, feature_name=feature_name, version='v2')
        print(f"Saved: {feature_name}")
    except Exception as e:
        pass
# Out:
# Running: Flank=120, Access=20, Seeds=[13])...
