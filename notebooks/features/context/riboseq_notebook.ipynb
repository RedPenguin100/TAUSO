# %%
from notebooks.consts import PROCESSED_CSV
from notebooks.preprocessing import preprocess_aso_data

aso_df = preprocess_aso_data(PROCESSED_CSV, include_smiles=False)
# Out:
# Adding cell line depmap name proxy
# Adding a depmap column
# Preprocessing complete. Final valid rows: 18153

# %%
from tauso.data.data import get_paths
from tauso.genome.TranscriptMapper import GeneCoordinateMapper

paths = get_paths('GRCh38')
mapper = GeneCoordinateMapper(paths['db'])

# %%
from tauso.features.context.ribo_seq import add_genomic_coordinates

new = add_genomic_coordinates(aso_df, mapper)

# %%
from tauso.populate.populate_context import populate_ribo_seq

new_new_df, feature_names = populate_ribo_seq('human', new, flanks=(30, 50, 100, 200, 400, 600, 800))

# %%
from notebooks.features.feature_extraction import save_feature

for feature in feature_names:
    save_feature(new_new_df, feature, version='v2')
# Out:
# Saved feature: ribo_gene_mean
# Saved feature: ribo_f30_mean
# Saved feature: ribo_upstream_30_mean
# Saved feature: ribo_downstream_30_mean
# Saved feature: ribo_f50_mean
# Saved feature: ribo_upstream_50_mean
# Saved feature: ribo_downstream_50_mean
# Saved feature: ribo_f100_mean
# Saved feature: ribo_upstream_100_mean
# Saved feature: ribo_downstream_100_mean
# Saved feature: ribo_f200_mean
# Saved feature: ribo_upstream_200_mean
# Saved feature: ribo_downstream_200_mean
# Saved feature: ribo_f400_mean
# Saved feature: ribo_upstream_400_mean
# Saved feature: ribo_downstream_400_mean
# Saved feature: ribo_f600_mean
# Saved feature: ribo_upstream_600_mean
# Saved feature: ribo_downstream_600_mean
# Saved feature: ribo_f800_mean
# Saved feature: ribo_upstream_800_mean
# Saved feature: ribo_downstream_800_mean
