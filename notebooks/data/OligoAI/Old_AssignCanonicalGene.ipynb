# %%
import pandas as pd
from tauso.data.consts import CANONICAL_GENE
from notebooks.data.OligoAI.assign_canonical_gene import process_and_assign_genes

# %%
from notebooks.consts import ORIGINAL_OLIGO_CSV_FLANK_100

original_df = pd.read_csv(ORIGINAL_OLIGO_CSV_FLANK_100)

# %%
original_df[original_df['target_gene'] == 'SNHG14']
# Out:
# Empty DataFrame
# Columns: [aso_sequence_5_to_3, inhibition_percent, chemistry, custom_id, target_mrna, target_gene, cell_line, cell_line_species, dosage, cells_per_well, transfection_method, steric_blocking, rna_context, sugar_mods, backbone_mods]
# Index: []

# %%
# Cell 2: Run the pipeline
df, ambiguous_genes = process_and_assign_genes()
# Out:
# Resolving 293 unique target genes
# [50/293] genes processed
# [100/293] genes processed
# [150/293] genes processed
# [200/293] genes processed
# [250/293] genes processed
# [293/293] genes processed
# /home/michael/career/tauso_article/tauso_source2/notebooks/data/OligoAI/assign_canonical_gene.py:419: UserWarning: 3 target genes mapped to multiple canonical genes
#   warnings.warn(f"{len(ambiguous_genes)} target genes mapped to multiple canonical genes")

# %%
df[(df['target_gene'] != df[CANONICAL_GENE])][['target_gene', CANONICAL_GENE]]
# Out:
#        target_gene                                Canonical Gene Name
# 15286         DUX4  DUX4L8;DUX4;DUX4L2;DUX4L3;DUX4L6;DUX4L1;DUX4L5...
# 15287         DUX4  DUX4L8;DUX4;DUX4L2;DUX4L3;DUX4L6;DUX4L1;DUX4L5...
# 15288         DUX4  DUX4L8;DUX4;DUX4L2;DUX4L3;DUX4L6;DUX4L1;DUX4L5...
# 15289         DUX4  DUX4L8;DUX4;DUX4L2;DUX4L3;DUX4L6;DUX4L1;DUX4L5...
# 15290         DUX4  DUX4L8;DUX4;DUX4L2;DUX4L3;DUX4L6;DUX4L1;DUX4L5...
# ...            ...                                                ...
# 150846        IGF2                                            IGF2-AS
# 150847        IGF2                                            IGF2-AS
# 150848        IGF2                                            IGF2-AS
# 150849        IGF2                                            IGF2-AS
# 150850        IGF2                                            IGF2-AS
#
# [1160 rows x 2 columns]

# %%
df[df['target_gene'] == 'STAT5B']
# Out:
#          aso_sequence_5_to_3  inhibition_percent  \
# 149343  GCTTCTGCTGGAGGGCCGTC                76.0
# 149344  TGATGGTCTGCTGCTTCCGC                66.0
# 149345  GCATCTCCTCCACTGGGCCG                53.0
# 149346  GCACGGCAAATGGCACCCTG                84.0
# 149347  GGGCCTGGTCCATGTACGTG                69.0
# ...                      ...                 ...
# 149408  ACTGTAGTCCTCCAGGTGGC                73.0
# 149409  GACAGGCCACTGTAGTCCTC                74.0
# 149410  TATCCATCAACAGCTTTAGC                68.0
# 149411  ACCACTTGCTTGATCTGTGG                79.0
# 149412  TCTGTGGGTACATGTTATAG                78.0
#
#                                                 chemistry  \
# 149343  length=20 modifications=[Modification(modifica...
# 149344  length=20 modifications=[Modification(modifica...
# 149345  length=20 modifications=[Modification(modifica...
# 149346  length=20 modifications=[Modification(modifica...
# 149347  length=20 modifications=[Modification(modifica...
# ...

# %%
# Cell 3: Analyze Ambiguous Genes
amb_df = pd.DataFrame(
    [
        {"target_gene": tg, "matched_canonical_genes": ";".join(genes)}
        for tg, genes in ambiguous_genes.items()
    ]
)
display(amb_df)

# %%
# Cell 4: Check what happened with the errors
not_found = df[df[CANONICAL_GENE].isna()]
print(f"{len(not_found)} RNA contexts were not found in the genome")

# %%
# Cell 5: Check multi-gene masks
multi_gene_mask = (
    df[CANONICAL_GENE].notna()
    & df[CANONICAL_GENE].str.contains(";", regex=False)
)
count_multi = multi_gene_mask.sum()
print(f"{count_multi} rows have more than one canonical gene")

# %%
# Cell 6: View multi-gene inconsistencies
display(df[df[CANONICAL_GENE] != df['target_gene']][[CANONICAL_GENE, 'target_gene']].drop_duplicates())
