# %%
# %load_ext autoreload
# %autoreload 2

# %%
from notebooks.consts import OLIGO_CSV_INDEXED
import pandas as pd

data = pd.read_csv(OLIGO_CSV_INDEXED)

# %%
from tauso.data.consts import SEQUENCE, CELL_LINE, CANONICAL_GENE, CELL_LINE_ORGANISM, INHIBITION, VOLUME

rename_scheme = {'aso_sequence_5_to_3': SEQUENCE, 'Canonical Gene Name': CANONICAL_GENE, 'cell_line': CELL_LINE,
                 'cell_line_species': CELL_LINE_ORGANISM, 'inhibition_percent': INHIBITION, 'dosage': VOLUME}
data = data.rename(columns=rename_scheme)

# %%
data = data[data['steric_blocking'] == False]
data = data[data[INHIBITION].notna()]

# %%
from tauso.data.consts import CELL_LINE_TO_DEPMAP_PROXY_DICT, CELL_LINE_DEPMAP, CELL_LINE_DEPMAP_PROXY, \
    CELL_LINE_TO_DEPMAP

data[CELL_LINE_DEPMAP_PROXY] = data[CELL_LINE].map(CELL_LINE_TO_DEPMAP_PROXY_DICT)
data[CELL_LINE_DEPMAP] = data[CELL_LINE_DEPMAP_PROXY].map(CELL_LINE_TO_DEPMAP)

# %%
from notebooks.data.OligoAI.parse_chemistry import assign_chemistry

data = assign_chemistry(data)

# %%
from tauso.populate.calculators.calculator import Calculator

calculator = Calculator(data=data, data_version='oligo', overwrite=True, cpus=24)
calculator.calculate_structure()
# Out:
# Computing structure features...
# Warning: Genes ['IFNAR1', 'FOXP3', 'CYTH1', 'FOLR1', 'TDP1', 'SND1', 'SERPINA1', 'CENPB', 'S1PR5', 'HMOX1', 'PIM1', 'FUS', 'RECQL4', 'RAF1', 'CSNK2A1', 'CDK9', 'ATXN1', 'SNCA', 'TTR', 'STK17B', 'ADGRA2', 'NR3C1', 'LIPG', 'STAT3', 'STAT6', 'ARNT', 'PRKD2', 'GPR39', 'BIRC5', 'TNFSF14', 'SLC37A4', 'SERBP1', 'CD40', 'PLSCR1', 'APP', 'SLC26A2', 'MAD1L1', 'TFAP2C', 'CRP', 'MECP2', 'SPDEF', 'CDK17', 'F11', 'KSR1', 'S1PR2', 'DUSP9', 'HMGCR', 'F3', 'NEK6', 'ANGPT2', 'PPM1B', 'BUB1B', 'PAK1', 'SMN1', 'PSD3', 'DRAP1', 'PLP1', 'MRPL13', 'PTPN13', 'KCNT1', 'ABCC2', 'C9orf72', 'SCD', 'IL22RA1', 'JAG1', 'APOL1', 'GYS1', 'FDFT1', 'SREBF1', 'PLN', 'VEGFC', 'DNM2', 'PLD2', 'PPP3CB', 'RPS6KB1', 'UBE2K', 'MAGED1', 'MET', 'AP5Z1', 'ESR1', 'ATXN3', 'LCK', 'HDAC1', 'CD1D', 'JAM3', 'ATXN2', 'MMP11', 'MAP3K11', 'BAG5', 'ACTL6A', 'KRAS', 'ABCC5', 'COMP', 'SEPHS2', 'ZNHIT3', 'PLIN2', 'DUSP4', 'SNHG14', 'RANGAP1', 'C3', 'IFNGR2', 'IRF5', 'BACE1', 'MAPK12', 'RECQL', 'PTPRF', 'ADAM9', 'GFAP', 'ADAM12', 'MAD2L1', 'KLKB1', 'TLN1', 'EFNB2', 'DGAT1', 'CD86', 'CD81', 'TEK', 'EZH2', 'CD36', 'SCN2A', 'ATF3', 'BAX', 'AGT', 'HCK', 'ACAT2', 'SMAD7', 'KCNQ2', 'DAPK1', 'ACTA1', 'PCK2', 'HIF1A', 'APOB', 'PRKCI', 'MAPK13', 'F12', 'RBL2', 'BRCA1', 'BIRC7', 'FGFR4', 'SCNN1A', 'CIITA', 'CTSZ', 'CD24', 'CDK4', 'TGFBR2', 'PTTG1', 'XPO5', 'SUMO2', 'LIMK1', 'PLIN1', 'MRPS16', 'DUSP6', 'CDK1', 'PPP2R1A', 'BACE2', 'CHEK1', 'RCOR1', 'STAT5B', 'NID1', 'GPRC5B', 'HTT', 'STK16', 'SELENOW', 'APOC3', 'AR', 'NOTCH1', 'PTPRA', 'CETP', 'UBE2G1', 'ROCK1', 'AIMP1', 'GCGR', 'N4BP2L2', 'DGAT2', 'MALT1', 'PTPN12', 'STAT5A', 'PUM1', 'TFDP1', 'LGR5', 'ACACA', 'IGF2', 'AGO1', 'GPR3', 'ADAM15', 'IL18', 'HDAC2', 'NANOS1', 'TRA2B', 'CFB', 'MYD88', 'FLT1', 'PDE1B', 'EIF4EBP2', 'STK17A', 'ITGB5', 'BUB3', 'TFAP2A', 'SLC5A2', 'PNPLA3', 'CDC14A', 'HDAC4', 'EIF2AK2', 'PTBP1', 'FGFR2', 'ANGPTL3', 'CD40LG', 'VDR', 'API5', 'FGFR3', 'HIP1', 'RNASEL', 'PFN1', 'APOE', 'STAT1', 'PTPN1', 'PIP4K2B', 'JAG2', 'HDGF', 'PPARD', 'NKRF', 'VEGFB', 'PAK2', 'PCSK9', 'MALAT1', 'EIF4E', 'CXCL8', 'EPAS1', 'PRKAR2B', 'TGFB2', 'STAT2', 'HSP90AA1', 'CSK', 'NOTCH3', 'KIF11', 'CCN2', 'TYR', 'RASD2', 'DDB1', 'NOTCH4', 'CALR', 'IKBKG', 'SCARB1', 'IRAK1', 'IL4R', 'S1PR1', 'SLC2A4', 'P2RX4', 'TMPRSS6', 'NCOR2', 'MARK3', 'LY86', 'PRNP', 'GHR', 'PMP22', 'PTPRK', 'HSD11B1', 'RETN', 'AMACR', 'NR1H4', 'IRAK4', 'GGPS1', 'PTPRU', 'LMNA', 'HSD17B13', 'MAPT', 'PLSCR4', 'NOD1', 'NFKB1', 'INPP5D', 'DYRK4', 'PTPA', 'YAP1', 'PTP4A3', 'DPYSL2', 'PIP5K1A', 'PDE4B', 'LRRK2', 'SOD1', 'FNTB', 'SIDT1', 'F7', 'IRF4', 'MSH3', 'DMPK', 'FXYD3', 'ICMT', 'ACACB', 'TONSL', 'CREB1', 'CDK6', 'CLK1', 'PDE8A', 'NLRP3', 'ODC1', 'PROX1', 'PPARA', 'BAG1', 'FOXO1', 'NOTCH2', 'DUX4', 'KLK6', 'MMP1', 'PLSCR3', 'RNASEH1'] differ from cached genes None, regenerating cache.
# Loading genome data dictionary into memory (happens once)...
# [Task] finished in 0.0092s
# Elapsed DB:  0.009158611297607422
# Elapsed Fasta:  0.009158611297607422
# Length:  3267117988
# File exists for 'sense_start' but values are identical (within tolerance). No action taken.
# File exists for 'sense_start_from_end' but values are identical (within tolerance). No action taken.
# File exists for 'sense_length' but values are identical (within tolerance). No action taken.
# File exists for 'sense_exon' but values are identical (within tolerance). No action taken.
# File exists for 'sense_intron' but values are identical (within tolerance). No action taken.
# File exists for 'sense_utr' but values are identical (within tolerance). No action taken.
# File exists for 'sense_type' but values are identical (within tolerance). No action taken.

# %%
calculator.overwrite = False

# %%
calculator.calculate_sense_accessibility()
# Out:
# Skipping 'access_120flank_20access_13seed_sizes': CSV already exists.
# Computing sense accessibility features...
# Running: Flank=120, Access=13, Seeds=[4, 6, 8]...
# Saved feature: access_120flank_13access_4-6-8seed_sizes
# Saved: access_120flank_13access_4-6-8seed_sizes
# Running: Flank=120, Access=20, Seeds=[4, 6, 8]...
# Saved feature: access_120flank_20access_4-6-8seed_sizes
# Saved: access_120flank_20access_4-6-8seed_sizes
# Running: Flank=120, Access=13, Seeds=[13, 26, 39]...
# Saved feature: access_120flank_13access_13-26-39seed_sizes
# Saved: access_120flank_13access_13-26-39seed_sizes

# %%
calculator.calculate_sequence_one_hot()
# Out:
# Computing sequence one-hot features...
# Saved feature: OHE_pos0_A
# Saved feature: OHE_pos0_C
# Saved feature: OHE_pos0_G
# Saved feature: OHE_pos0_T
# Saved feature: OHE_pos1_A
# Saved feature: OHE_pos1_C
# Saved feature: OHE_pos1_G
# Saved feature: OHE_pos1_T
# Saved feature: OHE_pos2_A
# Saved feature: OHE_pos2_C
# Saved feature: OHE_pos2_G
# Saved feature: OHE_pos2_T
# Saved feature: OHE_pos3_A
# Saved feature: OHE_pos3_C
# Saved feature: OHE_pos3_G
# Saved feature: OHE_pos3_T
# Saved feature: OHE_pos4_A
# Saved feature: OHE_pos4_C
# Saved feature: OHE_pos4_G
# Saved feature: OHE_pos4_T
# Saved feature: OHE_pos5_A
# Saved feature: OHE_pos5_C
# Saved feature: OHE_pos5_G
# Saved feature: OHE_pos5_T
# Saved feature: OHE_pos6_A
# Saved feature: OHE_pos6_C
# Saved feature: OHE_pos6_G
# Saved feature: OHE_pos6_T
# Saved feature: OHE_pos7_A
# Saved feature: OHE_pos7_C
# Saved feature: OHE_pos7_G
# Saved feature: OHE_pos7_T
# Saved feature: OHE_pos8_A
# Saved feature: OHE_pos8_C
# Saved feature: OHE_pos8_G
# Saved feature: OHE_pos8_T
# Saved feature: OHE_pos9_A
# Saved feature: OHE_pos9_C
# Saved feature: OHE_pos9_G
# Saved feature: OHE_pos9_T
# Saved feature: OHE_pos10_A
# Saved feature: OHE_pos10_C
# Saved feature: OHE_pos10_G
# Saved feature: OHE_pos10_T
# Saved feature: OHE_pos11_A
# Saved feature: OHE_pos11_C
# Saved feature: OHE_pos11_G
# Saved feature: OHE_pos11_T
# Saved feature: OHE_pos12_A
# Saved feature: OHE_pos12_C
# Saved feature: OHE_pos12_G
# Saved feature: OHE_pos12_T
# Saved feature: OHE_pos13_A
# Saved feature: OHE_pos13_C
# Saved feature: OHE_pos13_G
# Saved feature: OHE_pos13_T
# Saved feature: OHE_pos14_A
# Saved feature: OHE_pos14_C
# Saved feature: OHE_pos14_G
# Saved feature: OHE_pos14_T
# Saved feature: OHE_pos15_A
# Saved feature: OHE_pos15_C
# Saved feature: OHE_pos15_G
# Saved feature: OHE_pos15_T
# Saved feature: OHE_pos16_A
# Saved feature: OHE_pos16_C
# Saved feature: OHE_pos16_G
# Saved feature: OHE_pos16_T
# Saved feature: OHE_pos17_A
# Saved feature: OHE_pos17_C
# Saved feature: OHE_pos17_G
# Saved feature: OHE_pos17_T
# Saved feature: OHE_pos18_A
# Saved feature: OHE_pos18_C
# Saved feature: OHE_pos18_G
# Saved feature: OHE_pos18_T
# Saved feature: OHE_pos19_A
# Saved feature: OHE_pos19_C
# Saved feature: OHE_pos19_G
# Saved feature: OHE_pos19_T
# Saved feature: OHE_pos20_A
# Saved feature: OHE_pos20_C
# Saved feature: OHE_pos20_G
# Saved feature: OHE_pos20_T
# Saved feature: OHE_pos21_A
# Saved feature: OHE_pos21_C
# Saved feature: OHE_pos21_G
# Saved feature: OHE_pos21_T
# Saved feature: OHE_pos22_A
# Saved feature: OHE_pos22_C
# Saved feature: OHE_pos22_G
# Saved feature: OHE_pos22_T
# Saved feature: OHE_pos23_A
# Saved feature: OHE_pos23_C
# Saved feature: OHE_pos23_G
# Saved feature: OHE_pos23_T
# Saved feature: OHE_pos24_A
# Saved feature: OHE_pos24_C
# Saved feature: OHE_pos24_G
# Saved feature: OHE_pos24_T
# Saved feature: OHE_pos25_A
# Saved feature: OHE_pos25_C
# Saved feature: OHE_pos25_G
# Saved feature: OHE_pos25_T
# Saved feature: OHE_pos26_A
# Saved feature: OHE_pos26_C
# Saved feature: OHE_pos26_G
# Saved feature: OHE_pos26_T
# Saved feature: OHE_pos27_A
# Saved feature: OHE_pos27_C
# Saved feature: OHE_pos27_G
# Saved feature: OHE_pos27_T

# %%
calculator.calculate_sequence_chemistry()
# Out:
# Computing 2 sequence chemistry features...
# [SeqChem_gap_gc_content] finished in 0.5925s
# [SeqChem_wing_gap_gc_delta] finished in 0.5911s
# Saved feature: SeqChem_gap_gc_content
# Saved feature: SeqChem_wing_gap_gc_delta

# %%
calculator.calculate_modification()
# Out:
# Computing 20 modification features...
# INFO: Pandarallel will run on 24 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.
# Calculating: Modification_fraction
# Calculating: Modification_type_count
# Calculating: Modification_5prime_run
# Calculating: Modification_3prime_run
# Calculating: Modification_min_distance_to_5prime
# Calculating: Modification_min_distance_to_3prime
# Calculating: Modification_pos_std
# Calculating: Modification_block_count
# Calculating: Modification_max_block_length
# Calculating: Modification_char_entropy
# Calculating: Modification_dominant_mod_fraction
# Calculating: Modification_evenness
# Calculating: Modification_symmetry_score
# Calculating: Modification_skew_index
# Calculating: Modification_mean_gap
# Calculating: Modification_local_density_max
# Calculating: Modification_in_core
# Calculating: Modification_longest_repeat_run
# Calculating: Modification_adjacent_pair_count
# Calculating: Modification_strong_repeat_group_count
# Saved feature: Modification_fraction
# Saved feature: Modification_type_count
# Saved feature: Modification_5prime_run
# Saved feature: Modification_3prime_run
# Saved feature: Modification_min_distance_to_5prime
# Saved feature: Modification_min_distance_to_3prime
# Saved feature: Modification_pos_std
# Saved feature: Modification_block_count
# Saved feature: Modification_max_block_length
# Saved feature: Modification_char_entropy
# Saved feature: Modification_dominant_mod_fraction
# Saved feature: Modification_evenness
# Saved feature: Modification_symmetry_score
# Saved feature: Modification_skew_index
# Saved feature: Modification_mean_gap
# Saved feature: Modification_local_density_max
# Saved feature: Modification_in_core
# Saved feature: Modification_longest_repeat_run
# Saved feature: Modification_adjacent_pair_count
# Saved feature: Modification_strong_repeat_group_count

# %%
calculator.calculate_hybridization()
# Out:
# Computing 12 hybridization features...
# INFO: Pandarallel will run on 24 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.
# Calculating feature: MOE_DIFF_37_MD_GB_HYBR...
# Calculating feature: MOE_DIFF_37_MD_PB_HYBR...
# Calculating feature: PSDNA_RNA_MD_37_GB_TOTAL_HYBR...
# Calculating feature: PSDNA_RNA_MD_37_PB_TOTAL_HYBR...
# Calculating feature: METHYL_CYTOSINES...
# Calculating feature: LNA_DIFF_37_HYBR...
# Calculating feature: CET_DIFF_37_HYBR...
# Calculating feature: TOTAL_PSDNA_HYBR...
# Calculating feature: PSDNA_DIFF_37_HYBR...
# Calculating feature: TOTAL_DNA_HYBR...
# Calculating feature: TOTAL_DNA_RNA_HYBR...
# Calculating vectorized feature: DNA_HYBR_DIFF...
# Saved feature: MOE_DIFF_37_MD_GB_HYBR
# Saved feature: MOE_DIFF_37_MD_PB_HYBR
# Saved feature: PSDNA_RNA_MD_37_GB_TOTAL_HYBR
# Saved feature: PSDNA_RNA_MD_37_PB_TOTAL_HYBR
# Saved feature: METHYL_CYTOSINES
# Saved feature: LNA_DIFF_37_HYBR
# Saved feature: CET_DIFF_37_HYBR
# Saved feature: TOTAL_PSDNA_HYBR
# Saved feature: PSDNA_DIFF_37_HYBR
# Saved feature: TOTAL_DNA_HYBR
# Saved feature: TOTAL_DNA_RNA_HYBR
# Saved feature: DNA_HYBR_DIFF

# %%
calculator.calculate_backbone_features()
# Out:
# Computing 4 backbone features...
# Saved feature: is_all_ps
# Saved feature: po_percentage
# Saved feature: ps_end_score
# Saved feature: max_consecutive_PO

# %%
calculator.calculate_ribo_seq()
# Out:
# Computing 20 Ribo-seq features...
# Loading GeneCoordinateMapper into memory (happens once)...
# Row 1505 failed: 'KZ208915.1'
# Row 1506 failed: 'KZ208915.1'
# Row 1507 failed: 'KZ208915.1'
# Row 1508 failed: 'KZ208915.1'
# Row 1509 failed: 'KZ208915.1'
# Row 1510 failed: 'KZ208915.1'
# Row 1511 failed: 'KZ208915.1'
# Row 1512 failed: 'KZ208915.1'
# Row 1513 failed: 'KZ208915.1'
# Row 1514 failed: 'KZ208915.1'
# Row 1515 failed: 'KZ208915.1'
# Row 1516 failed: 'KZ208915.1'
# Row 1517 failed: 'KZ208915.1'
# Row 1518 failed: 'KZ208915.1'
# Row 1519 failed: 'KZ208915.1'
# Row 1520 failed: 'KZ208915.1'
# Row 1521 failed: 'KZ208915.1'
# Row 1522 failed: 'KZ208915.1'
# Row 1523 failed: 'KZ208915.1'
# Row 1524 failed: 'KZ208915.1'
# Row 1525 failed: 'KZ208915.1'
# Row 1526 failed: 'KZ208915.1'
# Row 1527 failed: 'KZ208915.1'
# Row 1528 failed: 'KZ208915.1'
# Row 1529 failed: 'KZ208915.1'
# Row 1530 failed: 'KZ208915.1'
# Row 1531 failed: 'KZ208915.1'
# Row 1532 failed: 'KZ208915.1'
# Row 1533 failed: 'KZ208915.1'
# Row 1534 failed: 'KZ208915.1'
# Row 1535 failed: 'KZ208915.1'
# Row 1536 failed: 'KZ208915.1'
# Row 1537 failed: 'KZ208915.1'
# Row 1538 failed: 'KZ208915.1'
# Row 1539 failed: 'KZ208915.1'
# Row 1540 failed: 'KZ208915.1'
# Row 1541 failed: 'KZ208915.1'
# Row 1542 failed: 'KZ208915.1'
# Row 1543 failed: 'KZ208915.1'
# Row 1544 failed: 'KZ208915.1'
# Row 1545 failed: 'KZ208915.1'
# Row 1546 failed: 'KZ208915.1'
# Row 1547 failed: 'KZ208915.1'
# Row 1548 failed: 'KZ208915.1'
# Row 1549 failed: 'KZ208915.1'
# Row 1550 failed: 'KZ208915.1'
# Row 1551 failed: 'KZ208915.1'
# Row 1552 failed: 'KZ208915.1'
# Row 1553 failed: 'KZ208915.1'
# Row 1554 failed: 'KZ208915.1'
# Row 1555 failed: 'KZ208915.1'
# Row 1556 failed: 'KZ208915.1'
# Row 1557 failed: 'KZ208915.1'
# Row 1558 failed: 'KZ208915.1'
# Row 1559 failed: 'KZ208915.1'
# Row 1560 failed: 'KZ208915.1'
# Row 1561 failed: 'KZ208915.1'
# Row 1562 failed: 'KZ208915.1'
# Row 1563 failed: 'KZ208915.1'
# Row 1564 failed: 'KZ208915.1'
# Row 1565 failed: 'KZ208915.1'
# Row 1566 failed: 'KZ208915.1'
# Row 1567 failed: 'KZ208915.1'
# Row 1568 failed: 'KZ208915.1'
# Row 1569 failed: 'KZ208915.1'
# Row 1570 failed: 'KZ208915.1'
# Row 1571 failed: 'KZ208915.1'
# Row 1572 failed: 'KZ208915.1'
# Row 1573 failed: 'KZ208915.1'
# Row 1574 failed: 'KZ208915.1'
# Row 1575 failed: 'KZ208915.1'
# Row 1576 failed: 'KZ208915.1'
# Row 3317 failed: 'GL000256.2'
# Row 3318 failed: 'GL000256.2'
# Row 3319 failed: 'GL000256.2'
# Row 3320 failed: 'GL000256.2'
# Row 3321 failed: 'GL000256.2'
# Row 3322 failed: 'GL000256.2'
# Row 3323 failed: 'GL000256.2'
# Row 3324 failed: 'GL000256.2'
# Row 3325 failed: 'GL000256.2'
# Row 3326 failed: 'GL000256.2'
# Row 3327 failed: 'GL000256.2'
# Row 3328 failed: 'GL000256.2'
# Row 3329 failed: 'GL000256.2'
# Row 3330 failed: 'GL000256.2'
# Row 3331 failed: 'GL000256.2'
# Row 3332 failed: 'GL000256.2'
# Row 3333 failed: 'GL000256.2'
# Row 3334 failed: 'GL000256.2'
# Row 3335 failed: 'GL000256.2'
# Row 3336 failed: 'GL000256.2'
# Row 3337 failed: 'GL000256.2'
# Row 3338 failed: 'GL000256.2'
# Row 3339 failed: 'GL000256.2'
# Row 3340 failed: 'GL000256.2'
# Row 3341 failed: 'GL000256.2'
# Row 3342 failed: 'GL000256.2'
# Row 3343 failed: 'GL000256.2'
# Row 3344 failed: 'GL000256.2'
# Row 3345 failed: 'GL000256.2'
# Row 3346 failed: 'GL000256.2'
# Row 3347 failed: 'GL000256.2'
# Row 3348 failed: 'GL000256.2'
# Row 3349 failed: 'GL000256.2'
# Row 3350 failed: 'GL000256.2'
# Row 3351 failed: 'GL000256.2'
# Row 3352 failed: 'GL000256.2'
# Row 3353 failed: 'GL000256.2'
# Row 3354 failed: 'GL000256.2'
# Row 3355 failed: 'GL000256.2'
# Row 3356 failed: 'GL000256.2'
# Row 3357 failed: 'GL000256.2'
# Row 3358 failed: 'GL000256.2'
# Row 3359 failed: 'GL000256.2'
# Row 3360 failed: 'GL000256.2'
# Row 3361 failed: 'GL000256.2'
# Row 3362 failed: 'GL000256.2'
# Row 3363 failed: 'GL000256.2'
# Row 3364 failed: 'GL000256.2'
# Row 3365 failed: 'GL000256.2'
# Row 3366 failed: 'GL000256.2'
# Row 3367 failed: 'GL000256.2'
# Row 3368 failed: 'GL000256.2'
# Row 3369 failed: 'GL000256.2'
# Row 3370 failed: 'GL000256.2'
# Row 3371 failed: 'GL000256.2'
# Row 3372 failed: 'GL000256.2'
# Row 3373 failed: 'GL000256.2'
# Row 3374 failed: 'GL000256.2'
# Row 3375 failed: 'GL000256.2'
# Row 3376 failed: 'GL000256.2'
# Row 3377 failed: 'GL000256.2'
# Row 3378 failed: 'GL000256.2'
# Row 3379 failed: 'GL000256.2'
# Row 3380 failed: 'GL000256.2'
# Row 3381 failed: 'GL000256.2'
# Row 3382 failed: 'GL000256.2'
# Row 3383 failed: 'GL000256.2'
# Row 3384 failed: 'GL000256.2'
# Row 3385 failed: 'GL000256.2'
# Row 3386 failed: 'GL000256.2'
# Row 3387 failed: 'GL000256.2'
# Row 3388 failed: 'GL000256.2'
# Row 3389 failed: 'GL000256.2'
# Row 3390 failed: 'GL000256.2'
# Row 3391 failed: 'GL000256.2'
# Row 3392 failed: 'GL000256.2'
# Row 3393 failed: 'GL000256.2'
# Row 3394 failed: 'GL000256.2'
# Row 4160 failed: 'KI270908.1'
# Row 4161 failed: 'KI270908.1'
# Row 4162 failed: 'KI270908.1'
# Row 4163 failed: 'KI270908.1'
# Row 4164 failed: 'KI270908.1'
# Row 4165 failed: 'KI270908.1'
# Row 4166 failed: 'KI270908.1'
# Row 4167 failed: 'KI270908.1'
# Row 4168 failed: 'KI270908.1'
# Row 4169 failed: 'KI270908.1'
# Row 4170 failed: 'KI270908.1'
# Row 4171 failed: 'KI270908.1'
# Row 4172 failed: 'KI270908.1'
# Row 4173 failed: 'KI270908.1'
# Row 4174 failed: 'KI270908.1'
# Row 4175 failed: 'KI270908.1'
# Row 4176 failed: 'KI270908.1'
# Row 4177 failed: 'KI270908.1'
# Row 4178 failed: 'KI270908.1'
# Row 4179 failed: 'KI270908.1'
# Row 4180 failed: 'KI270908.1'
# Row 4181 failed: 'KI270908.1'
# Row 4182 failed: 'KI270908.1'
# Row 4183 failed: 'KI270908.1'
# Row 4184 failed: 'KI270908.1'
# Row 4185 failed: 'KI270908.1'
# Row 4186 failed: 'KI270908.1'
# Row 4187 failed: 'KI270908.1'
# Row 4188 failed: 'KI270908.1'
# Row 4189 failed: 'KI270908.1'
# Row 4190 failed: 'KI270908.1'
# Row 4191 failed: 'KI270908.1'
# Row 4192 failed: 'KI270908.1'
# Row 4193 failed: 'KI270908.1'
# Row 4194 failed: 'KI270908.1'
# Row 4195 failed: 'KI270908.1'
# Row 4196 failed: 'KI270908.1'
# Row 4197 failed: 'KI270908.1'
# Row 4198 failed: 'KI270908.1'
# Row 4199 failed: 'KI270908.1'
# Row 4200 failed: 'KI270908.1'
# Row 4201 failed: 'KI270908.1'
# Row 4202 failed: 'KI270908.1'
# Row 4203 failed: 'KI270908.1'
# Row 4204 failed: 'KI270908.1'
# Row 4205 failed: 'KI270908.1'
# Row 4206 failed: 'KI270908.1'
# Row 4207 failed: 'KI270908.1'
# Row 4208 failed: 'KI270908.1'
# Row 4209 failed: 'KI270908.1'
# Row 4210 failed: 'KI270908.1'
# Row 4211 failed: 'KI270908.1'
# Row 4212 failed: 'KI270908.1'
# Row 4213 failed: 'KI270908.1'
# Row 4214 failed: 'KI270908.1'
# Row 4215 failed: 'KI270908.1'
# Row 4216 failed: 'KI270908.1'
# Row 4217 failed: 'KI270908.1'
# Row 4218 failed: 'KI270908.1'
# Row 4219 failed: 'KI270908.1'
# Row 4220 failed: 'KI270908.1'
# Row 4221 failed: 'KI270908.1'
# Row 4222 failed: 'KI270908.1'
# Row 4223 failed: 'KI270908.1'
# Row 4224 failed: 'KI270908.1'
# Row 4225 failed: 'KI270908.1'
# Row 4226 failed: 'KI270908.1'
# Row 4227 failed: 'KI270908.1'
# Row 4228 failed: 'KI270908.1'
# Row 4229 failed: 'KI270908.1'
# Row 4230 failed: 'KI270908.1'
# Row 4231 failed: 'KI270908.1'
# Row 4232 failed: 'KI270908.1'
# Row 4233 failed: 'KI270908.1'
# Row 4234 failed: 'KI270908.1'
# Row 4235 failed: 'KI270908.1'
# Row 4236 failed: 'KI270908.1'
# Row 4237 failed: 'KI270908.1'
# Row 4238 failed: 'KI270908.1'
# Row 4317 failed: 'KI270908.1'
# Row 4318 failed: 'KI270908.1'
# Row 4319 failed: 'KI270908.1'
# Row 4320 failed: 'KI270908.1'
# Row 4321 failed: 'KI270908.1'
# Row 4322 failed: 'KI270908.1'
# Row 4323 failed: 'KI270908.1'
# Row 4324 failed: 'KI270908.1'
# Row 4325 failed: 'KI270908.1'
# Row 4326 failed: 'KI270908.1'
# Row 4327 failed: 'KI270908.1'
# Row 4328 failed: 'KI270908.1'
# Row 4329 failed: 'KI270908.1'
# Row 4330 failed: 'KI270908.1'
# Row 4331 failed: 'KI270908.1'
# Row 4332 failed: 'KI270908.1'
# Row 4333 failed: 'KI270908.1'
# Row 4334 failed: 'KI270908.1'
# Row 4335 failed: 'KI270908.1'
# Row 4336 failed: 'KI270908.1'
# Row 4337 failed: 'KI270908.1'
# Row 4338 failed: 'KI270908.1'
# Row 4339 failed: 'KI270908.1'
# Row 4340 failed: 'KI270908.1'
# Row 4341 failed: 'KI270908.1'
# Row 4342 failed: 'KI270908.1'
# Row 4343 failed: 'KI270908.1'
# Row 4344 failed: 'KI270908.1'
# Row 4345 failed: 'KI270908.1'
# Row 4346 failed: 'KI270908.1'
# Row 4347 failed: 'KI270908.1'
# Row 4348 failed: 'KI270908.1'
# Row 4349 failed: 'KI270908.1'
# Row 4350 failed: 'KI270908.1'
# Row 4351 failed: 'KI270908.1'
# Row 4352 failed: 'KI270908.1'
# Row 4353 failed: 'KI270908.1'
# Row 4354 failed: 'KI270908.1'
# Row 4355 failed: 'KI270908.1'
# Row 4356 failed: 'KI270908.1'
# Row 4357 failed: 'KI270908.1'
# Row 4358 failed: 'KI270908.1'
# Row 4359 failed: 'KI270908.1'
# Row 4360 failed: 'KI270908.1'
# Row 4361 failed: 'KI270908.1'
# Row 4362 failed: 'KI270908.1'
# Row 4363 failed: 'KI270908.1'
# Row 4364 failed: 'KI270908.1'
# Row 4365 failed: 'KI270908.1'
# Row 4366 failed: 'KI270908.1'
# Row 4367 failed: 'KI270908.1'
# Row 4368 failed: 'KI270908.1'
# Row 4369 failed: 'KI270908.1'
# Row 4370 failed: 'KI270908.1'
# Row 4371 failed: 'KI270908.1'
# Row 4372 failed: 'KI270908.1'
# Row 4373 failed: 'KI270908.1'
# Row 4374 failed: 'KI270908.1'
# Row 4375 failed: 'KI270908.1'
# Row 4376 failed: 'KI270908.1'
# Row 4377 failed: 'KI270908.1'
# Row 4378 failed: 'KI270908.1'
# Row 4379 failed: 'KI270908.1'
# Row 4380 failed: 'KI270908.1'
# Row 4381 failed: 'KI270908.1'
# Row 4382 failed: 'KI270908.1'
# Row 4383 failed: 'KI270908.1'
# Row 4384 failed: 'KI270908.1'
# Row 4385 failed: 'KI270908.1'
# Row 4386 failed: 'KI270908.1'
# Row 4387 failed: 'KI270908.1'
# Row 4388 failed: 'KI270908.1'
# Row 4389 failed: 'KI270908.1'
# Row 4390 failed: 'KI270908.1'
# Row 4391 failed: 'KI270908.1'
# Row 4392 failed: 'KI270908.1'
# Row 4393 failed: 'KI270908.1'
# Row 4394 failed: 'KI270908.1'
# Row 7085 failed: 'KI270908.1'
# Row 7086 failed: 'KI270908.1'
# Row 7087 failed: 'KI270908.1'
# Row 7088 failed: 'KI270908.1'
# Row 7089 failed: 'KI270908.1'
# Row 7090 failed: 'KI270908.1'
# Row 7091 failed: 'KI270908.1'
# Row 7092 failed: 'KI270908.1'
# Row 7093 failed: 'KI270908.1'
# Row 7094 failed: 'KI270908.1'
# Row 7095 failed: 'KI270908.1'
# Row 7096 failed: 'KI270908.1'
# Row 7097 failed: 'KI270908.1'
# Row 7098 failed: 'KI270908.1'
# Row 7099 failed: 'KI270908.1'
# Row 7100 failed: 'KI270908.1'
# Row 7101 failed: 'KI270908.1'
# Row 7102 failed: 'KI270908.1'
# Row 7103 failed: 'KI270908.1'
# Row 7104 failed: 'KI270908.1'
# Row 7105 failed: 'KI270908.1'
# Row 7106 failed: 'KI270908.1'
# Row 7107 failed: 'KI270908.1'
# Row 7108 failed: 'KI270908.1'
# Row 7109 failed: 'KI270908.1'
# Row 7110 failed: 'KI270908.1'
# Row 7111 failed: 'KI270908.1'
# Row 7112 failed: 'KI270908.1'
# Row 7113 failed: 'KI270908.1'
# Row 7114 failed: 'KI270908.1'
# Row 7115 failed: 'KI270908.1'
# Row 7116 failed: 'KI270908.1'
# Row 7117 failed: 'KI270908.1'
# Row 7118 failed: 'KI270908.1'
# Row 7119 failed: 'KI270908.1'
# Row 7120 failed: 'KI270908.1'
# Row 7121 failed: 'KI270908.1'
# Row 7122 failed: 'KI270908.1'
# Row 7123 failed: 'KI270908.1'
# Row 7124 failed: 'KI270908.1'
# Row 7125 failed: 'KI270908.1'
# Row 7126 failed: 'KI270908.1'
# Row 7127 failed: 'KI270908.1'
# Row 7128 failed: 'KI270908.1'
# Row 7129 failed: 'KI270908.1'
# Row 7130 failed: 'KI270908.1'
# Row 7131 failed: 'KI270908.1'
# Row 7132 failed: 'KI270908.1'
# Row 7133 failed: 'KI270908.1'
# Row 7134 failed: 'KI270908.1'
# Row 7135 failed: 'KI270908.1'
# Row 7136 failed: 'KI270908.1'
# Row 7137 failed: 'KI270908.1'
# Row 7138 failed: 'KI270908.1'
# Row 7139 failed: 'KI270908.1'
# Row 7140 failed: 'KI270908.1'
# Row 7141 failed: 'KI270908.1'
# Row 7142 failed: 'KI270908.1'
# Row 7143 failed: 'KI270908.1'
# Row 7144 failed: 'KI270908.1'
# Row 7145 failed: 'KI270908.1'
# Row 7146 failed: 'KI270908.1'
# Row 7147 failed: 'KI270908.1'
# Row 7148 failed: 'KI270908.1'
# Row 7149 failed: 'KI270908.1'
# Row 7150 failed: 'KI270908.1'
# Row 7151 failed: 'KI270908.1'
# Row 7152 failed: 'KI270908.1'
# Row 7153 failed: 'KI270908.1'
# Row 7154 failed: 'KI270908.1'
# Row 7155 failed: 'KI270908.1'
# Row 7156 failed: 'KI270908.1'
# Row 7157 failed: 'KI270908.1'
# Row 7158 failed: 'KI270908.1'
# Row 7159 failed: 'KI270908.1'
# Row 7160 failed: 'KI270908.1'
# Row 7161 failed: 'KI270908.1'
# Row 7162 failed: 'KI270908.1'
# Row 7163 failed: 'KI270908.1'
# Row 8497 failed: 'KI270847.1'
# Row 8498 failed: 'KI270847.1'
# Row 8499 failed: 'KI270847.1'
# Row 8500 failed: 'KI270847.1'
# Row 8501 failed: 'KI270847.1'
# Row 8502 failed: 'KI270847.1'
# Row 8503 failed: 'KI270847.1'
# Row 8504 failed: 'KI270847.1'
# Row 8505 failed: 'KI270847.1'
# Row 8506 failed: 'KI270847.1'
# Row 8507 failed: 'KI270847.1'
# Row 8508 failed: 'KI270847.1'
# Row 8509 failed: 'KI270847.1'
# Row 8510 failed: 'KI270847.1'
# Row 8511 failed: 'KI270847.1'
# Row 8512 failed: 'KI270847.1'
# Row 8513 failed: 'KI270847.1'
# Row 8514 failed: 'KI270847.1'
# Row 8515 failed: 'KI270847.1'
# Row 8516 failed: 'KI270847.1'
# Row 8517 failed: 'KI270847.1'
# Row 8518 failed: 'KI270847.1'
# Row 9061 failed: 'GL383581.2'
# Row 9062 failed: 'GL383581.2'
# Row 9063 failed: 'GL383581.2'
# Row 9064 failed: 'GL383581.2'
# Row 9065 failed: 'GL383581.2'
# Row 9066 failed: 'GL383581.2'
# Row 9067 failed: 'GL383581.2'
# Row 9068 failed: 'GL383581.2'
# Row 9069 failed: 'GL383581.2'
# Row 9070 failed: 'GL383581.2'
# Row 9071 failed: 'GL383581.2'
# Row 9072 failed: 'GL383581.2'
# Row 9073 failed: 'GL383581.2'
# Row 9074 failed: 'GL383581.2'
# Row 9075 failed: 'GL383581.2'
# Row 9076 failed: 'GL383581.2'
# Row 9077 failed: 'GL383581.2'
# Row 9078 failed: 'GL383581.2'
# Row 9079 failed: 'GL383581.2'
# Row 9080 failed: 'GL383581.2'
# Row 9081 failed: 'GL383581.2'
# Row 9082 failed: 'GL383581.2'
# Row 9083 failed: 'GL383581.2'
# Row 9084 failed: 'GL383581.2'
# Row 9085 failed: 'GL383581.2'
# Row 9086 failed: 'GL383581.2'
# Row 9087 failed: 'GL383581.2'
# Row 9088 failed: 'GL383581.2'
# Row 9089 failed: 'GL383581.2'
# Row 9090 failed: 'GL383581.2'
# Row 9091 failed: 'GL383581.2'
# Row 9092 failed: 'GL383581.2'
# Row 9093 failed: 'GL383581.2'
# Row 9094 failed: 'GL383581.2'
# Row 9095 failed: 'GL383581.2'
# Row 9096 failed: 'GL383581.2'
# Row 9097 failed: 'GL383581.2'
# Row 9098 failed: 'GL383581.2'
# Row 9099 failed: 'GL383581.2'
# Row 9100 failed: 'GL383581.2'
# Row 9101 failed: 'GL383581.2'
# Row 9102 failed: 'GL383581.2'
# Row 9103 failed: 'GL383581.2'
# Row 9104 failed: 'GL383581.2'
# Row 9105 failed: 'GL383581.2'
# Row 9106 failed: 'GL383581.2'
# Row 9107 failed: 'GL383581.2'
# Row 9108 failed: 'GL383581.2'
# Row 9109 failed: 'GL383581.2'
# Row 9110 failed: 'GL383581.2'
# Row 9111 failed: 'GL383581.2'
# Row 9112 failed: 'GL383581.2'
# Row 9113 failed: 'GL383581.2'
# Row 9114 failed: 'GL383581.2'
# Row 9115 failed: 'GL383581.2'
# Row 9116 failed: 'GL383581.2'
# Row 9117 failed: 'GL383581.2'
# Row 9118 failed: 'GL383581.2'
# Row 9119 failed: 'GL383581.2'
# Row 9120 failed: 'GL383581.2'
# Row 9121 failed: 'GL383581.2'
# Row 9122 failed: 'GL383581.2'
# Row 9123 failed: 'GL383581.2'
# Row 9124 failed: 'GL383581.2'
# Row 9125 failed: 'GL383581.2'
# Row 9126 failed: 'GL383581.2'
# Row 9127 failed: 'GL383581.2'
# Row 9128 failed: 'GL383581.2'
# Row 9129 failed: 'GL383581.2'
# Row 9130 failed: 'GL383581.2'
# Row 9131 failed: 'GL383581.2'
# Row 9132 failed: 'GL383581.2'
# Row 9133 failed: 'GL383581.2'
# Row 9134 failed: 'GL383581.2'
# Row 9135 failed: 'GL383581.2'
# Row 9136 failed: 'GL383581.2'
# Row 9137 failed: 'GL383581.2'
# Row 9138 failed: 'GL383581.2'
# Row 9139 failed: 'KQ983257.1'
# Row 9140 failed: 'KQ983257.1'
# Row 9141 failed: 'KQ983257.1'
# Row 9142 failed: 'KQ983257.1'
# Row 9143 failed: 'KQ983257.1'
# Row 9144 failed: 'KQ983257.1'
# Row 9145 failed: 'KQ983257.1'
# Row 9146 failed: 'KQ983257.1'
# Row 9147 failed: 'KQ983257.1'
# Row 9148 failed: 'KQ983257.1'
# Row 9149 failed: 'KQ983257.1'
# Row 9150 failed: 'KQ983257.1'
# Row 9151 failed: 'KQ983257.1'
# Row 9152 failed: 'KQ983257.1'
# Row 9153 failed: 'KQ983257.1'
# Row 9154 failed: 'KQ983257.1'
# Row 9155 failed: 'KQ983257.1'
# Row 9156 failed: 'KQ983257.1'
# Row 9157 failed: 'KQ983257.1'
# Row 9158 failed: 'KQ983257.1'
# Row 9159 failed: 'KQ983257.1'
# Row 9160 failed: 'KQ983257.1'
# Row 9161 failed: 'KQ983257.1'
# Row 9162 failed: 'KQ983257.1'
# Row 9163 failed: 'KQ983257.1'
# Row 9164 failed: 'KQ983257.1'
# Row 9165 failed: 'KQ983257.1'
# Row 9166 failed: 'KQ983257.1'
# Row 9167 failed: 'KQ983257.1'
# Row 9168 failed: 'KQ983257.1'
# Row 9169 failed: 'KQ983257.1'
# Row 9170 failed: 'KQ983257.1'
# Row 9171 failed: 'KQ983257.1'
# Row 9172 failed: 'KQ983257.1'
# Row 9173 failed: 'KQ983257.1'
# Row 9174 failed: 'KQ983257.1'
# Row 9175 failed: 'KQ983257.1'
# Row 9176 failed: 'KQ983257.1'
# Row 9177 failed: 'KQ983257.1'
# Row 9178 failed: 'KQ983257.1'
# Row 9179 failed: 'KQ983257.1'
# Row 9180 failed: 'KQ983257.1'
# Row 9181 failed: 'KQ983257.1'
# Row 9182 failed: 'KQ983257.1'
# Row 9183 failed: 'KQ983257.1'
# Row 9184 failed: 'KQ983257.1'
# Row 9185 failed: 'KQ983257.1'
# Row 9186 failed: 'KQ983257.1'
# Row 9187 failed: 'KQ983257.1'
# Row 9188 failed: 'KQ983257.1'
# Row 9189 failed: 'KQ983257.1'
# Row 9190 failed: 'KQ983257.1'
# Row 9191 failed: 'KQ983257.1'
# Row 9192 failed: 'KQ983257.1'
# Row 9193 failed: 'KQ983257.1'
# Row 9194 failed: 'KQ983257.1'
# Row 9195 failed: 'KQ983257.1'
# Row 9196 failed: 'KQ983257.1'
# Row 9197 failed: 'KQ983257.1'
# Row 9198 failed: 'KQ983257.1'
# Row 9199 failed: 'KQ983257.1'
# Row 9200 failed: 'KQ983257.1'
# Row 9201 failed: 'KQ983257.1'
# Row 9202 failed: 'KQ983257.1'
# Row 9203 failed: 'KQ983257.1'
# Row 9204 failed: 'KQ983257.1'
# Row 9205 failed: 'KQ983257.1'
# Row 9206 failed: 'KQ983257.1'
# Row 9207 failed: 'KQ983257.1'
# Row 9208 failed: 'KQ983257.1'
# Row 9209 failed: 'KQ983257.1'
# Row 9210 failed: 'KQ983257.1'
# Row 9211 failed: 'KQ983257.1'
# Row 9212 failed: 'KQ983257.1'
# Row 9213 failed: 'KQ983257.1'
# Row 9214 failed: 'KQ983257.1'
# Row 9215 failed: 'KQ983257.1'
# Row 9216 failed: 'KQ983257.1'
# Row 9217 failed: 'KQ983257.1'
# Row 9218 failed: 'KQ983257.1'
# Row 9219 failed: 'KQ983257.1'
# Row 9220 failed: 'KQ983257.1'
# Row 9221 failed: 'KQ983257.1'
# Row 9222 failed: 'KQ983257.1'
# Row 9223 failed: 'KQ983257.1'
# Row 9224 failed: 'KQ983257.1'
# Row 9225 failed: 'KQ983257.1'
# Row 9226 failed: 'KQ983257.1'
# Row 9227 failed: 'KQ983257.1'
# Row 9228 failed: 'KQ983257.1'
# Row 9229 failed: 'KQ983257.1'
# Row 9230 failed: 'KQ983257.1'
# Row 9231 failed: 'KQ983257.1'
# Row 9232 failed: 'KQ983257.1'
# Row 9233 failed: 'KQ983257.1'
# Row 9234 failed: 'KQ983257.1'
# Row 9235 failed: 'KQ983257.1'
# Row 9236 failed: 'KQ983257.1'
# Row 9237 failed: 'KQ983257.1'
# Row 9238 failed: 'KQ983257.1'
# Row 9239 failed: 'KQ983257.1'
# Row 9240 failed: 'KQ983257.1'
# Row 9241 failed: 'KQ983257.1'
# Row 9242 failed: 'KQ983257.1'
# Row 9243 failed: 'KQ983257.1'
# Row 9244 failed: 'KQ983257.1'
# Row 9245 failed: 'KQ983257.1'
# Row 9246 failed: 'KQ983257.1'
# Row 9247 failed: 'KQ983257.1'
# Row 9248 failed: 'KQ983257.1'
# Row 9249 failed: 'KQ983257.1'
# Row 9250 failed: 'KQ983257.1'
# Row 9251 failed: 'KQ983257.1'
# Row 9252 failed: 'KQ983257.1'
# Row 9253 failed: 'KQ983257.1'
# Row 9254 failed: 'KQ983257.1'
# Row 9255 failed: 'KQ983257.1'
# Row 9256 failed: 'KQ983257.1'
# Row 9257 failed: 'KQ983257.1'
# Row 9258 failed: 'KQ983257.1'
# Row 9259 failed: 'KQ983257.1'
# Row 9260 failed: 'KQ983257.1'
# Row 9261 failed: 'KQ983257.1'
# Row 9262 failed: 'KQ983257.1'
# Row 9263 failed: 'KQ983257.1'
# Row 9264 failed: 'KQ983257.1'
# Row 9265 failed: 'KQ983257.1'
# Row 9266 failed: 'KQ983257.1'
# Row 9267 failed: 'KQ983257.1'
# Row 9268 failed: 'KQ983257.1'
# Row 9269 failed: 'KQ983257.1'
# Row 9270 failed: 'KQ983257.1'
# Row 9271 failed: 'KQ983257.1'
# Row 9272 failed: 'KQ983257.1'
# Row 9273 failed: 'KQ983257.1'
# Row 9274 failed: 'KQ983257.1'
# Row 9275 failed: 'KQ983257.1'
# Row 9276 failed: 'KQ983257.1'
# Row 9277 failed: 'KQ983257.1'
# Row 9278 failed: 'KQ983257.1'
# Row 9279 failed: 'KQ983257.1'
# Row 9280 failed: 'KQ983257.1'
# Row 9281 failed: 'KQ983257.1'
# Row 9282 failed: 'KQ983257.1'
# Row 9283 failed: 'KQ983257.1'
# Row 9284 failed: 'KQ983257.1'
# Row 9285 failed: 'KQ983257.1'
# Row 9286 failed: 'KQ983257.1'
# Row 9287 failed: 'KQ983257.1'
# Row 9288 failed: 'KQ983257.1'
# Row 9289 failed: 'KQ983257.1'
# Row 9290 failed: 'KQ983257.1'
# Row 9291 failed: 'KQ983257.1'
# Row 9292 failed: 'KQ983257.1'
# Row 9293 failed: 'KQ983257.1'
# Row 9294 failed: 'KQ983257.1'
# Row 9295 failed: 'KQ983257.1'
# Row 9296 failed: 'KQ983257.1'
# Row 9297 failed: 'KQ983257.1'
# Row 9298 failed: 'KQ983257.1'
# Row 9299 failed: 'KQ983257.1'
# Row 9300 failed: 'KQ983257.1'
# Row 9301 failed: 'KQ983257.1'
# Row 9302 failed: 'KQ983257.1'
# Row 9303 failed: 'KQ983257.1'
# Row 9304 failed: 'KQ983257.1'
# Row 9305 failed: 'KQ983257.1'
# Row 9306 failed: 'KQ983257.1'
# Row 9307 failed: 'KQ983257.1'
# Row 9308 failed: 'KQ983257.1'
# Row 9309 failed: 'KQ983257.1'
# Row 9310 failed: 'KQ983257.1'
# Row 9311 failed: 'KQ983257.1'
# Row 9312 failed: 'KQ983257.1'
# Row 9313 failed: 'KQ983257.1'
# Row 9314 failed: 'KQ983257.1'
# Row 9315 failed: 'KQ983257.1'
# Row 9316 failed: 'KQ983257.1'
# Row 12223 failed: 'KI270908.1'
# Row 12224 failed: 'KI270908.1'
# Row 12225 failed: 'KI270908.1'
# Row 12226 failed: 'KI270908.1'
# Row 12227 failed: 'KI270908.1'
# Row 12228 failed: 'KI270908.1'
# Row 12229 failed: 'KI270908.1'
# Row 12230 failed: 'KI270908.1'
# Row 12231 failed: 'KI270908.1'
# Row 12232 failed: 'KI270908.1'
# Row 12233 failed: 'KI270908.1'
# Row 12234 failed: 'KI270908.1'
# Row 12235 failed: 'KI270908.1'
# Row 12236 failed: 'KI270908.1'
# Row 12237 failed: 'KI270908.1'
# Row 12238 failed: 'KI270908.1'
# Row 12239 failed: 'KI270908.1'
# Row 12240 failed: 'KI270908.1'
# Row 12241 failed: 'KI270908.1'
# Row 12242 failed: 'KI270908.1'
# Row 12243 failed: 'KI270908.1'
# Row 12244 failed: 'KI270908.1'
# Row 12245 failed: 'KI270908.1'
# Row 12246 failed: 'KI270908.1'
# Row 12247 failed: 'KI270908.1'
# Row 12248 failed: 'KI270908.1'
# Row 12249 failed: 'KI270908.1'
# Row 12250 failed: 'KI270908.1'
# Row 12251 failed: 'KI270908.1'
# Row 12252 failed: 'KI270908.1'
# Row 12253 failed: 'KI270908.1'
# Row 12254 failed: 'KI270908.1'
# Row 12255 failed: 'KI270908.1'
# Row 12256 failed: 'KI270908.1'
# Row 12257 failed: 'KI270908.1'
# Row 12258 failed: 'KI270908.1'
# Row 12259 failed: 'KI270908.1'
# Row 12260 failed: 'KI270908.1'
# Row 12261 failed: 'KI270908.1'
# Row 12262 failed: 'KI270908.1'
# Row 12263 failed: 'KI270908.1'
# Row 12264 failed: 'KI270908.1'
# Row 12265 failed: 'KI270908.1'
# Row 12266 failed: 'KI270908.1'
# Row 12267 failed: 'KI270908.1'
# Row 12268 failed: 'KI270908.1'
# Row 12269 failed: 'KI270908.1'
# Row 12270 failed: 'KI270908.1'
# Row 12271 failed: 'KI270908.1'
# Row 12272 failed: 'KI270908.1'
# Row 12273 failed: 'KI270908.1'
# Row 12274 failed: 'KI270908.1'
# Row 12275 failed: 'KI270908.1'
# Row 12276 failed: 'KI270908.1'
# Row 12277 failed: 'KI270908.1'
# Row 12278 failed: 'KI270908.1'
# Row 12279 failed: 'KI270908.1'
# Row 12280 failed: 'KI270908.1'
# Row 12281 failed: 'KI270908.1'
# Row 12282 failed: 'KI270908.1'
# Row 12283 failed: 'KI270908.1'
# Row 12284 failed: 'KI270908.1'
# Row 12285 failed: 'KI270908.1'
# Row 12286 failed: 'KI270908.1'
# Row 12287 failed: 'KI270908.1'
# Row 12288 failed: 'KI270908.1'
# Row 12289 failed: 'KI270908.1'
# Row 12290 failed: 'KI270908.1'
# Row 12291 failed: 'KI270908.1'
# Row 12292 failed: 'KI270908.1'
# Row 12293 failed: 'KI270908.1'
# Row 12294 failed: 'KI270908.1'
# Row 12295 failed: 'KI270908.1'
# Row 12296 failed: 'KI270908.1'
# Row 12297 failed: 'KI270908.1'
# Row 12298 failed: 'KI270908.1'
# Row 12299 failed: 'KI270908.1'
# Row 12300 failed: 'KI270908.1'
# Row 12301 failed: 'KI270908.1'
# Row 13689 failed: 'KI270908.1'
# Row 13690 failed: 'KI270908.1'
# Row 13691 failed: 'KI270908.1'
# Row 13692 failed: 'KI270908.1'
# Row 13693 failed: 'KI270908.1'
# Row 13694 failed: 'KI270908.1'
# Row 13695 failed: 'KI270908.1'
# Row 13696 failed: 'KI270908.1'
# Row 13697 failed: 'KI270908.1'
# Row 13698 failed: 'KI270908.1'
# Row 13699 failed: 'KI270908.1'
# Row 13700 failed: 'KI270908.1'
# Row 13701 failed: 'KI270908.1'
# Row 13702 failed: 'KI270908.1'
# Row 13703 failed: 'KI270908.1'
# Row 13704 failed: 'KI270908.1'
# Row 13705 failed: 'KI270908.1'
# Row 13706 failed: 'KI270908.1'
# Row 13707 failed: 'KI270908.1'
# Row 13708 failed: 'KI270908.1'
# Row 13709 failed: 'KI270908.1'
# Row 13710 failed: 'KI270908.1'
# Row 13711 failed: 'KI270908.1'
# Row 13712 failed: 'KI270908.1'
# Row 13713 failed: 'KI270908.1'
# Row 13714 failed: 'KI270908.1'
# Row 13715 failed: 'KI270908.1'
# Row 13716 failed: 'KI270908.1'
# Row 13717 failed: 'KI270908.1'
# Row 13718 failed: 'KI270908.1'
# Row 13719 failed: 'KI270908.1'
# Row 13720 failed: 'KI270908.1'
# Row 13721 failed: 'KI270908.1'
# Row 13722 failed: 'KI270908.1'
# Row 13723 failed: 'KI270908.1'
# Row 13724 failed: 'KI270908.1'
# Row 13725 failed: 'KI270908.1'
# Row 13726 failed: 'KI270908.1'
# Row 13727 failed: 'KI270908.1'
# Row 13728 failed: 'KI270908.1'
# Row 13729 failed: 'KI270908.1'
# Row 13730 failed: 'KI270908.1'
# Row 13731 failed: 'KI270908.1'
# Row 13732 failed: 'KI270908.1'
# Row 13733 failed: 'KI270908.1'
# Row 13734 failed: 'KI270908.1'
# Row 13735 failed: 'KI270908.1'
# Row 13736 failed: 'KI270908.1'
# Row 13737 failed: 'KI270908.1'
# Row 13738 failed: 'KI270908.1'
# Row 13739 failed: 'KI270908.1'
# Row 13740 failed: 'KI270908.1'
# Row 13741 failed: 'KI270908.1'
# Row 13742 failed: 'KI270908.1'
# Row 13743 failed: 'KI270908.1'
# Row 13744 failed: 'KI270908.1'
# Row 13745 failed: 'KI270908.1'
# Row 13746 failed: 'KI270908.1'
# Row 13747 failed: 'KI270908.1'
# Row 13748 failed: 'KI270908.1'
# Row 13749 failed: 'KI270908.1'
# Row 13750 failed: 'KI270908.1'
# Row 13751 failed: 'KI270908.1'
# Row 13752 failed: 'KI270908.1'
# Row 13753 failed: 'KI270908.1'
# Row 13754 failed: 'KI270908.1'
# Row 13755 failed: 'KI270908.1'
# Row 13756 failed: 'KI270908.1'
# Row 13757 failed: 'KI270908.1'
# Row 13758 failed: 'KI270908.1'
# Row 13759 failed: 'KI270908.1'
# Row 13760 failed: 'KI270908.1'
# Row 13761 failed: 'KI270908.1'
# Row 13762 failed: 'KI270908.1'
# Row 13763 failed: 'KI270908.1'
# Row 13764 failed: 'KI270908.1'
# Row 13765 failed: 'KI270908.1'
# Row 13766 failed: 'KI270908.1'
# Row 14459 failed: 'GL000256.2'
# Row 14460 failed: 'GL000256.2'
# Row 14461 failed: 'GL000256.2'
# Row 14462 failed: 'GL000256.2'
# Row 14463 failed: 'GL000256.2'
# Row 14464 failed: 'GL000256.2'
# Row 14465 failed: 'GL000256.2'
# Row 14466 failed: 'GL000256.2'
# Row 14467 failed: 'GL000256.2'
# Row 14468 failed: 'GL000256.2'
# Row 14469 failed: 'GL000256.2'
# Row 14470 failed: 'GL000256.2'
# Row 14471 failed: 'GL000256.2'
# Row 14472 failed: 'GL000256.2'
# Row 14473 failed: 'GL000256.2'
# Row 14474 failed: 'GL000256.2'
# Row 14475 failed: 'GL000256.2'
# Row 14476 failed: 'GL000256.2'
# Row 14477 failed: 'GL000256.2'
# Row 14478 failed: 'GL000256.2'
# Row 14479 failed: 'GL000256.2'
# Row 14480 failed: 'GL000256.2'
# Row 14481 failed: 'GL000256.2'
# Row 14482 failed: 'GL000256.2'
# Row 14483 failed: 'GL000256.2'
# Row 14484 failed: 'GL000256.2'
# Row 14485 failed: 'GL000256.2'
# Row 14486 failed: 'GL000256.2'
# Row 14487 failed: 'GL000256.2'
# Row 14488 failed: 'GL000256.2'
# Row 14489 failed: 'GL000256.2'
# Row 14490 failed: 'GL000256.2'
# Row 14491 failed: 'GL000256.2'
# Row 14492 failed: 'GL000256.2'
# Row 14493 failed: 'GL000256.2'
# Row 14494 failed: 'GL000256.2'
# Row 14495 failed: 'GL000256.2'
# Row 14496 failed: 'GL000256.2'
# Row 14497 failed: 'GL000256.2'
# Row 14498 failed: 'GL000256.2'
# Row 14499 failed: 'GL000256.2'
# Row 14500 failed: 'GL000256.2'
# Row 14501 failed: 'GL000256.2'
# Row 14502 failed: 'GL000256.2'
# Row 14503 failed: 'GL000256.2'
# Row 14504 failed: 'GL000256.2'
# Row 14505 failed: 'GL000256.2'
# Row 14506 failed: 'GL000256.2'
# Row 14507 failed: 'GL000256.2'
# Row 14508 failed: 'GL000256.2'
# Row 14509 failed: 'GL000256.2'
# Row 14510 failed: 'GL000256.2'
# Row 14511 failed: 'GL000256.2'
# Row 14512 failed: 'GL000256.2'
# Row 14513 failed: 'GL000256.2'
# Row 14514 failed: 'GL000256.2'
# Row 14515 failed: 'GL000256.2'
# Row 14516 failed: 'GL000256.2'
# Row 14517 failed: 'GL000256.2'
# Row 14518 failed: 'GL000256.2'
# Row 14519 failed: 'GL000256.2'
# Row 14520 failed: 'GL000256.2'
# Row 14521 failed: 'GL000256.2'
# Row 14522 failed: 'GL000256.2'
# Row 14523 failed: 'GL000256.2'
# Row 14524 failed: 'GL000256.2'
# Row 14525 failed: 'GL000256.2'
# Row 14526 failed: 'GL000256.2'
# Row 14527 failed: 'GL000256.2'
# Row 14528 failed: 'GL000256.2'
# Row 14529 failed: 'GL000256.2'
# Row 14530 failed: 'GL000256.2'
# Row 14531 failed: 'GL000256.2'
# Row 14532 failed: 'GL000256.2'
# Row 14533 failed: 'GL000256.2'
# Row 14534 failed: 'GL000256.2'
# Row 14535 failed: 'GL000256.2'
# Row 14536 failed: 'GL000256.2'
# Row 14890 failed: 'KI270871.1'
# Row 14891 failed: 'KI270871.1'
# Row 14892 failed: 'KI270871.1'
# Row 14893 failed: 'KI270871.1'
# Row 14894 failed: 'KI270871.1'
# Row 14895 failed: 'KI270871.1'
# Row 14896 failed: 'KI270871.1'
# Row 14897 failed: 'KI270871.1'
# Row 14898 failed: 'KI270871.1'
# Row 14899 failed: 'KI270871.1'
# Row 14900 failed: 'KI270871.1'
# Row 14901 failed: 'KI270871.1'
# Row 14902 failed: 'KI270871.1'
# Row 14903 failed: 'KI270871.1'
# Row 14904 failed: 'KI270871.1'
# Row 14905 failed: 'KI270871.1'
# Row 14906 failed: 'KI270871.1'
# Row 14907 failed: 'KI270871.1'
# Row 14908 failed: 'KI270871.1'
# Row 14909 failed: 'KI270871.1'
# Row 14910 failed: 'KI270871.1'
# Row 14911 failed: 'KI270871.1'
# Row 14912 failed: 'KI270871.1'
# Row 14913 failed: 'KI270871.1'
# Row 14914 failed: 'KI270871.1'
# Row 14915 failed: 'KI270871.1'
# Row 14916 failed: 'KI270871.1'
# Row 14917 failed: 'KI270871.1'
# Row 14918 failed: 'KI270871.1'
# Row 14919 failed: 'KI270871.1'
# Row 14920 failed: 'KI270871.1'
# Row 14921 failed: 'KI270871.1'
# Row 14922 failed: 'KI270871.1'
# Row 14923 failed: 'KI270871.1'
# Row 14924 failed: 'KI270871.1'
# Row 14925 failed: 'KI270871.1'
# Row 14926 failed: 'KI270871.1'
# Row 14927 failed: 'KI270871.1'
# Row 14928 failed: 'KI270871.1'
# Row 14929 failed: 'KI270871.1'
# Row 14930 failed: 'KI270871.1'
# Row 14931 failed: 'KI270871.1'
# Row 14932 failed: 'KI270871.1'
# Row 14933 failed: 'KI270871.1'
# Row 14934 failed: 'KI270871.1'
# Row 14935 failed: 'KI270871.1'
# Row 14936 failed: 'KI270871.1'
# Row 14937 failed: 'KI270871.1'
# Row 14938 failed: 'KI270871.1'
# Row 14939 failed: 'KI270871.1'
# Row 14940 failed: 'KI270871.1'
# Row 14941 failed: 'KI270871.1'
# Row 14942 failed: 'KI270871.1'
# Row 14943 failed: 'KI270871.1'
# Row 14944 failed: 'KI270871.1'
# Row 14945 failed: 'KI270871.1'
# Row 14946 failed: 'KI270871.1'
# Row 14947 failed: 'KI270871.1'
# Row 14948 failed: 'KI270871.1'
# Row 14949 failed: 'KI270871.1'
# Row 14950 failed: 'KI270871.1'
# Row 14951 failed: 'KI270871.1'
# Row 14952 failed: 'KI270871.1'
# Row 14953 failed: 'KI270871.1'
# Row 14954 failed: 'KI270871.1'
# Row 14955 failed: 'KI270871.1'
# Row 14956 failed: 'KI270871.1'
# Row 14957 failed: 'KI270871.1'
# Row 14958 failed: 'KI270871.1'
# Row 14959 failed: 'KI270871.1'
# Row 14960 failed: 'KI270871.1'
# Row 14961 failed: 'KI270871.1'
# Row 14962 failed: 'KI270871.1'
# Row 14963 failed: 'KI270871.1'
# Row 14964 failed: 'KI270871.1'
# Row 14965 failed: 'KI270871.1'
# Row 14966 failed: 'KI270871.1'
# Row 14967 failed: 'KI270871.1'
# Row 14968 failed: 'KI270871.1'
# Row 14969 failed: 'KI270871.1'
# Row 14970 failed: 'KI270871.1'
# Row 14971 failed: 'KI270871.1'
# Row 14972 failed: 'KI270871.1'
# Row 14973 failed: 'KI270871.1'
# Row 14974 failed: 'KI270871.1'
# Row 14975 failed: 'KI270871.1'
# Row 14976 failed: 'KI270871.1'
# Row 14977 failed: 'KI270871.1'
# Row 14978 failed: 'KI270871.1'
# Row 14979 failed: 'KI270871.1'
# Row 14980 failed: 'KI270871.1'
# Row 14981 failed: 'KI270871.1'
# Row 14982 failed: 'KI270871.1'
# Row 14983 failed: 'KI270871.1'
# Row 14984 failed: 'KI270871.1'
# Row 14985 failed: 'KI270871.1'
# Row 14986 failed: 'KI270871.1'
# Row 14987 failed: 'KI270871.1'
# Row 14988 failed: 'KI270871.1'
# Row 14989 failed: 'KI270871.1'
# Row 14990 failed: 'KI270871.1'
# Row 14991 failed: 'KI270871.1'
# Row 14992 failed: 'KI270871.1'
# Row 14993 failed: 'KI270871.1'
# Row 14994 failed: 'KI270871.1'
# Row 14995 failed: 'KI270871.1'
# Row 14996 failed: 'KI270871.1'
# Row 14997 failed: 'KI270871.1'
# Row 14998 failed: 'KI270871.1'
# Row 14999 failed: 'KI270871.1'
# Row 15000 failed: 'KI270871.1'
# Row 15001 failed: 'KI270871.1'
# Row 15002 failed: 'KI270871.1'
# Row 15003 failed: 'KI270871.1'
# Row 15004 failed: 'KI270871.1'
# Row 15005 failed: 'KI270871.1'
# Row 15006 failed: 'KI270871.1'
# Row 15007 failed: 'KI270871.1'
# Row 15008 failed: 'KI270871.1'
# Row 15009 failed: 'KI270871.1'
# Row 15010 failed: 'KI270871.1'
# Row 15011 failed: 'KI270871.1'
# Row 15012 failed: 'KI270871.1'
# Row 15013 failed: 'KI270871.1'
# Row 15014 failed: 'KI270871.1'
# Row 15015 failed: 'KI270871.1'
# Row 15016 failed: 'KI270871.1'
# Row 15017 failed: 'KI270871.1'
# Row 15018 failed: 'KI270871.1'
# Row 15019 failed: 'KI270871.1'
# Row 15020 failed: 'KI270871.1'
# Row 15021 failed: 'KI270871.1'
# Row 15022 failed: 'KI270871.1'
# Row 15023 failed: 'KI270871.1'
# Row 15024 failed: 'KI270871.1'
# Row 15025 failed: 'KI270871.1'
# Row 15026 failed: 'KI270871.1'
# Row 15027 failed: 'KI270871.1'
# Row 15028 failed: 'KI270871.1'
# Row 15029 failed: 'KI270871.1'
# Row 15030 failed: 'KI270871.1'
# Row 15031 failed: 'KI270871.1'
# Row 15032 failed: 'KI270871.1'
# Row 15033 failed: 'KI270871.1'
# Row 15034 failed: 'KI270871.1'
# Row 15035 failed: 'KI270871.1'
# Row 15036 failed: 'KI270871.1'
# Row 15037 failed: 'KI270871.1'
# Row 15038 failed: 'KI270871.1'
# Row 15039 failed: 'KI270871.1'
# Row 15040 failed: 'KI270871.1'
# Row 15041 failed: 'KI270871.1'
# Row 15042 failed: 'KI270871.1'
# Row 15043 failed: 'KI270871.1'
# Row 15044 failed: 'KI270871.1'
# Row 15045 failed: 'KI270871.1'
# Row 15046 failed: 'KI270871.1'
# Row 15047 failed: 'KI270871.1'
# Row 15048 failed: 'KI270871.1'
# Row 15049 failed: 'KI270871.1'
# Row 15050 failed: 'KI270871.1'
# Row 15051 failed: 'KI270871.1'
# Row 15052 failed: 'KI270871.1'
# Row 15053 failed: 'KI270871.1'
# Row 15054 failed: 'KI270871.1'
# Row 15055 failed: 'KI270871.1'
# Row 15056 failed: 'KI270871.1'
# Row 15057 failed: 'KI270871.1'
# Row 15058 failed: 'KI270871.1'
# Row 15059 failed: 'KI270871.1'
# Row 15060 failed: 'KI270871.1'
# Row 15061 failed: 'KI270871.1'
# Row 15062 failed: 'KI270871.1'
# Row 15063 failed: 'KI270871.1'
# Row 15064 failed: 'KI270871.1'
# Row 15065 failed: 'KI270871.1'
# Row 15066 failed: 'KI270871.1'
# Row 15067 failed: 'KI270871.1'
# Row 15068 failed: 'KI270871.1'
# Row 15069 failed: 'KI270871.1'
# Row 15070 failed: 'KI270871.1'
# Row 15071 failed: 'KI270871.1'
# Row 15072 failed: 'KI270871.1'
# Row 15073 failed: 'KI270871.1'
# Row 15074 failed: 'KI270871.1'
# Row 15075 failed: 'KI270871.1'
# Row 15076 failed: 'KI270871.1'
# Row 15077 failed: 'KI270871.1'
# Row 15078 failed: 'KI270871.1'
# Row 15079 failed: 'KI270871.1'
# Row 15080 failed: 'KI270871.1'
# Row 15081 failed: 'KI270871.1'
# Row 15082 failed: 'KI270871.1'
# Row 15083 failed: 'KI270871.1'
# Row 15084 failed: 'KI270871.1'
# Row 15085 failed: 'KI270871.1'
# Row 15086 failed: 'KI270871.1'
# Row 15087 failed: 'KI270871.1'
# Row 15088 failed: 'KI270871.1'
# Row 15089 failed: 'KI270871.1'
# Row 15090 failed: 'KI270871.1'
# Row 15091 failed: 'KI270871.1'
# Row 15092 failed: 'KI270871.1'
# Row 15093 failed: 'KI270871.1'
# Row 15094 failed: 'KI270871.1'
# Row 15095 failed: 'KI270871.1'
# Row 15096 failed: 'KI270871.1'
# Row 15097 failed: 'KI270871.1'
# Row 15098 failed: 'KI270871.1'
# Row 15099 failed: 'KI270871.1'
# Row 15100 failed: 'KI270871.1'
# Row 15101 failed: 'KI270871.1'
# Row 15102 failed: 'KI270871.1'
# Row 15103 failed: 'KI270871.1'
# Row 15104 failed: 'KI270871.1'
# Row 15105 failed: 'KI270871.1'
# Row 15106 failed: 'KI270871.1'
# Row 15107 failed: 'KI270871.1'
# Row 15108 failed: 'KI270871.1'
# Row 15109 failed: 'KI270871.1'
# Row 15110 failed: 'KI270871.1'
# Row 15111 failed: 'KI270871.1'
# Row 15112 failed: 'KI270871.1'
# Row 15113 failed: 'KI270871.1'
# Row 15114 failed: 'KI270871.1'
# Row 15115 failed: 'KI270871.1'
# Row 15116 failed: 'KI270871.1'
# Row 15117 failed: 'KI270871.1'
# Row 15118 failed: 'KI270871.1'
# Row 15119 failed: 'KI270871.1'
# Row 15120 failed: 'KI270871.1'
# Row 15121 failed: 'KI270871.1'
# Row 15122 failed: 'KI270871.1'
# Row 15123 failed: 'KI270871.1'
# Row 15124 failed: 'KI270871.1'
# Row 15125 failed: 'KI270871.1'
# Row 15126 failed: 'KI270871.1'
# Row 15127 failed: 'KI270871.1'
# Row 15128 failed: 'KI270871.1'
# Row 15129 failed: 'KI270871.1'
# Row 15130 failed: 'KI270871.1'
# Row 15131 failed: 'KI270871.1'
# Row 15132 failed: 'KI270871.1'
# Row 15133 failed: 'KI270871.1'
# Row 15134 failed: 'KI270871.1'
# Row 15135 failed: 'KI270871.1'
# Row 15136 failed: 'KI270871.1'
# Row 15137 failed: 'KI270871.1'
# Row 15138 failed: 'KI270871.1'
# Row 15139 failed: 'KI270871.1'
# Row 15140 failed: 'KI270871.1'
# Row 15141 failed: 'KI270871.1'
# Row 15142 failed: 'KI270871.1'
# Row 15143 failed: 'KI270871.1'
# Row 15144 failed: 'KI270871.1'
# Row 15145 failed: 'KI270871.1'
# Row 15146 failed: 'KI270871.1'
# Row 15147 failed: 'KI270871.1'
# Row 15148 failed: 'KI270871.1'
# Row 15149 failed: 'KI270871.1'
# Row 15150 failed: 'KI270871.1'
# Row 15151 failed: 'KI270871.1'
# Row 15152 failed: 'KI270871.1'
# Row 15153 failed: 'KI270871.1'
# Row 15154 failed: 'KI270871.1'
# Row 15155 failed: 'KI270871.1'
# Row 15156 failed: 'KI270871.1'
# Row 15157 failed: 'KI270871.1'
# Row 15158 failed: 'KI270871.1'
# Row 15159 failed: 'KI270871.1'
# Row 15160 failed: 'KI270871.1'
# Row 15161 failed: 'KI270871.1'
# Row 15162 failed: 'KI270871.1'
# Row 15163 failed: 'KI270871.1'
# Row 15164 failed: 'KI270871.1'
# Row 15165 failed: 'KI270871.1'
# Row 15166 failed: 'KI270871.1'
# Row 15167 failed: 'KI270871.1'
# Row 15168 failed: 'KI270871.1'
# Row 15169 failed: 'KI270871.1'
# Row 15170 failed: 'KI270871.1'
# Row 15171 failed: 'KI270871.1'
# Row 15172 failed: 'KI270871.1'
# Row 15173 failed: 'KI270871.1'
# Row 15174 failed: 'KI270871.1'
# Row 15175 failed: 'KI270871.1'
# Row 15176 failed: 'KI270871.1'
# Row 15177 failed: 'KI270871.1'
# Row 15178 failed: 'KI270871.1'
# Row 15179 failed: 'KI270871.1'
# Row 15180 failed: 'KI270871.1'
# Row 15181 failed: 'KI270871.1'
# Row 15182 failed: 'KI270871.1'
# Row 15183 failed: 'KI270871.1'
# Row 15184 failed: 'KI270871.1'
# Row 15185 failed: 'KI270871.1'
# Row 15186 failed: 'KI270871.1'
# Row 15187 failed: 'KI270871.1'
# Row 15188 failed: 'KI270871.1'
# Row 15189 failed: 'KI270871.1'
# Row 15190 failed: 'KI270871.1'
# Row 15191 failed: 'KI270871.1'
# Row 15192 failed: 'KI270871.1'
# Row 15193 failed: 'KI270871.1'
# Row 15194 failed: 'KI270871.1'
# Row 15195 failed: 'KI270871.1'
# Row 15196 failed: 'KI270871.1'
# Row 15197 failed: 'KI270871.1'
# Row 15198 failed: 'KI270871.1'
# Row 15199 failed: 'KI270871.1'
# Row 15200 failed: 'KI270871.1'
# Row 15201 failed: 'KI270871.1'
# Row 15202 failed: 'KI270871.1'
# Row 15203 failed: 'KI270871.1'
# Row 15204 failed: 'KI270871.1'
# Row 15205 failed: 'KI270871.1'
# Row 15206 failed: 'KI270871.1'
# Row 15207 failed: 'KI270871.1'
# Row 15208 failed: 'KI270871.1'
# Row 15209 failed: 'KI270871.1'
# Row 15210 failed: 'KI270871.1'
# Row 15211 failed: 'KI270871.1'
# Row 15212 failed: 'KI270871.1'
# Row 15213 failed: 'KI270871.1'
# Row 15214 failed: 'KI270871.1'
# Row 15215 failed: 'KI270871.1'
# Row 15216 failed: 'KI270871.1'
# Row 15217 failed: 'KI270871.1'
# Row 15218 failed: 'KI270871.1'
# Row 15219 failed: 'KI270871.1'
# Row 15220 failed: 'KI270871.1'
# Row 15221 failed: 'KI270871.1'
# Row 15222 failed: 'KI270871.1'
# Row 15223 failed: 'KI270871.1'
# Row 15224 failed: 'KI270871.1'
# Row 15225 failed: 'KI270871.1'
# Row 15226 failed: 'KI270871.1'
# Row 15227 failed: 'KI270871.1'
# Row 15228 failed: 'KI270871.1'
# Row 15229 failed: 'KI270871.1'
# Row 15230 failed: 'KI270871.1'
# Row 15231 failed: 'KI270871.1'
# Row 15232 failed: 'KI270871.1'
# Row 15233 failed: 'KI270871.1'
# Row 15234 failed: 'KI270871.1'
# Row 15235 failed: 'KI270871.1'
# Row 15236 failed: 'KI270871.1'
# Row 15237 failed: 'KI270871.1'
# Row 15238 failed: 'KI270871.1'
# Row 15239 failed: 'KI270871.1'
# Row 15240 failed: 'KI270871.1'
# Row 15241 failed: 'KI270871.1'
# Row 15242 failed: 'KI270871.1'
# Row 15243 failed: 'KI270871.1'
# Row 15244 failed: 'KI270871.1'
# Row 15245 failed: 'KI270871.1'
# Row 15246 failed: 'KI270871.1'
# Row 15247 failed: 'KI270871.1'
# Row 15248 failed: 'KI270871.1'
# Row 15249 failed: 'KI270871.1'
# Row 15250 failed: 'KI270871.1'
# Row 15251 failed: 'KI270871.1'
# Row 15252 failed: 'KI270871.1'
# Row 15253 failed: 'KI270871.1'
# Row 15254 failed: 'KI270871.1'
# Row 15255 failed: 'KI270871.1'
# Row 15256 failed: 'KI270871.1'
# Row 15257 failed: 'KI270871.1'
# Row 15258 failed: 'KI270871.1'
# Row 15259 failed: 'KI270871.1'
# Row 15260 failed: 'KI270871.1'
# Row 15261 failed: 'KI270871.1'
# Row 15262 failed: 'KI270871.1'
# Row 15263 failed: 'KI270871.1'
# Row 15264 failed: 'KI270871.1'
# Row 15265 failed: 'KI270871.1'
# Row 15266 failed: 'KI270871.1'
# Row 15267 failed: 'KI270871.1'
# Row 15268 failed: 'KI270871.1'
# Row 15269 failed: 'KI270871.1'
# Row 15270 failed: 'KI270871.1'
# Row 15271 failed: 'KI270871.1'
# Row 15272 failed: 'KI270871.1'
# Row 15273 failed: 'KI270871.1'
# Row 15274 failed: 'KI270871.1'
# Row 15275 failed: 'KI270871.1'
# Row 15276 failed: 'KI270871.1'
# Row 15277 failed: 'KI270871.1'
# Row 15278 failed: 'KI270871.1'
# Row 15279 failed: 'KI270871.1'
# Row 15280 failed: 'KI270871.1'
# Row 15281 failed: 'KI270871.1'
# Row 15282 failed: 'KI270871.1'
# Row 15283 failed: 'KI270871.1'
# Row 15284 failed: 'KI270871.1'
# Row 15285 failed: 'KI270871.1'
# Row 15286 failed: 'KI270871.1'
# Row 15287 failed: 'KI270871.1'
# Row 15288 failed: 'KI270871.1'
# Row 15289 failed: 'KI270871.1'
# Row 15290 failed: 'KI270871.1'
# Row 15291 failed: 'KI270871.1'
# Row 15292 failed: 'KI270871.1'
# Row 15293 failed: 'KI270871.1'
# Row 15294 failed: 'KI270871.1'
# Row 15295 failed: 'KI270871.1'
# Row 15296 failed: 'KI270871.1'
# Row 15297 failed: 'KI270871.1'
# Row 15298 failed: 'KI270871.1'
# Row 15299 failed: 'KI270871.1'
# Row 15300 failed: 'KI270871.1'
# Row 15301 failed: 'KI270871.1'
# Row 15302 failed: 'KI270871.1'
# Row 15303 failed: 'KI270871.1'
# Row 15304 failed: 'KI270871.1'
# Row 15305 failed: 'KI270871.1'
# Row 15306 failed: 'KI270871.1'
# Row 15307 failed: 'KI270871.1'
# Row 15308 failed: 'KI270871.1'
# Row 15309 failed: 'KI270871.1'
# Row 15310 failed: 'KI270871.1'
# Row 15311 failed: 'KI270871.1'
# Row 15312 failed: 'KI270871.1'
# Row 15313 failed: 'KI270871.1'
# Row 15314 failed: 'KI270871.1'
# Row 15315 failed: 'KI270871.1'
# Row 15316 failed: 'KI270871.1'
# Row 15317 failed: 'KI270871.1'
# Row 15318 failed: 'KI270871.1'
# Row 15319 failed: 'KI270871.1'
# Row 15320 failed: 'KI270871.1'
# Row 15321 failed: 'KI270871.1'
# Row 15322 failed: 'KI270871.1'
# Row 15323 failed: 'KI270871.1'
# Row 15324 failed: 'KI270871.1'
# Row 15325 failed: 'KI270871.1'
# Row 15326 failed: 'KI270871.1'
# Row 15327 failed: 'KI270871.1'
# Row 15328 failed: 'KI270871.1'
# Row 15329 failed: 'KI270871.1'
# Row 15330 failed: 'KI270871.1'
# Row 15331 failed: 'KI270871.1'
# Row 15332 failed: 'KI270871.1'
# Row 15333 failed: 'KI270871.1'
# Row 15334 failed: 'KI270871.1'
# Row 15335 failed: 'KI270871.1'
# Row 15336 failed: 'KI270871.1'
# Row 15337 failed: 'KI270871.1'
# Row 15338 failed: 'KI270871.1'
# Row 15339 failed: 'KI270871.1'
# Row 15340 failed: 'KI270871.1'
# Row 15341 failed: 'KI270871.1'
# Row 15342 failed: 'KI270871.1'
# Row 15343 failed: 'KI270871.1'
# Row 15344 failed: 'KI270871.1'
# Row 15345 failed: 'KI270871.1'
# Row 15346 failed: 'KI270871.1'
# Row 15347 failed: 'KI270871.1'
# Row 15348 failed: 'KI270871.1'
# Row 15349 failed: 'KI270871.1'
# Row 15350 failed: 'KI270871.1'
# Row 15351 failed: 'KI270871.1'
# Row 15352 failed: 'KI270871.1'
# Row 15353 failed: 'KI270871.1'
# Row 15354 failed: 'KI270871.1'
# Row 15355 failed: 'KI270871.1'
# Row 15356 failed: 'KI270871.1'
# Row 15357 failed: 'KI270871.1'
# Row 16098 failed: 'KQ983257.1'
# Row 16099 failed: 'KQ983257.1'
# Row 16100 failed: 'KQ983257.1'
# Row 16101 failed: 'KQ983257.1'
# Row 16102 failed: 'KQ983257.1'
# Row 16103 failed: 'KQ983257.1'
# Row 16104 failed: 'KQ983257.1'
# Row 16105 failed: 'KQ983257.1'
# Row 16106 failed: 'KQ983257.1'
# Row 16107 failed: 'KQ983257.1'
# Row 16108 failed: 'KQ983257.1'
# Row 16109 failed: 'KQ983257.1'
# Row 16110 failed: 'KQ983257.1'
# Row 16111 failed: 'KQ983257.1'
# Row 16112 failed: 'KQ983257.1'
# Row 16825 failed: 'GL000256.2'
# Row 16826 failed: 'GL000256.2'
# Row 16827 failed: 'GL000256.2'
# Row 16828 failed: 'GL000256.2'
# Row 16829 failed: 'GL000256.2'
# Row 16830 failed: 'GL000256.2'
# Row 16831 failed: 'GL000256.2'
# Row 16832 failed: 'GL000256.2'
# Row 16833 failed: 'GL000256.2'
# Row 16834 failed: 'GL000256.2'
# Row 16835 failed: 'GL000256.2'
# Row 16836 failed: 'GL000256.2'
# Row 16837 failed: 'GL000256.2'
# Row 16838 failed: 'GL000256.2'
# Row 16839 failed: 'GL000256.2'
# Row 16840 failed: 'GL000256.2'
# Row 16841 failed: 'GL000256.2'
# Row 16842 failed: 'GL000256.2'
# Row 16843 failed: 'GL000256.2'
# Row 16844 failed: 'GL000256.2'
# Row 16845 failed: 'GL000256.2'
# Row 16846 failed: 'GL000256.2'
# Row 16847 failed: 'GL000256.2'
# Row 16848 failed: 'GL000256.2'
# Row 16849 failed: 'GL000256.2'
# Row 16850 failed: 'GL000256.2'
# Row 16851 failed: 'GL000256.2'
# Row 16852 failed: 'GL000256.2'
# Row 16853 failed: 'GL000256.2'
# Row 16854 failed: 'GL000256.2'
# Row 16855 failed: 'GL000256.2'
# Row 16856 failed: 'GL000256.2'
# Row 16857 failed: 'GL000256.2'
# Row 16858 failed: 'GL000256.2'
# Row 16859 failed: 'GL000256.2'
# Row 16860 failed: 'GL000256.2'
# Row 16861 failed: 'GL000256.2'
# Row 16862 failed: 'GL000256.2'
# Row 16863 failed: 'GL000256.2'
# Row 16864 failed: 'GL000256.2'
# Row 16865 failed: 'GL000256.2'
# Row 16866 failed: 'GL000256.2'
# Row 16867 failed: 'GL000256.2'
# Row 16868 failed: 'GL000256.2'
# Row 16869 failed: 'GL000256.2'
# Row 16870 failed: 'GL000256.2'
# Row 16871 failed: 'GL000256.2'
# Row 16872 failed: 'GL000256.2'
# Row 16873 failed: 'GL000256.2'
# Row 16874 failed: 'GL000256.2'
# Row 16875 failed: 'GL000256.2'
# Row 16876 failed: 'GL000256.2'
# Row 16877 failed: 'GL000256.2'
# Row 16878 failed: 'GL000256.2'
# Row 16879 failed: 'GL000256.2'
# Row 16880 failed: 'GL000256.2'
# Row 16881 failed: 'GL000256.2'
# Row 16882 failed: 'GL000256.2'
# Row 16883 failed: 'GL000256.2'
# Row 16884 failed: 'GL000256.2'
# Row 16885 failed: 'GL000256.2'
# Row 16886 failed: 'GL000256.2'
# Row 16887 failed: 'GL000256.2'
# Row 16888 failed: 'GL000256.2'
# Row 16889 failed: 'GL000256.2'
# Row 16890 failed: 'GL000256.2'
# Row 16891 failed: 'GL000256.2'
# Row 16892 failed: 'GL000256.2'
# Row 16893 failed: 'GL000256.2'
# Row 16894 failed: 'GL000256.2'
# Row 16895 failed: 'GL000256.2'
# Row 16896 failed: 'GL000256.2'
# Row 16897 failed: 'GL000256.2'
# Row 16898 failed: 'GL000256.2'
# Row 16899 failed: 'GL000256.2'
# Row 16900 failed: 'GL000256.2'
# Row 16901 failed: 'GL000256.2'
# Row 16902 failed: 'GL000256.2'
# Row 17215 failed: 'KQ983257.1'
# Row 17216 failed: 'KQ983257.1'
# Row 17217 failed: 'KQ983257.1'
# Row 17218 failed: 'KQ983257.1'
# Row 17219 failed: 'KQ983257.1'
# Row 17220 failed: 'KQ983257.1'
# Row 17221 failed: 'KQ983257.1'
# Row 17222 failed: 'KQ983257.1'
# Row 17223 failed: 'KQ983257.1'
# Row 17224 failed: 'KQ983257.1'
# Row 17225 failed: 'KQ983257.1'
# Row 17226 failed: 'KQ983257.1'
# Row 17227 failed: 'KQ983257.1'
# Row 17228 failed: 'KQ983257.1'
# Row 17229 failed: 'KQ983257.1'
# Row 17230 failed: 'KQ983257.1'
# Row 17231 failed: 'KQ983257.1'
# Row 17232 failed: 'KQ983257.1'
# Row 17233 failed: 'KQ983257.1'
# Row 17234 failed: 'KQ983257.1'
# Row 17235 failed: 'KQ983257.1'
# Row 17236 failed: 'KQ983257.1'
# Row 17237 failed: 'KQ983257.1'
# Row 17238 failed: 'KQ983257.1'
# Row 17239 failed: 'KQ983257.1'
# Row 17240 failed: 'KQ983257.1'
# Row 17241 failed: 'KQ983257.1'
# Row 17242 failed: 'KQ983257.1'
# Row 17243 failed: 'KQ983257.1'
# Row 17244 failed: 'KQ983257.1'
# Row 17245 failed: 'KQ983257.1'
# Row 17246 failed: 'KQ983257.1'
# Row 17247 failed: 'KQ983257.1'
# Row 17248 failed: 'KQ983257.1'
# Row 17249 failed: 'KQ983257.1'
# Row 17250 failed: 'KQ983257.1'
# Row 17251 failed: 'KQ983257.1'
# Row 17252 failed: 'KQ983257.1'
# Row 17253 failed: 'KQ983257.1'
# Row 17254 failed: 'KQ983257.1'
# Row 17255 failed: 'KQ983257.1'
# Row 17256 failed: 'KQ983257.1'
# Row 17257 failed: 'KQ983257.1'
# Row 17258 failed: 'KQ983257.1'
# Row 17259 failed: 'KQ983257.1'
# Row 17260 failed: 'KQ983257.1'
# Row 17261 failed: 'KQ983257.1'
# Row 17262 failed: 'KQ983257.1'
# Row 17263 failed: 'KQ983257.1'
# Row 17264 failed: 'KQ983257.1'
# Row 17265 failed: 'KQ983257.1'
# Row 17266 failed: 'KQ983257.1'
# Row 17267 failed: 'KQ983257.1'
# Row 17268 failed: 'KQ983257.1'
# Row 17269 failed: 'KQ983257.1'
# Row 17270 failed: 'KQ983257.1'
# Row 17271 failed: 'KQ983257.1'
# Row 17272 failed: 'KQ983257.1'
# Row 17273 failed: 'KQ983257.1'
# Row 17274 failed: 'KQ983257.1'
# Row 17275 failed: 'KQ983257.1'
# Row 17276 failed: 'KQ983257.1'
# Row 17277 failed: 'KQ983257.1'
# Row 17278 failed: 'KQ983257.1'
# Row 17279 failed: 'KQ983257.1'
# Row 17280 failed: 'KQ983257.1'
# Row 17281 failed: 'KQ983257.1'
# Row 17282 failed: 'KQ983257.1'
# Row 17283 failed: 'KQ983257.1'
# Row 17284 failed: 'KQ983257.1'
# Row 17285 failed: 'KQ983257.1'
# Row 17286 failed: 'KQ983257.1'
# Row 17287 failed: 'KQ983257.1'
# Row 17288 failed: 'KQ983257.1'
# Row 17289 failed: 'KQ983257.1'
# Row 17290 failed: 'KQ983257.1'
# Row 17291 failed: 'KQ983257.1'
# Row 17292 failed: 'KQ983257.1'
# Row 17293 failed: 'KQ983257.1'
# Row 17294 failed: 'KQ983257.1'
# Row 17295 failed: 'KQ983257.1'
# Row 17296 failed: 'KQ983257.1'
# Row 17297 failed: 'KQ983257.1'
# Row 17298 failed: 'KQ983257.1'
# Row 17299 failed: 'KQ983257.1'
# Row 17300 failed: 'KQ983257.1'
# Row 17301 failed: 'KQ983257.1'
# Row 17302 failed: 'KQ983257.1'
# Row 17303 failed: 'KQ983257.1'
# Row 17304 failed: 'KQ983257.1'
# Row 17305 failed: 'KQ983257.1'
# Row 17306 failed: 'KQ983257.1'
# Row 17307 failed: 'KQ983257.1'
# Row 17308 failed: 'KQ983257.1'
# Row 17309 failed: 'KQ983257.1'
# Row 17310 failed: 'KQ983257.1'
# Row 17311 failed: 'KQ983257.1'
# Row 17312 failed: 'KQ983257.1'
# Row 17313 failed: 'KQ983257.1'
# Row 17314 failed: 'KQ983257.1'
# Row 17315 failed: 'KQ983257.1'
# Row 17316 failed: 'KQ983257.1'
# Row 17317 failed: 'KQ983257.1'
# Row 17318 failed: 'KQ983257.1'
# Row 17319 failed: 'KQ983257.1'
# Row 17320 failed: 'KQ983257.1'
# ...
# Row 153277 failed: 'KI270908.1'
# Row 153278 failed: 'KI270908.1'
# Row 153279 failed: 'KI270908.1'
# Row 153280 failed: 'KI270908.1'
# Row 153281 failed: 'KI270908.1'
# Row 153282 failed: 'KI270908.1'
# Row 153283 failed: 'KI270908.1'
# Row 153284 failed: 'KI270908.1'
# Row 153285 failed: 'KI270908.1'
# Row 153286 failed: 'KI270908.1'
# Row 153287 failed: 'KI270908.1'
# Row 153288 failed: 'KI270908.1'
# Row 153289 failed: 'KI270908.1'
# Row 153290 failed: 'KI270908.1'
# Row 153291 failed: 'KI270908.1'
# Row 153292 failed: 'KI270908.1'
# Row 154378 failed: 'KI270908.1'
# Row 154379 failed: 'KI270908.1'
# Row 154380 failed: 'KI270908.1'
# Row 154381 failed: 'KI270908.1'
# Row 154382 failed: 'KI270908.1'
# Row 154383 failed: 'KI270908.1'
# Row 154384 failed: 'KI270908.1'
# Row 154385 failed: 'KI270908.1'
# Row 154386 failed: 'KI270908.1'
# Row 154387 failed: 'KI270908.1'
# Row 154388 failed: 'KI270908.1'
# Row 154389 failed: 'KI270908.1'
# Row 154390 failed: 'KI270908.1'
# Row 154391 failed: 'KI270908.1'
# Row 154392 failed: 'KI270908.1'
# Row 154393 failed: 'KI270908.1'
# Row 154394 failed: 'KI270908.1'
# Row 154395 failed: 'KI270908.1'
# Row 154396 failed: 'KI270908.1'
# Row 154397 failed: 'KI270908.1'
# Row 154398 failed: 'KI270908.1'
# Row 154399 failed: 'KI270908.1'
# Row 154400 failed: 'KI270908.1'
# Row 154401 failed: 'KI270908.1'
# Row 154402 failed: 'KI270908.1'
# Row 154403 failed: 'KI270908.1'
# Row 154404 failed: 'KI270908.1'
# Row 154405 failed: 'KI270908.1'
# Row 154406 failed: 'KI270908.1'
# Row 154407 failed: 'KI270908.1'
# Row 154408 failed: 'KI270908.1'
# Row 154409 failed: 'KI270908.1'
# Row 154410 failed: 'KI270908.1'
# Row 154411 failed: 'KI270908.1'
# Row 154412 failed: 'KI270908.1'
# Row 154413 failed: 'KI270908.1'
# Row 154414 failed: 'KI270908.1'
# Row 154415 failed: 'KI270908.1'
# Row 154416 failed: 'KI270908.1'
# Row 154417 failed: 'KI270908.1'
# Row 154418 failed: 'KI270908.1'
# Row 154419 failed: 'KI270908.1'
# Row 154420 failed: 'KI270908.1'
# Row 154421 failed: 'KI270908.1'
# Row 154422 failed: 'KI270908.1'
# Row 154423 failed: 'KI270908.1'
# Row 154424 failed: 'KI270908.1'
# Row 154425 failed: 'KI270908.1'
# Row 154426 failed: 'KI270908.1'
# Row 154427 failed: 'KI270908.1'
# Row 154428 failed: 'KI270908.1'
# Row 154429 failed: 'KI270908.1'
# Row 154430 failed: 'KI270908.1'
# Row 154431 failed: 'KI270908.1'
# Row 154432 failed: 'KI270908.1'
# Row 154433 failed: 'KI270908.1'
# Row 154434 failed: 'KI270908.1'
# Row 154435 failed: 'KI270908.1'
# Row 154436 failed: 'KI270908.1'
# Row 154437 failed: 'KI270908.1'
# Row 154438 failed: 'KI270908.1'
# Row 154439 failed: 'KI270908.1'
# Row 154440 failed: 'KI270908.1'
# Row 154441 failed: 'KI270908.1'
# Row 154442 failed: 'KI270908.1'
# Row 154443 failed: 'KI270908.1'
# Row 154444 failed: 'KI270908.1'
# Row 154445 failed: 'KI270908.1'
# Row 154446 failed: 'KI270908.1'
# Row 154447 failed: 'KI270908.1'
# Row 154448 failed: 'KI270908.1'
# Row 154449 failed: 'KI270908.1'
# Row 154450 failed: 'KI270908.1'
# Row 154451 failed: 'KI270908.1'
# Row 154452 failed: 'KI270908.1'
# Row 154453 failed: 'KI270908.1'
# Row 154454 failed: 'KI270908.1'
# Row 154455 failed: 'KI270908.1'
# Row 154456 failed: 'KI270908.1'
# Row 160833 failed: 'KQ983257.1'
# Row 160834 failed: 'KQ983257.1'
# Row 160835 failed: 'KQ983257.1'
# Row 160836 failed: 'KQ983257.1'
# Row 163294 failed: 'KI270908.1'
# Row 163295 failed: 'KI270908.1'
# Row 163296 failed: 'KI270908.1'
# Row 163297 failed: 'KI270908.1'
# Row 163298 failed: 'KI270908.1'
# Row 163299 failed: 'KI270908.1'
# Row 163300 failed: 'KI270908.1'
# Row 163301 failed: 'KI270908.1'
# Row 163302 failed: 'KI270908.1'
# Row 163303 failed: 'KI270908.1'
# Row 163304 failed: 'KI270908.1'
# Row 163305 failed: 'KI270908.1'
# Row 163306 failed: 'KI270908.1'
# Row 163307 failed: 'KI270908.1'
# Row 163308 failed: 'KI270908.1'
# Row 163309 failed: 'KI270908.1'
# Row 163310 failed: 'KI270908.1'
# Row 163311 failed: 'KI270908.1'
# Row 163312 failed: 'KI270908.1'
# Row 163313 failed: 'KI270908.1'
# Row 163314 failed: 'KI270908.1'
# Row 163315 failed: 'KI270908.1'
# Row 163316 failed: 'KI270908.1'
# Row 163317 failed: 'KI270908.1'
# Row 163318 failed: 'KI270908.1'
# Row 163319 failed: 'KI270908.1'
# Row 163320 failed: 'KI270908.1'
# Row 163321 failed: 'KI270908.1'
# Row 163322 failed: 'KI270908.1'
# Row 163323 failed: 'KI270908.1'
# Row 163324 failed: 'KI270908.1'
# Row 163325 failed: 'KI270908.1'
# Row 163326 failed: 'KI270908.1'
# Row 163327 failed: 'KI270908.1'
# Row 163328 failed: 'KI270908.1'
# Row 163329 failed: 'KI270908.1'
# Row 163330 failed: 'KI270908.1'
# Row 163331 failed: 'KI270908.1'
# Row 163332 failed: 'KI270908.1'
# Row 163333 failed: 'KI270908.1'
# Row 163334 failed: 'KI270908.1'
# Row 163335 failed: 'KI270908.1'
# Row 163336 failed: 'KI270908.1'
# Row 163337 failed: 'KI270908.1'
# Row 163338 failed: 'KI270908.1'
# Row 163339 failed: 'KI270908.1'
# Row 163340 failed: 'KI270908.1'
# Row 163341 failed: 'KI270908.1'
# Row 163342 failed: 'KI270908.1'
# Row 163343 failed: 'KI270908.1'
# Row 163344 failed: 'KI270908.1'
# Row 163345 failed: 'KI270908.1'
# Row 163346 failed: 'KI270908.1'
# Row 163347 failed: 'KI270908.1'
# Row 163348 failed: 'KI270908.1'
# Row 163349 failed: 'KI270908.1'
# Row 163350 failed: 'KI270908.1'
# Row 163351 failed: 'KI270908.1'
# Row 163352 failed: 'KI270908.1'
# Row 163353 failed: 'KI270908.1'
# Row 163354 failed: 'KI270908.1'
# Row 163355 failed: 'KI270908.1'
# Row 163356 failed: 'KI270908.1'
# Row 163357 failed: 'KI270908.1'
# Row 163358 failed: 'KI270908.1'
# Row 163359 failed: 'KI270908.1'
# Row 163360 failed: 'KI270908.1'
# Row 163361 failed: 'KI270908.1'
# Row 163362 failed: 'KI270908.1'
# Row 163363 failed: 'KI270908.1'
# Row 163364 failed: 'KI270908.1'
# Row 163365 failed: 'KI270908.1'
# Row 163366 failed: 'KI270908.1'
# Row 163367 failed: 'KI270908.1'
# Row 163368 failed: 'KI270908.1'
# Row 163369 failed: 'KI270908.1'
# Row 163370 failed: 'KI270908.1'
# Row 163371 failed: 'KI270908.1'
# Row 163372 failed: 'KI270908.1'
# Row 166412 failed: 'GL000256.2'
# Row 166413 failed: 'GL000256.2'
# Row 166414 failed: 'GL000256.2'
# Row 166415 failed: 'GL000256.2'
# Row 166416 failed: 'GL000256.2'
# Row 166417 failed: 'GL000256.2'
# Row 166418 failed: 'GL000256.2'
# Row 166419 failed: 'GL000256.2'
# Row 166420 failed: 'GL000256.2'
# Row 166421 failed: 'GL000256.2'
# Row 166422 failed: 'GL000256.2'
# Row 166423 failed: 'GL000256.2'
# Row 166424 failed: 'GL000256.2'
# Row 166425 failed: 'GL000256.2'
# Row 166426 failed: 'GL000256.2'
# Row 166427 failed: 'GL000256.2'
# Row 166428 failed: 'GL000256.2'
# Row 166429 failed: 'GL000256.2'
# Row 166430 failed: 'GL000256.2'
# Row 166431 failed: 'GL000256.2'
# Row 166432 failed: 'GL000256.2'
# Row 166433 failed: 'GL000256.2'
# Row 166434 failed: 'GL000256.2'
# Row 166435 failed: 'GL000256.2'
# Row 166436 failed: 'GL000256.2'
# Row 166437 failed: 'GL000256.2'
# Row 166438 failed: 'GL000256.2'
# Row 166439 failed: 'GL000256.2'
# Row 166440 failed: 'GL000256.2'
# Row 166441 failed: 'GL000256.2'
# Row 166442 failed: 'GL000256.2'
# Row 166443 failed: 'GL000256.2'
# Row 166444 failed: 'GL000256.2'
# Row 166445 failed: 'GL000256.2'
# Row 166446 failed: 'GL000256.2'
# Row 166447 failed: 'GL000256.2'
# Row 166448 failed: 'GL000256.2'
# Row 166449 failed: 'GL000256.2'
# Row 166450 failed: 'GL000256.2'
# Row 166451 failed: 'GL000256.2'
# Row 166452 failed: 'GL000256.2'
# Row 166453 failed: 'GL000256.2'
# Row 166454 failed: 'GL000256.2'
# Row 166455 failed: 'GL000256.2'
# Row 166456 failed: 'GL000256.2'
# Row 166457 failed: 'GL000256.2'
# Row 166458 failed: 'GL000256.2'
# Row 166459 failed: 'GL000256.2'
# Row 166460 failed: 'GL000256.2'
# Row 166461 failed: 'GL000256.2'
# Row 166462 failed: 'GL000256.2'
# Row 166463 failed: 'GL000256.2'
# Row 166464 failed: 'GL000256.2'
# Row 166465 failed: 'GL000256.2'
# Row 166466 failed: 'GL000256.2'
# Row 166467 failed: 'GL000256.2'
# Row 166468 failed: 'GL000256.2'
# Row 166469 failed: 'GL000256.2'
# Row 166470 failed: 'GL000256.2'
# Row 166471 failed: 'GL000256.2'
# Row 166472 failed: 'GL000256.2'
# Row 166473 failed: 'GL000256.2'
# Row 166474 failed: 'GL000256.2'
# Row 166475 failed: 'GL000256.2'
# Row 166476 failed: 'GL000256.2'
# Row 166477 failed: 'GL000256.2'
# Row 166478 failed: 'GL000256.2'
# Row 166479 failed: 'GL000256.2'
# Row 166480 failed: 'GL000256.2'
# Row 166481 failed: 'GL000256.2'
# Row 166482 failed: 'GL000256.2'
# Row 166483 failed: 'GL000256.2'
# Row 166484 failed: 'GL000256.2'
# Row 166485 failed: 'GL000256.2'
# Row 166486 failed: 'GL000256.2'
# Row 166487 failed: 'GL000256.2'
# Row 166488 failed: 'GL000256.2'
# Row 166489 failed: 'GL000256.2'
# Row 166490 failed: 'GL000256.2'
# Row 166892 failed: 'KI270908.1'
# Row 166893 failed: 'KI270908.1'
# Row 166894 failed: 'KI270908.1'
# Row 166895 failed: 'KI270908.1'
# Row 166896 failed: 'KI270908.1'
# Row 166897 failed: 'KI270908.1'
# Row 166898 failed: 'KI270908.1'
# Row 166899 failed: 'KI270908.1'
# Row 166900 failed: 'KI270908.1'
# Row 166901 failed: 'KI270908.1'
# Row 166902 failed: 'KI270908.1'
# Row 166903 failed: 'KI270908.1'
# Row 166904 failed: 'KI270908.1'
# Row 166905 failed: 'KI270908.1'
# Row 166906 failed: 'KI270908.1'
# Row 166907 failed: 'KI270908.1'
# Row 166908 failed: 'KI270908.1'
# Row 166909 failed: 'KI270908.1'
# Row 166910 failed: 'KI270908.1'
# Row 166911 failed: 'KI270908.1'
# Row 166912 failed: 'KI270908.1'
# Row 166913 failed: 'KI270908.1'
# Row 166914 failed: 'KI270908.1'
# Row 166915 failed: 'KI270908.1'
# Row 166916 failed: 'KI270908.1'
# Row 166917 failed: 'KI270908.1'
# Row 166918 failed: 'KI270908.1'
# Row 166919 failed: 'KI270908.1'
# Row 166920 failed: 'KI270908.1'
# Row 166921 failed: 'KI270908.1'
# Row 166922 failed: 'KI270908.1'
# Row 166923 failed: 'KI270908.1'
# Row 166924 failed: 'KI270908.1'
# Row 166925 failed: 'KI270908.1'
# Row 166926 failed: 'KI270908.1'
# Row 166927 failed: 'KI270908.1'
# Row 166928 failed: 'KI270908.1'
# Row 166929 failed: 'KI270908.1'
# Row 166930 failed: 'KI270908.1'
# Row 166931 failed: 'KI270908.1'
# Row 166932 failed: 'KI270908.1'
# Row 166933 failed: 'KI270908.1'
# Row 166934 failed: 'KI270908.1'
# Row 166935 failed: 'KI270908.1'
# Row 166936 failed: 'KI270908.1'
# Row 166937 failed: 'KI270908.1'
# Row 166938 failed: 'KI270908.1'
# Row 166939 failed: 'KI270908.1'
# Row 166940 failed: 'KI270908.1'
# Row 166941 failed: 'KI270908.1'
# Row 166942 failed: 'KI270908.1'
# Row 166943 failed: 'KI270908.1'
# Row 166944 failed: 'KI270908.1'
# Row 166945 failed: 'KI270908.1'
# Row 166946 failed: 'KI270908.1'
# Row 166947 failed: 'KI270908.1'
# Row 166948 failed: 'KI270908.1'
# Row 166949 failed: 'KI270908.1'
# Row 166950 failed: 'KI270908.1'
# Row 166951 failed: 'KI270908.1'
# Row 166952 failed: 'KI270908.1'
# Row 166953 failed: 'KI270908.1'
# Row 166954 failed: 'KI270908.1'
# Row 166955 failed: 'KI270908.1'
# Row 167269 failed: 'KI270871.1'
# Row 167270 failed: 'KI270871.1'
# Row 167271 failed: 'KI270871.1'
# Row 167272 failed: 'KI270871.1'
# Row 167273 failed: 'KI270871.1'
# Row 167274 failed: 'KI270871.1'
# Row 167275 failed: 'KI270871.1'
# Row 167276 failed: 'KI270871.1'
# Row 167277 failed: 'KI270871.1'
# Row 167278 failed: 'KI270871.1'
# Row 167279 failed: 'KI270871.1'
# Row 167280 failed: 'KI270871.1'
# Row 167281 failed: 'KI270871.1'
# Row 167282 failed: 'KI270871.1'
# Row 167283 failed: 'KI270871.1'
# Row 167284 failed: 'KI270871.1'
# Row 167285 failed: 'KI270871.1'
# Row 167286 failed: 'KI270871.1'
# Row 167287 failed: 'KI270871.1'
# Row 167288 failed: 'KI270871.1'
# Row 167289 failed: 'KI270871.1'
# Row 167290 failed: 'KI270871.1'
# Row 167291 failed: 'KI270871.1'
# Row 167292 failed: 'KI270871.1'
# Row 167293 failed: 'KI270871.1'
# Row 167294 failed: 'KI270871.1'
# Row 167295 failed: 'KI270871.1'
# Row 167296 failed: 'KI270871.1'
# Row 167297 failed: 'KI270871.1'
# Row 167298 failed: 'KI270871.1'
# Row 167299 failed: 'KI270871.1'
# Row 167300 failed: 'KI270871.1'
# Row 167301 failed: 'KI270871.1'
# Row 167302 failed: 'KI270871.1'
# Row 167303 failed: 'KI270871.1'
# Row 167304 failed: 'KI270871.1'
# Row 167305 failed: 'KI270871.1'
# Row 167306 failed: 'KI270871.1'
# Row 167307 failed: 'KI270871.1'
# Row 167308 failed: 'KI270871.1'
# Row 167309 failed: 'KI270871.1'
# Row 167310 failed: 'KI270871.1'
# Row 167311 failed: 'KI270871.1'
# Row 167312 failed: 'KI270871.1'
# Row 167313 failed: 'KI270871.1'
# Row 167314 failed: 'KI270871.1'
# Row 167315 failed: 'KI270871.1'
# Row 167316 failed: 'KI270871.1'
# Row 167317 failed: 'KI270871.1'
# Row 167318 failed: 'KI270871.1'
# Row 167319 failed: 'KI270871.1'
# Row 167320 failed: 'KI270871.1'
# Row 167321 failed: 'KI270871.1'
# Row 167322 failed: 'KI270871.1'
# Row 167323 failed: 'KI270871.1'
# Row 167324 failed: 'KI270871.1'
# Row 167325 failed: 'KI270871.1'
# Row 167326 failed: 'KI270871.1'
# Row 167327 failed: 'KI270871.1'
# Row 167328 failed: 'KI270871.1'
# Row 167329 failed: 'KI270871.1'
# Row 167330 failed: 'KI270871.1'
# Row 167331 failed: 'KI270871.1'
# Row 167332 failed: 'KI270871.1'
# Row 167333 failed: 'KI270871.1'
# Row 167334 failed: 'KI270871.1'
# Row 167335 failed: 'KI270871.1'
# Row 167336 failed: 'KI270871.1'
# Row 167337 failed: 'KI270871.1'
# Row 167338 failed: 'KI270871.1'
# Row 167339 failed: 'KI270871.1'
# Row 167340 failed: 'KI270871.1'
# Row 167341 failed: 'KI270871.1'
# Row 167342 failed: 'KI270871.1'
# Row 167343 failed: 'KI270871.1'
# Row 167344 failed: 'KI270871.1'
# Row 167345 failed: 'KI270871.1'
# Row 167346 failed: 'KI270871.1'
# Row 171950 failed: 'KI270908.1'
# Row 171951 failed: 'KI270908.1'
# Row 171952 failed: 'KI270908.1'
# Row 171953 failed: 'KI270908.1'
# Row 171954 failed: 'KI270908.1'
# Row 171955 failed: 'KI270908.1'
# Row 171956 failed: 'KI270908.1'
# Row 171957 failed: 'KI270908.1'
# Row 171958 failed: 'KI270908.1'
# Row 171959 failed: 'KI270908.1'
# Row 171960 failed: 'KI270908.1'
# Row 171961 failed: 'KI270908.1'
# Row 171962 failed: 'KI270908.1'
# Row 171963 failed: 'KI270908.1'
# Row 171964 failed: 'KI270908.1'
# Row 171965 failed: 'KI270908.1'
# Row 171966 failed: 'KI270908.1'
# Row 171967 failed: 'KI270908.1'
# Row 171968 failed: 'KI270908.1'
# Row 171969 failed: 'KI270908.1'
# Row 171970 failed: 'KI270908.1'
# Row 171971 failed: 'KI270908.1'
# Row 171972 failed: 'KI270908.1'
# Row 171973 failed: 'KI270908.1'
# Row 171974 failed: 'KI270908.1'
# Row 171975 failed: 'KI270908.1'
# Row 171976 failed: 'KI270908.1'
# Row 171977 failed: 'KI270908.1'
# Row 171978 failed: 'KI270908.1'
# Row 171979 failed: 'KI270908.1'
# Row 171980 failed: 'KI270908.1'
# Row 171981 failed: 'KI270908.1'
# Row 171982 failed: 'KI270908.1'
# Row 171983 failed: 'KI270908.1'
# Row 171984 failed: 'KI270908.1'
# Row 171985 failed: 'KI270908.1'
# Row 171986 failed: 'KI270908.1'
# Row 171987 failed: 'KI270908.1'
# Row 171988 failed: 'KI270908.1'
# Row 171989 failed: 'KI270908.1'
# Row 171990 failed: 'KI270908.1'
# Row 171991 failed: 'KI270908.1'
# Row 171992 failed: 'KI270908.1'
# Row 171993 failed: 'KI270908.1'
# Row 171994 failed: 'KI270908.1'
# Row 171995 failed: 'KI270908.1'
# Row 171996 failed: 'KI270908.1'
# Row 171997 failed: 'KI270908.1'
# Row 171998 failed: 'KI270908.1'
# Row 171999 failed: 'KI270908.1'
# Row 172000 failed: 'KI270908.1'
# Row 172001 failed: 'KI270908.1'
# Row 172002 failed: 'KI270908.1'
# Row 172003 failed: 'KI270908.1'
# Row 172004 failed: 'KI270908.1'
# Row 172005 failed: 'KI270908.1'
# Row 172006 failed: 'KI270908.1'
# Row 172007 failed: 'KI270908.1'
# Row 172008 failed: 'KI270908.1'
# Row 172009 failed: 'KI270908.1'
# Row 172010 failed: 'KI270908.1'
# Row 172011 failed: 'KI270908.1'
# Row 172012 failed: 'KI270908.1'
# Row 172013 failed: 'KI270908.1'
# Row 172014 failed: 'KI270908.1'
# Row 172015 failed: 'KI270908.1'
# Row 172016 failed: 'KI270908.1'
# Row 172017 failed: 'KI270908.1'
# Row 172018 failed: 'KI270908.1'
# Row 172019 failed: 'KI270908.1'
# Row 172020 failed: 'KI270908.1'
# Row 172021 failed: 'KI270908.1'
# Row 172022 failed: 'KI270908.1'
# Row 172023 failed: 'KI270908.1'
# Row 172024 failed: 'KI270908.1'
# Row 172025 failed: 'KI270908.1'
# Row 172026 failed: 'KI270908.1'
# Row 172027 failed: 'KI270908.1'
# Row 172028 failed: 'KI270908.1'
# Saved feature: ribo_gene_mean
# Saved feature: ribo_f0_mean
# Saved feature: ribo_f10_mean
# Saved feature: ribo_upstream_10_mean
# Saved feature: ribo_downstream_10_mean
# Saved feature: ribo_f20_mean
# Saved feature: ribo_upstream_20_mean
# Saved feature: ribo_downstream_20_mean
# Saved feature: ribo_f50_mean
# Saved feature: ribo_upstream_50_mean
# Saved feature: ribo_downstream_50_mean
# Saved feature: ribo_f100_mean
# Saved feature: ribo_upstream_100_mean
# Saved feature: ribo_downstream_100_mean
# Saved feature: ribo_f125_mean
# Saved feature: ribo_upstream_125_mean
# Saved feature: ribo_downstream_125_mean
# Saved feature: ribo_f150_mean
# Saved feature: ribo_upstream_150_mean
# Saved feature: ribo_downstream_150_mean

# %%
calculator.calculate_off_target_general()
# Out:
# Computing 24 general off-target features...
# Loading FULL genome data dictionary into memory (happens once)...
# [Task] finished in 0.0006s
# Elapsed DB:  0.0005767345428466797
# Elapsed Fasta:  0.0005767345428466797
# Length:  3267117988
# Loading FULL transcriptomes into memory (happens once)...
# Querying GTF database for non_mt genes...
#   -> Warning: No expression data for ACH-002310
#   -> Warning: No expression data for ACH-001087
# Filtering: Kept 38585 genes out of 41144 total columns.
# Running config: TopN=25, Cutoff=1200
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=7217), Label(value='0 / 7217'))), …
# Saved feature: off_target_score_general_ARTM_n25_c1200
# Running config: TopN=25, Cutoff=1000
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=7217), Label(value='0 / 7217'))), …
# Saved feature: off_target_score_general_ARTM_n25_c1000
# Running config: TopN=25, Cutoff=800
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=7217), Label(value='0 / 7217'))), …
# Saved feature: off_target_score_general_ARTM_n25_c800
# Running config: TopN=50, Cutoff=1200
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=7217), Label(value='0 / 7217'))), …
# Saved feature: off_target_score_general_ARTM_n50_c1200
# Running config: TopN=50, Cutoff=1000
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=7217), Label(value='0 / 7217'))), …
# Saved feature: off_target_score_general_ARTM_n50_c1000
# Running config: TopN=50, Cutoff=800
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=7217), Label(value='0 / 7217'))), …
# Saved feature: off_target_score_general_ARTM_n50_c800
# Running config: TopN=100, Cutoff=1200
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=7217), Label(value='0 / 7217'))), …
# Warning! PFN1 is the target gene, score is set to 0 for ASO AGCCCATTCACGTAAAAACT
# Warning! PFN1 is the target gene, score is set to 0 for ASO CAGACGAGGTCAGTACTGGG
# Warning! PFN1 is the target gene, score is set to 0 for ASO GTGACAGTGACATTGAAGGT
# Warning! PFN1 is the target gene, score is set to 0 for ASO TTGTCAGTCTTGGTGACAGT
# Warning! PFN1 is the target gene, score is set to 0 for ASO GAAGGGACAGACGAGGTCAG
# Warning! PFN1 is the target gene, score is set to 0 for ASO CCATGAGGTTGTCGATGTAG
# Warning! PFN1 is the target gene, score is set to 0 for ASO TGGTACGAAGATCCATGCTA
# Warning! PFN1 is the target gene, score is set to 0 for ASO CCCAAGTGTCAGCCCATTCA
# Warning! PFN1 is the target gene, score is set to 0 for ASO ATCACCGAACATTTCTGGCC
# Warning! PFN1 is the target gene, score is set to 0 for ASO ACCGGTCTTTGCCAACCAGG
# Warning! PFN1 is the target gene, score is set to 0 for ASO CCCATTCACGTAAAAACTTG
# Warning! PFN1 is the target gene, score is set to 0 for ASO GCGTCTTGTCAGTCTTGGTG
# Warning! PFN1 is the target gene, score is set to 0 for ASO AGATCCATGCTAAATTCCCC
# Warning! PFN1 is the target gene, score is set to 0 for ASO AGGCCATTTCATAACATTTC
# Saved feature: off_target_score_general_ARTM_n100_c1200
# Running config: TopN=100, Cutoff=1000
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=7217), Label(value='0 / 7217'))), …
# Warning! PFN1 is the target gene, score is set to 0 for ASO GTGACAGTGACATTGAAGGT
# Warning! PFN1 is the target gene, score is set to 0 for ASO CCATGAGGTTGTCGATGTAG
# Warning! PFN1 is the target gene, score is set to 0 for ASO TGGTACGAAGATCCATGCTA
# Saved feature: off_target_score_general_ARTM_n100_c1000
# Running config: TopN=100, Cutoff=800
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=7217), Label(value='0 / 7217'))), …
# Saved feature: off_target_score_general_ARTM_n100_c800
# Running config: TopN=200, Cutoff=1200
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=7217), Label(value='0 / 7217'))), …
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO GAAAGATCTCTTTGTTCGAG
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO ATGCGTGATGTGTCGTCATC
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO CTTCAGTTACAGCAGCACTG
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO CCGGATTTTGTCCAATGCAT
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO ACAGCATGGAGATGTCACCA
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO GAAGACAGGAGCGCAGTTTC
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO GACAGGAGCGCAGTTTCATA
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO GTTGCAACATCTCACGGGAT
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO TGAATTTGAAATGAGCTCTC
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO AGTTTGATCATCCTGTAGAT
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO AGACAGGAGCGCAGTTTCAT
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO AGGATAACTTTTGTTCCACG
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO AGTATCCACAATAGTGAGAG
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO CTTCTTTGGTGACTGACACT
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO TGGGCTCAATCATATAGATC
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO TGAGAGAAACCATCTCATCA
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO GAAAACTCTGCGTACATACA
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO AAACCATCTCATCACCAGAG
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO TAGATCCTGTTAGCATGTGT
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO ACAGATCAAAAGGAGCACGT
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO CAGCCATATGTGCTTGTGAC
# Warning! CALR is the target gene, score is set to 0 for ASO GGCACGGATAGCAGCATGGC
# Warning! CALR is the target gene, score is set to 0 for ASO TCTGACTTGTGTTTGGATTC
# Warning! CALR is the target gene, score is set to 0 for ASO CGTCACCGTAGAACTTGCCG
# Warning! CALR is the target gene, score is set to 0 for ASO GGCCTTTGTTGCTGAAAGGC
# Warning! CALR is the target gene, score is set to 0 for ASO GATGTTCTGCTCATGTTTCA
# Warning! CALR is the target gene, score is set to 0 for ASO ACATGATGTTGTATTCTGAG
# Warning! CALR is the target gene, score is set to 0 for ASO TTGTAGTTGAAGATGACATG
# Warning! CALR is the target gene, score is set to 0 for ASO ACAGGTGTGTAAACTCATCA
# Warning! CALR is the target gene, score is set to 0 for ASO CTTCACCTCATAGGTGTTGT
# Warning! CALR is the target gene, score is set to 0 for ASO CCAATCGTCTTCCAAGGAGC
# Warning! CALR is the target gene, score is set to 0 for ASO GGTTTTGAAGCATCAGGATC
# Warning! CALR is the target gene, score is set to 0 for ASO CTGTGGGATCATCGATCTTG
# Warning! CALR is the target gene, score is set to 0 for ASO CTTCTTAGCATCAGGGTCAG
# Warning! CALR is the target gene, score is set to 0 for ASO GGGTTGTCAATTTCTGGGTG
# Warning! CALR is the target gene, score is set to 0 for ASO CATAGGCATAGATACTGGGA
# Warning! CALR is the target gene, score is set to 0 for ASO TGAGGAAGTTGTCAAAGATG
# Warning! CALR is the target gene, score is set to 0 for ASO CCTCATCGTTGGTGATGAGG
# Warning! CALR is the target gene, score is set to 0 for ASO TCCTCTTTGCGTTTCTTGTC
# Warning! CALR is the target gene, score is set to 0 for ASO CTCATCTTTGTCCTCATCAT
# Warning! CALR is the target gene, score is set to 0 for ASO AAGTTCTCGAGTCTCACAGA
# Warning! CALR is the target gene, score is set to 0 for ASO GAGGGCTGAAGGAGAATCAA
# Warning! CALR is the target gene, score is set to 0 for ASO GAGCAGATGAAATCTCAGGC
# Warning! CALR is the target gene, score is set to 0 for ASO CTTACATTCTCAGTGTGAGC
# Warning! CALR is the target gene, score is set to 0 for ASO ATTTTGTTTGTAGTTCTTAC
# Warning! PFN1 is the target gene, score is set to 0 for ASO AGCCCATTCACGTAAAAACT
# Warning! PFN1 is the target gene, score is set to 0 for ASO CAGACGAGGTCAGTACTGGG
# Warning! PFN1 is the target gene, score is set to 0 for ASO GTGACAGTGACATTGAAGGT
# Warning! PFN1 is the target gene, score is set to 0 for ASO TTGTCAGTCTTGGTGACAGT
# Warning! PFN1 is the target gene, score is set to 0 for ASO GAAGGGACAGACGAGGTCAG
# Warning! PFN1 is the target gene, score is set to 0 for ASO CCATGAGGTTGTCGATGTAG
# Warning! PFN1 is the target gene, score is set to 0 for ASO TGGTACGAAGATCCATGCTA
# Warning! PFN1 is the target gene, score is set to 0 for ASO ATCACCGAACATTTCTGGCC
# Warning! PFN1 is the target gene, score is set to 0 for ASO CCCATTCACGTAAAAACTTG
# Warning! PFN1 is the target gene, score is set to 0 for ASO GCGTCTTGTCAGTCTTGGTG
# Warning! PFN1 is the target gene, score is set to 0 for ASO AGATCCATGCTAAATTCCCC
# Warning! PFN1 is the target gene, score is set to 0 for ASO AGGCCATTTCATAACATTTC
# Saved feature: off_target_score_general_ARTM_n200_c1200
# Running config: TopN=200, Cutoff=1000
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=7217), Label(value='0 / 7217'))), …
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO GAAAGATCTCTTTGTTCGAG
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO ACAGCATGGAGATGTCACCA
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO TGAATTTGAAATGAGCTCTC
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO CATATAGATCACTTCTAAGC
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO GTTCAGTAAAGAGTTCTAAG
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO TCCTGATAACTTTCAAAATT
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO AGTATCCACAATAGTGAGAG
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO GAAAACTCTGCGTACATACA
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO GTATAAGGTTAATATGCAGC
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO ACAGATCAAAAGGAGCACGT
# Warning! CALR is the target gene, score is set to 0 for ASO AAACTATTAGGAAACAGCTT
# Warning! CALR is the target gene, score is set to 0 for ASO ACATGATGTTGTATTCTGAG
# Warning! CALR is the target gene, score is set to 0 for ASO TTGTAGTTGAAGATGACATG
# Warning! CALR is the target gene, score is set to 0 for ASO ACAGGTGTGTAAACTCATCA
# Warning! CALR is the target gene, score is set to 0 for ASO GGTTTTGAAGCATCAGGATC
# Warning! CALR is the target gene, score is set to 0 for ASO CATAGGCATAGATACTGGGA
# Warning! CALR is the target gene, score is set to 0 for ASO TGAGGAAGTTGTCAAAGATG
# Warning! CALR is the target gene, score is set to 0 for ASO GAGCAGATGAAATCTCAGGC
# Warning! CALR is the target gene, score is set to 0 for ASO CTTACATTCTCAGTGTGAGC
# Warning! CALR is the target gene, score is set to 0 for ASO ATTTTGTTTGTAGTTCTTAC
# Warning! PFN1 is the target gene, score is set to 0 for ASO GTGACAGTGACATTGAAGGT
# Warning! PFN1 is the target gene, score is set to 0 for ASO CCATGAGGTTGTCGATGTAG
# Warning! PFN1 is the target gene, score is set to 0 for ASO TGGTACGAAGATCCATGCTA
# Saved feature: off_target_score_general_ARTM_n200_c1000
# Running config: TopN=200, Cutoff=800
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=7217), Label(value='0 / 7217'))), …
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO CATATAGATCACTTCTAAGC
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO GTTCAGTAAAGAGTTCTAAG
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO GTATAAGGTTAATATGCAGC
# Warning! CALR is the target gene, score is set to 0 for ASO AAACTATTAGGAAACAGCTT
# Warning! CALR is the target gene, score is set to 0 for ASO TTGTAGTTGAAGATGACATG
# Warning! CALR is the target gene, score is set to 0 for ASO GCAAGAAAAGATGTTGATCA
# Saved feature: off_target_score_general_ARTM_n200_c800
# Running config: TopN=25, Cutoff=1200
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=7217), Label(value='0 / 7217'))), …
# Saved feature: off_target_score_general_MECH_n25_c1200
# Running config: TopN=25, Cutoff=1000
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=7217), Label(value='0 / 7217'))), …
# Saved feature: off_target_score_general_MECH_n25_c1000
# Running config: TopN=25, Cutoff=800
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=7217), Label(value='0 / 7217'))), …
# Saved feature: off_target_score_general_MECH_n25_c800
# Running config: TopN=50, Cutoff=1200
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=7217), Label(value='0 / 7217'))), …
# Saved feature: off_target_score_general_MECH_n50_c1200
# Running config: TopN=50, Cutoff=1000
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=7217), Label(value='0 / 7217'))), …
# Saved feature: off_target_score_general_MECH_n50_c1000
# Running config: TopN=50, Cutoff=800
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=7217), Label(value='0 / 7217'))), …
# Saved feature: off_target_score_general_MECH_n50_c800
# Running config: TopN=100, Cutoff=1200
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=7217), Label(value='0 / 7217'))), …
# Warning! PFN1 is the target gene, score is set to 0 for ASO AGCCCATTCACGTAAAAACT
# Warning! PFN1 is the target gene, score is set to 0 for ASO CAGACGAGGTCAGTACTGGG
# Warning! PFN1 is the target gene, score is set to 0 for ASO GTGACAGTGACATTGAAGGT
# Warning! PFN1 is the target gene, score is set to 0 for ASO TTGTCAGTCTTGGTGACAGT
# Warning! PFN1 is the target gene, score is set to 0 for ASO GAAGGGACAGACGAGGTCAG
# Warning! PFN1 is the target gene, score is set to 0 for ASO CCATGAGGTTGTCGATGTAG
# Warning! PFN1 is the target gene, score is set to 0 for ASO TGGTACGAAGATCCATGCTA
# Warning! PFN1 is the target gene, score is set to 0 for ASO CCCAAGTGTCAGCCCATTCA
# Warning! PFN1 is the target gene, score is set to 0 for ASO ATCACCGAACATTTCTGGCC
# Warning! PFN1 is the target gene, score is set to 0 for ASO ACCGGTCTTTGCCAACCAGG
# Warning! PFN1 is the target gene, score is set to 0 for ASO CCCATTCACGTAAAAACTTG
# Warning! PFN1 is the target gene, score is set to 0 for ASO GCGTCTTGTCAGTCTTGGTG
# Warning! PFN1 is the target gene, score is set to 0 for ASO AGATCCATGCTAAATTCCCC
# Warning! PFN1 is the target gene, score is set to 0 for ASO AGGCCATTTCATAACATTTC
# Saved feature: off_target_score_general_MECH_n100_c1200
# Running config: TopN=100, Cutoff=1000
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=7217), Label(value='0 / 7217'))), …
# Warning! PFN1 is the target gene, score is set to 0 for ASO GTGACAGTGACATTGAAGGT
# Warning! PFN1 is the target gene, score is set to 0 for ASO CCATGAGGTTGTCGATGTAG
# Warning! PFN1 is the target gene, score is set to 0 for ASO TGGTACGAAGATCCATGCTA
# Saved feature: off_target_score_general_MECH_n100_c1000
# Running config: TopN=100, Cutoff=800
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=7217), Label(value='0 / 7217'))), …
# Saved feature: off_target_score_general_MECH_n100_c800
# Running config: TopN=200, Cutoff=1200
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=7217), Label(value='0 / 7217'))), …
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO GAAAGATCTCTTTGTTCGAG
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO ATGCGTGATGTGTCGTCATC
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO CTTCAGTTACAGCAGCACTG
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO CCGGATTTTGTCCAATGCAT
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO ACAGCATGGAGATGTCACCA
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO GAAGACAGGAGCGCAGTTTC
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO GACAGGAGCGCAGTTTCATA
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO GTTGCAACATCTCACGGGAT
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO TGAATTTGAAATGAGCTCTC
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO AGTTTGATCATCCTGTAGAT
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO AGACAGGAGCGCAGTTTCAT
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO AGGATAACTTTTGTTCCACG
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO AGTATCCACAATAGTGAGAG
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO CTTCTTTGGTGACTGACACT
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO TGGGCTCAATCATATAGATC
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO TGAGAGAAACCATCTCATCA
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO GAAAACTCTGCGTACATACA
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO AAACCATCTCATCACCAGAG
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO TAGATCCTGTTAGCATGTGT
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO ACAGATCAAAAGGAGCACGT
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO CAGCCATATGTGCTTGTGAC
# Warning! CALR is the target gene, score is set to 0 for ASO GGCACGGATAGCAGCATGGC
# Warning! CALR is the target gene, score is set to 0 for ASO TCTGACTTGTGTTTGGATTC
# Warning! CALR is the target gene, score is set to 0 for ASO CGTCACCGTAGAACTTGCCG
# Warning! CALR is the target gene, score is set to 0 for ASO GGCCTTTGTTGCTGAAAGGC
# Warning! CALR is the target gene, score is set to 0 for ASO GATGTTCTGCTCATGTTTCA
# Warning! CALR is the target gene, score is set to 0 for ASO ACATGATGTTGTATTCTGAG
# Warning! CALR is the target gene, score is set to 0 for ASO TTGTAGTTGAAGATGACATG
# Warning! CALR is the target gene, score is set to 0 for ASO ACAGGTGTGTAAACTCATCA
# Warning! CALR is the target gene, score is set to 0 for ASO CTTCACCTCATAGGTGTTGT
# Warning! CALR is the target gene, score is set to 0 for ASO CCAATCGTCTTCCAAGGAGC
# Warning! CALR is the target gene, score is set to 0 for ASO GGTTTTGAAGCATCAGGATC
# Warning! CALR is the target gene, score is set to 0 for ASO CTGTGGGATCATCGATCTTG
# Warning! CALR is the target gene, score is set to 0 for ASO CTTCTTAGCATCAGGGTCAG
# Warning! CALR is the target gene, score is set to 0 for ASO GGGTTGTCAATTTCTGGGTG
# Warning! CALR is the target gene, score is set to 0 for ASO CATAGGCATAGATACTGGGA
# Warning! CALR is the target gene, score is set to 0 for ASO TGAGGAAGTTGTCAAAGATG
# Warning! CALR is the target gene, score is set to 0 for ASO CCTCATCGTTGGTGATGAGG
# Warning! CALR is the target gene, score is set to 0 for ASO TCCTCTTTGCGTTTCTTGTC
# Warning! CALR is the target gene, score is set to 0 for ASO CTCATCTTTGTCCTCATCAT
# Warning! CALR is the target gene, score is set to 0 for ASO AAGTTCTCGAGTCTCACAGA
# Warning! CALR is the target gene, score is set to 0 for ASO GAGGGCTGAAGGAGAATCAA
# Warning! CALR is the target gene, score is set to 0 for ASO GAGCAGATGAAATCTCAGGC
# Warning! CALR is the target gene, score is set to 0 for ASO CTTACATTCTCAGTGTGAGC
# Warning! CALR is the target gene, score is set to 0 for ASO ATTTTGTTTGTAGTTCTTAC
# Warning! PFN1 is the target gene, score is set to 0 for ASO AGCCCATTCACGTAAAAACT
# Warning! PFN1 is the target gene, score is set to 0 for ASO CAGACGAGGTCAGTACTGGG
# Warning! PFN1 is the target gene, score is set to 0 for ASO GTGACAGTGACATTGAAGGT
# Warning! PFN1 is the target gene, score is set to 0 for ASO TTGTCAGTCTTGGTGACAGT
# Warning! PFN1 is the target gene, score is set to 0 for ASO GAAGGGACAGACGAGGTCAG
# Warning! PFN1 is the target gene, score is set to 0 for ASO CCATGAGGTTGTCGATGTAG
# Warning! PFN1 is the target gene, score is set to 0 for ASO TGGTACGAAGATCCATGCTA
# Warning! PFN1 is the target gene, score is set to 0 for ASO ATCACCGAACATTTCTGGCC
# Warning! PFN1 is the target gene, score is set to 0 for ASO CCCATTCACGTAAAAACTTG
# Warning! PFN1 is the target gene, score is set to 0 for ASO GCGTCTTGTCAGTCTTGGTG
# Warning! PFN1 is the target gene, score is set to 0 for ASO AGATCCATGCTAAATTCCCC
# Warning! PFN1 is the target gene, score is set to 0 for ASO AGGCCATTTCATAACATTTC
# Saved feature: off_target_score_general_MECH_n200_c1200
# Running config: TopN=200, Cutoff=1000
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=7217), Label(value='0 / 7217'))), …
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO GAAAGATCTCTTTGTTCGAG
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO ACAGCATGGAGATGTCACCA
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO TGAATTTGAAATGAGCTCTC
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO CATATAGATCACTTCTAAGC
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO GTTCAGTAAAGAGTTCTAAG
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO TCCTGATAACTTTCAAAATT
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO AGTATCCACAATAGTGAGAG
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO GAAAACTCTGCGTACATACA
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO GTATAAGGTTAATATGCAGC
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO ACAGATCAAAAGGAGCACGT
# Warning! CALR is the target gene, score is set to 0 for ASO AAACTATTAGGAAACAGCTT
# Warning! CALR is the target gene, score is set to 0 for ASO ACATGATGTTGTATTCTGAG
# Warning! CALR is the target gene, score is set to 0 for ASO TTGTAGTTGAAGATGACATG
# Warning! CALR is the target gene, score is set to 0 for ASO ACAGGTGTGTAAACTCATCA
# Warning! CALR is the target gene, score is set to 0 for ASO GGTTTTGAAGCATCAGGATC
# Warning! CALR is the target gene, score is set to 0 for ASO CATAGGCATAGATACTGGGA
# Warning! CALR is the target gene, score is set to 0 for ASO TGAGGAAGTTGTCAAAGATG
# Warning! CALR is the target gene, score is set to 0 for ASO GAGCAGATGAAATCTCAGGC
# Warning! CALR is the target gene, score is set to 0 for ASO CTTACATTCTCAGTGTGAGC
# Warning! CALR is the target gene, score is set to 0 for ASO ATTTTGTTTGTAGTTCTTAC
# Warning! PFN1 is the target gene, score is set to 0 for ASO GTGACAGTGACATTGAAGGT
# Warning! PFN1 is the target gene, score is set to 0 for ASO CCATGAGGTTGTCGATGTAG
# Warning! PFN1 is the target gene, score is set to 0 for ASO TGGTACGAAGATCCATGCTA
# Saved feature: off_target_score_general_MECH_n200_c1000
# Running config: TopN=200, Cutoff=800
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=7217), Label(value='0 / 7217'))), …
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO CATATAGATCACTTCTAAGC
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO GTTCAGTAAAGAGTTCTAAG
# Warning! HSP90AA1 is the target gene, score is set to 0 for ASO GTATAAGGTTAATATGCAGC
# Warning! CALR is the target gene, score is set to 0 for ASO AAACTATTAGGAAACAGCTT
# Warning! CALR is the target gene, score is set to 0 for ASO TTGTAGTTGAAGATGACATG
# Warning! CALR is the target gene, score is set to 0 for ASO GCAAGAAAAGATGTTGATCA
# Saved feature: off_target_score_general_MECH_n200_c800

# %%
calculator.calculate_off_target_single()
# Out:
# Computing specific off-target features...
# INFO: Pandarallel will run on 24 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=7217), Label(value='0 / 7217'))), …
# Saved feature: off_target_single_RNASEH1_c1200
# INFO: Pandarallel will run on 24 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=7217), Label(value='0 / 7217'))), …
# Saved feature: off_target_single_RNASEH1_c0
# INFO: Pandarallel will run on 24 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=7217), Label(value='0 / 7217'))), …
# Saved feature: off_target_single_ACTB_c1200
# INFO: Pandarallel will run on 24 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=7217), Label(value='0 / 7217'))), …
# Saved feature: off_target_single_ACTB_c0

# %%
calculator.calculate_mrna_halflife()
# Out:
# Computing 3 mRNA half-life features...
# Loading mRNA Half-Life Oracle into memory (happens once)...
# Loading half-life data from /home/michael/.local/share/tauso/mrna_half_life.csv.gz...
# Successfully loaded 327615 specific (Gene+Cell) stability profiles.
# Provider ready. Global Geometric Mean: 2.04h (N=327615)
# Calculating stability features for 173191 rows...
# Features populated successfully.
# Saved feature: mRNA_HalfLife
# Saved feature: HalfLife_Source
# Saved feature: Mapped_Cell_Proxy

# %%
calculator.calculate_rbp()
# Out:
# Computing RBP Pipeline...
# Adding external mRNA and genomic context columns...
# Building gene sequence registry (happens once)...
# Loading ATTRACT RBP data into memory (happens once)...
# Loading RBP metadata from /home/michael/.local/share/tauso/RBS_motifs_Homo_sapiens.csv...
# Loading PWM matrices from /home/michael/.local/share/tauso/pwm.txt...
# Loaded 1583 PWMs covering 160 unique RBPs.
# Warning: Cells ['ACH-001188', 'ACH-000625', 'ACH-001328', 'ACH-000146', 'ACH-000977', 'ACH-000018', 'ACH-000763', 'ACH-000615', 'ACH-000232', 'ACH-000739', 'ACH-000681', 'ACH-000115', 'ACH-000480', 'ACH-000995', 'ACH-000420', 'ACH-000811', 'ACH-000551', 'ACH-001086', 'ACH-000558', 'ACH-000090', 'ACH-000019', 'ACH-002310', 'ACH-001087', 'ACH-000572'] differ from cached genes ['IFNAR1', 'FOXP3', 'CYTH1', 'FOLR1', 'TDP1', 'SND1', 'SERPINA1', 'CENPB', 'S1PR5', 'HMOX1', 'PIM1', 'FUS', 'RECQL4', 'RAF1', 'CSNK2A1', 'CDK9', 'ATXN1', 'SNCA', 'TTR', 'STK17B', 'ADGRA2', 'NR3C1', 'LIPG', 'STAT3', 'STAT6', 'ARNT', 'PRKD2', 'GPR39', 'BIRC5', 'TNFSF14', 'SLC37A4', 'SERBP1', 'CD40', 'PLSCR1', 'APP', 'SLC26A2', 'MAD1L1', 'TFAP2C', 'CRP', 'MECP2', 'SPDEF', 'CDK17', 'F11', 'KSR1', 'S1PR2', 'DUSP9', 'HMGCR', 'F3', 'NEK6', 'ANGPT2', 'PPM1B', 'BUB1B', 'PAK1', 'SMN1', 'PSD3', 'DRAP1', 'PLP1', 'MRPL13', 'PTPN13', 'KCNT1', 'ABCC2', 'C9orf72', 'SCD', 'IL22RA1', 'JAG1', 'APOL1', 'GYS1', 'FDFT1', 'SREBF1', 'PLN', 'VEGFC', 'DNM2', 'PLD2', 'PPP3CB', 'RPS6KB1', 'UBE2K', 'MAGED1', 'MET', 'AP5Z1', 'ESR1', 'ATXN3', 'LCK', 'HDAC1', 'CD1D', 'JAM3', 'ATXN2', 'MMP11', 'MAP3K11', 'BAG5', 'ACTL6A', 'KRAS', 'ABCC5', 'COMP', 'SEPHS2', 'ZNHIT3', 'PLIN2', 'DUSP4', 'SNHG14', 'RANGAP1', 'C3', 'IFNGR2', 'IRF5', 'BACE1', 'MAPK12', 'RECQL', 'PTPRF', 'ADAM9', 'GFAP', 'ADAM12', 'MAD2L1', 'KLKB1', 'TLN1', 'EFNB2', 'DGAT1', 'CD86', 'CD81', 'TEK', 'EZH2', 'CD36', 'SCN2A', 'ATF3', 'BAX', 'AGT', 'HCK', 'ACAT2', 'SMAD7', 'KCNQ2', 'DAPK1', 'ACTA1', 'PCK2', 'HIF1A', 'APOB', 'PRKCI', 'MAPK13', 'F12', 'RBL2', 'BRCA1', 'BIRC7', 'FGFR4', 'SCNN1A', 'CIITA', 'CTSZ', 'CD24', 'CDK4', 'TGFBR2', 'PTTG1', 'XPO5', 'SUMO2', 'LIMK1', 'PLIN1', 'MRPS16', 'DUSP6', 'CDK1', 'PPP2R1A', 'BACE2', 'CHEK1', 'RCOR1', 'STAT5B', 'NID1', 'GPRC5B', 'HTT', 'STK16', 'SELENOW', 'APOC3', 'AR', 'NOTCH1', 'PTPRA', 'CETP', 'UBE2G1', 'ROCK1', 'AIMP1', 'GCGR', 'N4BP2L2', 'DGAT2', 'MALT1', 'PTPN12', 'STAT5A', 'PUM1', 'TFDP1', 'LGR5', 'ACACA', 'IGF2', 'AGO1', 'GPR3', 'ADAM15', 'IL18', 'HDAC2', 'NANOS1', 'TRA2B', 'CFB', 'MYD88', 'FLT1', 'PDE1B', 'EIF4EBP2', 'STK17A', 'ITGB5', 'BUB3', 'TFAP2A', 'SLC5A2', 'PNPLA3', 'CDC14A', 'HDAC4', 'EIF2AK2', 'PTBP1', 'FGFR2', 'ANGPTL3', 'CD40LG', 'VDR', 'API5', 'FGFR3', 'HIP1', 'RNASEL', 'PFN1', 'APOE', 'STAT1', 'PTPN1', 'PIP4K2B', 'JAG2', 'HDGF', 'PPARD', 'NKRF', 'VEGFB', 'PAK2', 'PCSK9', 'MALAT1', 'EIF4E', 'CXCL8', 'EPAS1', 'PRKAR2B', 'TGFB2', 'STAT2', 'HSP90AA1', 'CSK', 'NOTCH3', 'KIF11', 'CCN2', 'TYR', 'RASD2', 'DDB1', 'NOTCH4', 'CALR', 'IKBKG', 'SCARB1', 'IRAK1', 'IL4R', 'S1PR1', 'SLC2A4', 'P2RX4', 'TMPRSS6', 'NCOR2', 'MARK3', 'LY86', 'PRNP', 'GHR', 'PMP22', 'PTPRK', 'HSD11B1', 'RETN', 'AMACR', 'NR1H4', 'IRAK4', 'GGPS1', 'PTPRU', 'LMNA', 'HSD17B13', 'MAPT', 'PLSCR4', 'NOD1', 'NFKB1', 'INPP5D', 'DYRK4', 'PTPA', 'YAP1', 'PTP4A3', 'DPYSL2', 'PIP5K1A', 'PDE4B', 'LRRK2', 'SOD1', 'FNTB', 'SIDT1', 'F7', 'IRF4', 'MSH3', 'DMPK', 'FXYD3', 'ICMT', 'ACACB', 'TONSL', 'CREB1', 'CDK6', 'CLK1', 'PDE8A', 'NLRP3', 'ODC1', 'PROX1', 'PPARA', 'BAG1', 'FOXO1', 'NOTCH2', 'DUX4', 'KLK6', 'MMP1', 'PLSCR3', 'RNASEH1'], regenerating cache.
# Building RBP expression matrix (happens once)...
# Loading metadata from /home/michael/.local/share/tauso/RBS_motifs_Homo_sapiens.csv to map Matrix IDs to Gene Names...
# Mapped 1583 matrices to 160 unique gene names.
# Loading expression for 24 cell lines...
#   -> Warning: No expression data for ACH-001087
#   -> Warning: No expression data for ACH-002310
# Building lookup matrix...
# Success. Expression matrix ready: (22, 158)
#
# --- Processing Interaction Features ---
# 22 cells, 158 valid RBPs found.
# Calculating interaction features for 158 RBPs on 173191 rows...
# Computing Batches: 100%|██████████| 49/49 [00:09<00:00,  5.23it/s]
# Assigning columns...
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col_name] = values
# Done. Added 158 interaction features.
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:397: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[total_col] = total_scores
# /home/michael/career/tauso_article/tauso_source2/src/tauso/populate/populate_rbp.py:409: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[div_col] = entropy(probs, axis=1)
# Saved feature: RBP_A1CF_expr_aff_50
# Saved feature: RBP_ACO1_expr_aff_50
# Saved feature: RBP_ADAR_expr_aff_50
# Saved feature: RBP_AGO1_expr_aff_50
# Saved feature: RBP_AGO2_expr_aff_50
# Saved feature: RBP_AKAP1_expr_aff_50
# Saved feature: RBP_ANKHD1_expr_aff_50
# Saved feature: RBP_CELF1_expr_aff_50
# Saved feature: RBP_CELF2_expr_aff_50
# Saved feature: RBP_CELF4_expr_aff_50
# Saved feature: RBP_CELF5_expr_aff_50
# Saved feature: RBP_CELF6_expr_aff_50
# Saved feature: RBP_CMTR1_expr_aff_50
# Saved feature: RBP_CNOT4_expr_aff_50
# Saved feature: RBP_CPEB1_expr_aff_50
# Saved feature: RBP_CPEB2_expr_aff_50
# Saved feature: RBP_CPEB4_expr_aff_50
# Saved feature: RBP_CSTF2_expr_aff_50
# Saved feature: RBP_DAZAP1_expr_aff_50
# Saved feature: RBP_DDX19B_expr_aff_50
# Saved feature: RBP_DHX58_expr_aff_50
# Saved feature: RBP_DHX9_expr_aff_50
# Saved feature: RBP_EIF4A3_expr_aff_50
# Saved feature: RBP_EIF4B_expr_aff_50
# Saved feature: RBP_ELAVL1_expr_aff_50
# Saved feature: RBP_ELAVL2_expr_aff_50
# Saved feature: RBP_ELAVL3_expr_aff_50
# Saved feature: RBP_ELAVL4_expr_aff_50
# Saved feature: RBP_ENOX1_expr_aff_50
# Saved feature: RBP_ERI1_expr_aff_50
# Saved feature: RBP_ESRP1_expr_aff_50
# Saved feature: RBP_ESRP2_expr_aff_50
# Saved feature: RBP_F2_expr_aff_50
# Saved feature: RBP_FMR1_expr_aff_50
# Saved feature: RBP_FUS_expr_aff_50
# Saved feature: RBP_FXR1_expr_aff_50
# Saved feature: RBP_FXR2_expr_aff_50
# Saved feature: RBP_G3BP1_expr_aff_50
# Saved feature: RBP_G3BP2_expr_aff_50
# Saved feature: RBP_GRSF1_expr_aff_50
# Saved feature: RBP_HNRNPA0_expr_aff_50
# Saved feature: RBP_HNRNPA1_expr_aff_50
# Saved feature: RBP_HNRNPA1L2_expr_aff_50
# Saved feature: RBP_HNRNPA2B1_expr_aff_50
# Saved feature: RBP_HNRNPA3_expr_aff_50
# Saved feature: RBP_HNRNPAB_expr_aff_50
# Saved feature: RBP_HNRNPC_expr_aff_50
# Saved feature: RBP_HNRNPCL1_expr_aff_50
# Saved feature: RBP_HNRNPD_expr_aff_50
# Saved feature: RBP_HNRNPDL_expr_aff_50
# Saved feature: RBP_HNRNPF_expr_aff_50
# Saved feature: RBP_HNRNPH1_expr_aff_50
# Saved feature: RBP_HNRNPH2_expr_aff_50
# Saved feature: RBP_HNRNPH3_expr_aff_50
# Saved feature: RBP_HNRNPK_expr_aff_50
# Saved feature: RBP_HNRNPL_expr_aff_50
# Saved feature: RBP_HNRNPLL_expr_aff_50
# Saved feature: RBP_HNRNPM_expr_aff_50
# Saved feature: RBP_HNRNPU_expr_aff_50
# Saved feature: RBP_IFIH1_expr_aff_50
# Saved feature: RBP_IGF2BP1_expr_aff_50
# Saved feature: RBP_IGF2BP2_expr_aff_50
# Saved feature: RBP_IGF2BP3_expr_aff_50
# Saved feature: RBP_IGHMBP2_expr_aff_50
# Saved feature: RBP_KHDRBS1_expr_aff_50
# Saved feature: RBP_KHDRBS2_expr_aff_50
# Saved feature: RBP_KHDRBS3_expr_aff_50
# Saved feature: RBP_KHSRP_expr_aff_50
# Saved feature: RBP_LIN28A_expr_aff_50
# Saved feature: RBP_MATR3_expr_aff_50
# Saved feature: RBP_MBNL1_expr_aff_50
# Saved feature: RBP_MSI1_expr_aff_50
# Saved feature: RBP_NELFE_expr_aff_50
# Saved feature: RBP_NONO_expr_aff_50
# Saved feature: RBP_NOVA1_expr_aff_50
# Saved feature: RBP_NOVA2_expr_aff_50
# Saved feature: RBP_NUDT21_expr_aff_50
# Saved feature: RBP_NXF1_expr_aff_50
# Saved feature: RBP_OAS1_expr_aff_50
# Saved feature: RBP_PABPC1_expr_aff_50
# Saved feature: RBP_PABPC3_expr_aff_50
# Saved feature: RBP_PABPC4_expr_aff_50
# Saved feature: RBP_PABPC5_expr_aff_50
# Saved feature: RBP_PABPN1_expr_aff_50
# Saved feature: RBP_PCBP1_expr_aff_50
# Saved feature: RBP_PCBP2_expr_aff_50
# Saved feature: RBP_PHAX_expr_aff_50
# Saved feature: RBP_PIWIL1_expr_aff_50
# Saved feature: RBP_PPIE_expr_aff_50
# Saved feature: RBP_PPRC1_expr_aff_50
# Saved feature: RBP_PTBP1_expr_aff_50
# Saved feature: RBP_PTBP2_expr_aff_50
# Saved feature: RBP_PUM1_expr_aff_50
# Saved feature: RBP_PUM2_expr_aff_50
# Saved feature: RBP_QKI_expr_aff_50
# Saved feature: RBP_RALY_expr_aff_50
# Saved feature: RBP_RBFOX1_expr_aff_50
# Saved feature: RBP_RBFOX2_expr_aff_50
# Saved feature: RBP_RBM14_expr_aff_50
# Saved feature: RBP_RBM24_expr_aff_50
# Saved feature: RBP_RBM25_expr_aff_50
# Saved feature: RBP_RBM28_expr_aff_50
# Saved feature: RBP_RBM3_expr_aff_50
# Saved feature: RBP_RBM4_expr_aff_50
# Saved feature: RBP_RBM41_expr_aff_50
# Saved feature: RBP_RBM42_expr_aff_50
# Saved feature: RBP_RBM46_expr_aff_50
# Saved feature: RBP_RBM5_expr_aff_50
# Saved feature: RBP_RBM6_expr_aff_50
# Saved feature: RBP_RBM8A_expr_aff_50
# Saved feature: RBP_RBMS1_expr_aff_50
# Saved feature: RBP_RBMS3_expr_aff_50
# Saved feature: RBP_RBMX_expr_aff_50
# Saved feature: RBP_RBMY1A1_expr_aff_50
# Saved feature: RBP_RC3H1_expr_aff_50
# Saved feature: RBP_RNASEL_expr_aff_50
# Saved feature: RBP_SAMD4A_expr_aff_50
# Saved feature: RBP_SART3_expr_aff_50
# Saved feature: RBP_SF1_expr_aff_50
# Saved feature: RBP_SFPQ_expr_aff_50
# Saved feature: RBP_SNRNP70_expr_aff_50
# Saved feature: RBP_SNRPA_expr_aff_50
# Saved feature: RBP_SNRPB2_expr_aff_50
# Saved feature: RBP_SRP14_expr_aff_50
# Saved feature: RBP_SRP19_expr_aff_50
# Saved feature: RBP_SRP54_expr_aff_50
# Saved feature: RBP_SRP68_expr_aff_50
# Saved feature: RBP_SRSF1_expr_aff_50
# Saved feature: RBP_SRSF10_expr_aff_50
# Saved feature: RBP_SRSF11_expr_aff_50
# Saved feature: RBP_SRSF2_expr_aff_50
# Saved feature: RBP_SRSF3_expr_aff_50
# Saved feature: RBP_SRSF4_expr_aff_50
# Saved feature: RBP_SRSF5_expr_aff_50
# Saved feature: RBP_SRSF6_expr_aff_50
# Saved feature: RBP_SRSF7_expr_aff_50
# Saved feature: RBP_SRSF9_expr_aff_50
# Saved feature: RBP_SSB_expr_aff_50
# Saved feature: RBP_SUPV3L1_expr_aff_50
# Saved feature: RBP_SYNCRIP_expr_aff_50
# Saved feature: RBP_TARDBP_expr_aff_50
# Saved feature: RBP_TIA1_expr_aff_50
# Saved feature: RBP_TIAL1_expr_aff_50
# Saved feature: RBP_TRA2A_expr_aff_50
# Saved feature: RBP_TRA2B_expr_aff_50
# Saved feature: RBP_TUT1_expr_aff_50
# Saved feature: RBP_U2AF2_expr_aff_50
# Saved feature: RBP_XPO5_expr_aff_50
# Saved feature: RBP_YBX1_expr_aff_50
# Saved feature: RBP_YBX2_expr_aff_50
# Saved feature: RBP_YTHDC1_expr_aff_50
# Saved feature: RBP_ZC3H10_expr_aff_50
# Saved feature: RBP_ZCRB1_expr_aff_50
# Saved feature: RBP_ZFP36_expr_aff_50
# Saved feature: RBP_ZFP36L2_expr_aff_50
# Saved feature: RBP_ZNF346_expr_aff_50
# Saved feature: RBP_ZNF638_expr_aff_50
# Saved feature: RBP_ZRANB2_expr_aff_50
# Saved feature: RBP_interaction_total_50_expression
# Saved feature: RBP_diversity_global_50_expression
#
# --- Processing Affinity Features ---
# Calculating affinity features for 160 RBPs on 173191 rows...
# Computing RBPs: 100%|██████████| 160/160 [00:16<00:00,  9.83it/s]
# Assigning columns...
# Done. Added 160 affinity features.
# Saved feature: RBP_A1CF_aff_50
# Saved feature: RBP_ACO1_aff_50
# Saved feature: RBP_ADAR_aff_50
# Saved feature: RBP_AGO1_aff_50
# Saved feature: RBP_AGO2_aff_50
# Saved feature: RBP_AKAP1_aff_50
# Saved feature: RBP_ANKHD1_aff_50
# Saved feature: RBP_CELF1_aff_50
# Saved feature: RBP_CELF2_aff_50
# Saved feature: RBP_CELF4_aff_50
# Saved feature: RBP_CELF5_aff_50
# Saved feature: RBP_CELF6_aff_50
# Saved feature: RBP_CMTR1_aff_50
# Saved feature: RBP_CNOT4_aff_50
# Saved feature: RBP_CPEB1_aff_50
# Saved feature: RBP_CPEB2_aff_50
# Saved feature: RBP_CPEB4_aff_50
# Saved feature: RBP_CSTF2_aff_50
# Saved feature: RBP_DAZAP1_aff_50
# Saved feature: RBP_DDX19B_aff_50
# Saved feature: RBP_DDX58_aff_50
# Saved feature: RBP_DHX58_aff_50
# Saved feature: RBP_DHX9_aff_50
# Saved feature: RBP_EIF4A3_aff_50
# Saved feature: RBP_EIF4B_aff_50
# Saved feature: RBP_ELAVL1_aff_50
# Saved feature: RBP_ELAVL2_aff_50
# Saved feature: RBP_ELAVL3_aff_50
# Saved feature: RBP_ELAVL4_aff_50
# Saved feature: RBP_ENOX1_aff_50
# Saved feature: RBP_ERI1_aff_50
# Saved feature: RBP_ESRP1_aff_50
# Saved feature: RBP_ESRP2_aff_50
# Saved feature: RBP_F2_aff_50
# Saved feature: RBP_FMR1_aff_50
# Saved feature: RBP_FUS_aff_50
# Saved feature: RBP_FXR1_aff_50
# Saved feature: RBP_FXR2_aff_50
# Saved feature: RBP_G3BP1_aff_50
# Saved feature: RBP_G3BP2_aff_50
# Saved feature: RBP_GRSF1_aff_50
# Saved feature: RBP_HNRNPA0_aff_50
# Saved feature: RBP_HNRNPA1_aff_50
# Saved feature: RBP_HNRNPA1L2_aff_50
# Saved feature: RBP_HNRNPA2B1_aff_50
# Saved feature: RBP_HNRNPA3_aff_50
# Saved feature: RBP_HNRNPAB_aff_50
# Saved feature: RBP_HNRNPC_aff_50
# Saved feature: RBP_HNRNPCL1_aff_50
# Saved feature: RBP_HNRNPD_aff_50
# Saved feature: RBP_HNRNPDL_aff_50
# Saved feature: RBP_HNRNPF_aff_50
# Saved feature: RBP_HNRNPH1_aff_50
# Saved feature: RBP_HNRNPH2_aff_50
# Saved feature: RBP_HNRNPH3_aff_50
# Saved feature: RBP_HNRNPK_aff_50
# Saved feature: RBP_HNRNPL_aff_50
# Saved feature: RBP_HNRNPLL_aff_50
# Saved feature: RBP_HNRNPM_aff_50
# Saved feature: RBP_HNRNPU_aff_50
# Saved feature: RBP_IFIH1_aff_50
# Saved feature: RBP_IGF2BP1_aff_50
# Saved feature: RBP_IGF2BP2_aff_50
# Saved feature: RBP_IGF2BP3_aff_50
# Saved feature: RBP_IGHMBP2_aff_50
# Saved feature: RBP_KHDRBS1_aff_50
# Saved feature: RBP_KHDRBS2_aff_50
# Saved feature: RBP_KHDRBS3_aff_50
# Saved feature: RBP_KHSRP_aff_50
# Saved feature: RBP_LIN28A_aff_50
# Saved feature: RBP_MATR3_aff_50
# Saved feature: RBP_MBNL1_aff_50
# Saved feature: RBP_MSI1_aff_50
# Saved feature: RBP_NELFE_aff_50
# Saved feature: RBP_NONO_aff_50
# Saved feature: RBP_NOVA1_aff_50
# Saved feature: RBP_NOVA1 _aff_50
# Saved feature: RBP_NOVA2_aff_50
# Saved feature: RBP_NUDT21_aff_50
# Saved feature: RBP_NXF1_aff_50
# Saved feature: RBP_OAS1_aff_50
# Saved feature: RBP_PABPC1_aff_50
# Saved feature: RBP_PABPC3_aff_50
# Saved feature: RBP_PABPC4_aff_50
# Saved feature: RBP_PABPC5_aff_50
# Saved feature: RBP_PABPN1_aff_50
# Saved feature: RBP_PCBP1_aff_50
# Saved feature: RBP_PCBP2_aff_50
# Saved feature: RBP_PHAX_aff_50
# Saved feature: RBP_PIWIL1_aff_50
# Saved feature: RBP_PPIE_aff_50
# Saved feature: RBP_PPRC1_aff_50
# Saved feature: RBP_PTBP1_aff_50
# Saved feature: RBP_PTBP2_aff_50
# Saved feature: RBP_PUM1_aff_50
# Saved feature: RBP_PUM2_aff_50
# Saved feature: RBP_QKI_aff_50
# Saved feature: RBP_RALY_aff_50
# Saved feature: RBP_RBFOX1_aff_50
# Saved feature: RBP_RBFOX2_aff_50
# Saved feature: RBP_RBM14_aff_50
# Saved feature: RBP_RBM24_aff_50
# Saved feature: RBP_RBM25_aff_50
# Saved feature: RBP_RBM28_aff_50
# Saved feature: RBP_RBM3_aff_50
# Saved feature: RBP_RBM4_aff_50
# Saved feature: RBP_RBM41_aff_50
# Saved feature: RBP_RBM42_aff_50
# Saved feature: RBP_RBM46_aff_50
# Saved feature: RBP_RBM5_aff_50
# Saved feature: RBP_RBM6_aff_50
# Saved feature: RBP_RBM8A_aff_50
# Saved feature: RBP_RBMS1_aff_50
# Saved feature: RBP_RBMS3_aff_50
# Saved feature: RBP_RBMX_aff_50
# Saved feature: RBP_RBMY1A1_aff_50
# Saved feature: RBP_RC3H1_aff_50
# Saved feature: RBP_RNASEL_aff_50
# Saved feature: RBP_SAMD4A_aff_50
# Saved feature: RBP_SART3_aff_50
# Saved feature: RBP_SF1_aff_50
# Saved feature: RBP_SFPQ_aff_50
# Saved feature: RBP_SNRNP70_aff_50
# Saved feature: RBP_SNRPA_aff_50
# Saved feature: RBP_SNRPB2_aff_50
# Saved feature: RBP_SRP14_aff_50
# Saved feature: RBP_SRP19_aff_50
# Saved feature: RBP_SRP54_aff_50
# Saved feature: RBP_SRP68_aff_50
# Saved feature: RBP_SRSF1_aff_50
# Saved feature: RBP_SRSF10_aff_50
# Saved feature: RBP_SRSF11_aff_50
# Saved feature: RBP_SRSF2_aff_50
# Saved feature: RBP_SRSF3_aff_50
# Saved feature: RBP_SRSF4_aff_50
# Saved feature: RBP_SRSF5_aff_50
# Saved feature: RBP_SRSF6_aff_50
# Saved feature: RBP_SRSF7_aff_50
# Saved feature: RBP_SRSF9_aff_50
# Saved feature: RBP_SSB_aff_50
# Saved feature: RBP_SUPV3L1_aff_50
# Saved feature: RBP_SYNCRIP_aff_50
# Saved feature: RBP_TARDBP_aff_50
# Saved feature: RBP_TIA1_aff_50
# Saved feature: RBP_TIAL1_aff_50
# Saved feature: RBP_TRA2A_aff_50
# Saved feature: RBP_TRA2B_aff_50
# Saved feature: RBP_TUT1_aff_50
# Saved feature: RBP_U2AF2_aff_50
# Saved feature: RBP_XPO5_aff_50
# Saved feature: RBP_YBX1_aff_50
# Saved feature: RBP_YBX2_aff_50
# Saved feature: RBP_YTHDC1_aff_50
# Saved feature: RBP_ZC3H10_aff_50
# Saved feature: RBP_ZCRB1_aff_50
# Saved feature: RBP_ZFP36_aff_50
# Saved feature: RBP_ZFP36L2_aff_50
# Saved feature: RBP_ZNF346_aff_50
# Saved feature: RBP_ZNF638_aff_50
# Saved feature: RBP_ZRANB2_aff_50
# Saved feature: RBP_interaction_total_50_generic
# Saved feature: RBP_diversity_global_50_generic
#
# --- Processing Functional Features ---
# Saved feature: RBP_interaction_stabilizer_50
# Saved feature: RBP_interaction_destabilizer_50
# Saved feature: RBP_interaction_delta_stab_vs_destab_50
# Saved feature: RBP_interaction_ratio_stab_vs_destab_50
#
# --- Processing Regional Features ---
#
# --- Processing Region: LEFT ---
# 22 cells, 158 valid RBPs found.
# Calculating interaction features for 158 RBPs on 173191 rows...
# Computing Batches: 100%|██████████| 49/49 [00:03<00:00, 12.44it/s]
# Assigning columns...
# Done. Added 158 interaction features.
# Dropped 158 raw columns for left.
# Saved feature: RBP_interaction_total_left
# Saved feature: RBP_diversity_global_left
# Saved feature: RBP_interaction_stabilizer_left
# Saved feature: RBP_interaction_destabilizer_left
# Saved feature: RBP_interaction_delta_stab_vs_destab_left
# Saved feature: RBP_interaction_ratio_stab_vs_destab_left
#
# --- Processing Region: CORE ---
# 22 cells, 158 valid RBPs found.
# Calculating interaction features for 158 RBPs on 173191 rows...
# Computing Batches: 100%|██████████| 49/49 [00:02<00:00, 17.08it/s]
# Assigning columns...
# Done. Added 158 interaction features.
# Dropped 158 raw columns for core.
# Saved feature: RBP_interaction_total_core
# Saved feature: RBP_diversity_global_core
# Saved feature: RBP_interaction_stabilizer_core
# Saved feature: RBP_interaction_destabilizer_core
# Saved feature: RBP_interaction_delta_stab_vs_destab_core
# Saved feature: RBP_interaction_ratio_stab_vs_destab_core
#
# --- Processing Region: RIGHT ---
# 22 cells, 158 valid RBPs found.
# Calculating interaction features for 158 RBPs on 173191 rows...
# Computing Batches: 100%|██████████| 49/49 [00:03<00:00, 13.25it/s]
# Assigning columns...
# Done. Added 158 interaction features.
# Dropped 158 raw columns for right.
# Saved feature: RBP_interaction_total_right
# Saved feature: RBP_diversity_global_right
# Saved feature: RBP_interaction_stabilizer_right
# Saved feature: RBP_interaction_destabilizer_right
# Saved feature: RBP_interaction_delta_stab_vs_destab_right
# Saved feature: RBP_interaction_ratio_stab_vs_destab_right

# %%
calculator.calculate_off_target_specific()
# Out:
# Computing 9 specific off-target features...
# Running Specific Config: TopN=50, Cutoff=800
# Warning! GFAP is the target gene, score is set to 0 for ASO ACTACTAATAATAGCAATAG
# Warning! GFAP is the target gene, score is set to 0 for ASO GTAATCCATGAAAAGCACAG
# Warning! GFAP is the target gene, score is set to 0 for ASO GTGAAAGCTACTAACTTTAA
# Warning! GFAP is the target gene, score is set to 0 for ASO GTAGCAGTAATAATAATGGG
# Warning! GFAP is the target gene, score is set to 0 for ASO AAACGGAATTACATTCAGTT
# Warning! GFAP is the target gene, score is set to 0 for ASO ACTAACTTTAATTCTCTTTC
# Warning! GFAP is the target gene, score is set to 0 for ASO GCAGTAATAATAATGGGTAC
# Warning! GFAP is the target gene, score is set to 0 for ASO GAAAGCTACTAACTTTAATT
# Warning! GFAP is the target gene, score is set to 0 for ASO TACTTTTGAAAGCAATAGTG
# Warning! GFAP is the target gene, score is set to 0 for ASO CTTAGAACAGAACAGTATCA
# Warning! GFAP is the target gene, score is set to 0 for ASO ATAATAGCAATAGTAGCAGT
# Warning! GFAP is the target gene, score is set to 0 for ASO CACACTACATATAAGCTCTG
# Warning! GFAP is the target gene, score is set to 0 for ASO AACCAAAAGACAAAACAAGC
# Warning! GFAP is the target gene, score is set to 0 for ASO GGTACTTTTGAAAGCAATAG
# Warning! GFAP is the target gene, score is set to 0 for ASO GGCTTAGAACAGAACAGTAT
# Warning! GFAP is the target gene, score is set to 0 for ASO GCAAGCGAATGAATGAACAG
# Warning! GFAP is the target gene, score is set to 0 for ASO GTTTCCATAACAACAGGAAT
# Warning! GFAP is the target gene, score is set to 0 for ASO CCAAAAGACAAAACAAGCCT
# Warning! GFAP is the target gene, score is set to 0 for ASO AGTCATCAAACATCTAGTGA
# Warning! GFAP is the target gene, score is set to 0 for ASO CAAGGCTGAAAAAGACTCAG
# Warning! GFAP is the target gene, score is set to 0 for ASO AGAGAGAAAAATATAACACG
# Warning! GFAP is the target gene, score is set to 0 for ASO CCATTCAGTCATCAAACATC
# Warning! GFAP is the target gene, score is set to 0 for ASO CACATTCACTAATATTTAAC
# Warning! GFAP is the target gene, score is set to 0 for ASO CATTCACTAATATTTAACAT
# Warning! GFAP is the target gene, score is set to 0 for ASO TATTTAACATTAAGAGCAGG
# Warning! GFAP is the target gene, score is set to 0 for ASO TCAGTTTTACAATTGTAAAA
# Warning! GFAP is the target gene, score is set to 0 for ASO CAGCATTTGTCTTTATTTTT
# Warning! GFAP is the target gene, score is set to 0 for ASO TTAGTGCTCAATACACATAG
# Warning! GFAP is the target gene, score is set to 0 for ASO ACGGAATTACATTCAGTTTC
# Warning! GFAP is the target gene, score is set to 0 for ASO GCTTTTGAGATATCTTGTGA
# Warning! GFAP is the target gene, score is set to 0 for ASO GTTTAATGTACAGTTACTCT
# Warning! GFAP is the target gene, score is set to 0 for ASO AAGCTACTAACTTTAATTCT
# Warning! GFAP is the target gene, score is set to 0 for ASO GGATGAAAGAATAAAGCAGA
# Warning! GFAP is the target gene, score is set to 0 for ASO AGGGATGAAAGAATAAAGCA
# Warning! GFAP is the target gene, score is set to 0 for ASO GGAAACGGAATTACATTCAG
# Warning! GFAP is the target gene, score is set to 0 for ASO GGGAACATAAAACTTTATTC
# Warning! GFAP is the target gene, score is set to 0 for ASO TCCATAACAACAGGAATCAG
# Warning! GFAP is the target gene, score is set to 0 for ASO AAGGCTGAAAAAGACTCAGT
# Warning! GFAP is the target gene, score is set to 0 for ASO TACTAACTTTAATTCTCTTT
# Warning! GFAP is the target gene, score is set to 0 for ASO ACATAAAACTTTATTCACTG
# Warning! GFAP is the target gene, score is set to 0 for ASO ACATTCACTAATATTTAACA
# Warning! GFAP is the target gene, score is set to 0 for ASO GAAATGAATTTTATTATGAC
# Warning! GFAP is the target gene, score is set to 0 for ASO AGCTACTAACTTTAATTCTC
# Warning! GFAP is the target gene, score is set to 0 for ASO GGAAGTGAAAGCTACTAACT
# Warning! GFAP is the target gene, score is set to 0 for ASO GGGATGAAAGAATAAAGCAG
# Warning! GFAP is the target gene, score is set to 0 for ASO AGTTTCCATAACAACAGGAA
# Warning! GFAP is the target gene, score is set to 0 for ASO CCTCATAAAAACCAAAAGAC
# Warning! GFAP is the target gene, score is set to 0 for ASO ACCTCATAAAAACCAAAAGA
# Warning! GFAP is the target gene, score is set to 0 for ASO AGCAATAGTAGCAGTAATAA
# Warning! GFAP is the target gene, score is set to 0 for ASO CTTCATAGTAAGGTAATCCA
# Warning! GFAP is the target gene, score is set to 0 for ASO ACAGTGCAACAGTTAGGAGT
# Warning! GFAP is the target gene, score is set to 0 for ASO CTCATAAAAACCAAAAGACA
# Warning! GFAP is the target gene, score is set to 0 for ASO GCCTAATCAATATTGGTTGA
# Warning! GFAP is the target gene, score is set to 0 for ASO CAGCATCTTCAAGAGGATGA
# Warning! GFAP is the target gene, score is set to 0 for ASO CAAGTCAAAGTAACTTGATG
# Warning! GFAP is the target gene, score is set to 0 for ASO CTTAGCTAAGAATCATTTCA
# Warning! GFAP is the target gene, score is set to 0 for ASO TTCAGCATCTTCAAGAGGAT
# Warning! GFAP is the target gene, score is set to 0 for ASO GAACATAAAACTTTATTCAC
# Warning! GFAP is the target gene, score is set to 0 for ASO GTGGTGAAGAAAGTTCCAAG
# Warning! GFAP is the target gene, score is set to 0 for ASO ACCAAAAGACAAAACAAGCC
# Warning! GFAP is the target gene, score is set to 0 for ASO AAGTGGTGAAGAAAGTTCCA
# Warning! GFAP is the target gene, score is set to 0 for ASO TGACAAGCAGTTAAAAAAAC
# Warning! GFAP is the target gene, score is set to 0 for ASO GTCACATTCACTAATATTTA
# Warning! GFAP is the target gene, score is set to 0 for ASO TCACATTCACTAATATTTAAWarning! GFAP is the target gene, score is set to 0 for ASO TCAGTCATCAAACATCTAGT
#
# Warning! GFAP is the target gene, score is set to 0 for ASO GCTACTACTAATAATAGCAA
# Warning! GFAP is the target gene, score is set to 0 for ASO TTCATAGTAAGGTAATCCAT
# Warning! GFAP is the target gene, score is set to 0 for ASO CTCAGTTTTACAATTGTAAA
# Warning! GFAP is the target gene, score is set to 0 for ASO TGAAAGCTACTAACTTTAAT
# Warning! GFAP is the target gene, score is set to 0 for ASO CAGAAGAAGAGGAATTTTGT
# Warning! GFAP is the target gene, score is set to 0 for ASO AGTGCTCAATACACATAGGT
# Warning! GFAP is the target gene, score is set to 0 for ASO AGGGAACATAAAACTTTATT
# Warning! GFAP is the target gene, score is set to 0 for ASO AGCAGTAATAATAATGGGTA
# Warning! GFAP is the target gene, score is set to 0 for ASO TAGCAGTAATAATAATGGGT
# Warning! GFAP is the target gene, score is set to 0 for ASO GAGGAGACAATTAACTAAAA
# Warning! GFAP is the target gene, score is set to 0 for ASO ATATTTAACATTAAGAGCAG
# Warning! GFAP is the target gene, score is set to 0 for ASO CAAAAACAGAAAACACTCAG
# Warning! GFAP is the target gene, score is set to 0 for ASO GCTACTAACTTTAATTCTCT
# Warning! GFAP is the target gene, score is set to 0 for ASO AAGCGAATGAATGAACAGTG
# Warning! GFAP is the target gene, score is set to 0 for ASO TACTTCATAGTAAGGTAATC
# Warning! GFAP is the target gene, score is set to 0 for ASO AACGGAATTACATTCAGTTT
# Warning! GFAP is the target gene, score is set to 0 for ASO AAAGCTACTAACTTTAATTC
# Warning! GFAP is the target gene, score is set to 0 for ASO AGCAAGCGAATGAATGAACA
# Warning! GFAP is the target gene, score is set to 0 for ASO ACACTACATATAAGCTCTGA
# Warning! GFAP is the target gene, score is set to 0 for ASO CTACTAACTTTAATTCTCTT
# Warning! GFAP is the target gene, score is set to 0 for ASO AGTAGCAGTAATAATAATGG
# Warning! GFAP is the target gene, score is set to 0 for ASO ATTAGTGCTCAATACACATA
# Warning! GFAP is the target gene, score is set to 0 for ASO CAGTTTAATGTACAGTTACT
# Warning! GFAP is the target gene, score is set to 0 for ASO GGAGACAATTAACTAAAATA
# Warning! GFAP is the target gene, score is set to 0 for ASO CATATTAGTGCTCAATACAC
# Warning! GFAP is the target gene, score is set to 0 for ASO TACAATTGTAAAATAGGGCA
# Warning! GFAP is the target gene, score is set to 0 for ASO TTTCAGCATCTTCAAGAGGA
# Warning! GFAP is the target gene, score is set to 0 for ASO CGTCACATTCACTAATATTT
# Warning! GFAP is the target gene, score is set to 0 for ASO CCAATGCAAGTAAAAAGTAA
# Warning! GFAP is the target gene, score is set to 0 for ASO CTAATCAATATTGGTTGAAT
# Warning! GFAP is the target gene, score is set to 0 for ASO GAAAGTGGTGAAGAAAGTTC
# Warning! GFAP is the target gene, score is set to 0 for ASO AGCATTTGTCTTTATTTTTC
# Warning! GFAP is the target gene, score is set to 0 for ASO CCATCATGACAACTTGAACG
# Warning! GFAP is the target gene, score is set to 0 for ASO AGTGAAAGCTACTAACTTTA
# Warning! GFAP is the target gene, score is set to 0 for ASO AAGTGAAAGCTACTAACTTT
# Warning! GFAP is the target gene, score is set to 0 for ASO TAGTGCTCAATACACATAGG
# Warning! GFAP is the target gene, score is set to 0 for ASO TTAGCTAAGAATCATTTCAG
# Warning! GFAP is the target gene, score is set to 0 for ASO AGCCATGAATGAAACACAGG
# Warning! GFAP is the target gene, score is set to 0 for ASO GATGAAAGAATAAAGCAGAG
# Warning! GFAP is the target gene, score is set to 0 for ASO CAGGGAACATAAAACTTTAT
# Warning! GFAP is the target gene, score is set to 0 for ASO TCATCAAACATCTAGTGACT
# Warning! GFAP is the target gene, score is set to 0 for ASO AAATGAATTTTATTATGACC
# Warning! GFAP is the target gene, score is set to 0 for ASO GGCTTTTGAGATATCTTGTG
# Warning! GFAP is the target gene, score is set to 0 for ASO GGAACATAAAACTTTATTCA
# Warning! SERPINA1 is the target gene, score is set to 0 for ASO TTCTTTAATGTCATC
# Warning! SERPINA1 is the target gene, score is set to 0 for ASO CTTCTTTAATGTCAT
# Saved feature: off_target_score_specific_ARTM_n50_c800
# Running Specific Config: TopN=50, Cutoff=1000
# Warning! PFN1 is the target gene, score is set to 0 for ASO GCGTCTTGTCAGTCTTGGTG
# Warning! PFN1 is the target gene, score is set to 0 for ASO GTGACAGTGACATTGAAGGT
# Warning! PFN1 is the target gene, score is set to 0 for ASO CCATGAGGTTGTCGATGTAG
# Warning! PFN1 is the target gene, score is set to 0 for ASO TGGTACGAAGATCCATGCTA
# Warning! GFAP is the target gene, score is set to 0 for ASO GCATTTGTCTTTATTTTTCC
# Warning! GFAP is the target gene, score is set to 0 for ASO TGCTCAATACACATAGGTCC
# Warning! GFAP is the target gene, score is set to 0 for ASO CCATCATGAGTATGAGAACC
# Warning! GFAP is the target gene, score is set to 0 for ASO TACTTTTCTTGATAGTAACC
# Warning! GFAP is the target gene, score is set to 0 for ASO GCACGGTATTGAAATCAGGA
# Warning! GFAP is the target gene, score is set to 0 for ASO TTGTCTTTATTTTTCCTCAG
# Warning! GFAP is the target gene, score is set to 0 for ASO GTAATCCATGAAAAGCACAG
# Warning! GFAP is the target gene, score is set to 0 for ASO CTCTGGTGAAAGTCAGTCACWarning! GFAP is the target gene, score is set to 0 for ASO ACCTTTTGAAATGAATTTTA
#
# Warning! GFAP is the target gene, score is set to 0 for ASO TATGAGAACCTATGCAACCG
# Warning! GFAP is the target gene, score is set to 0 for ASO GGCAGATGTCAAGCTCTCAC
# Warning! GFAP is the target gene, score is set to 0 for ASO GGAATTACATTCAGTTTCCT
# Warning! GFAP is the target gene, score is set to 0 for ASO GTGAAAGCTACTAACTTTAA
# Warning! GFAP is the target gene, score is set to 0 for ASO GTAGCAGTAATAATAATGGG
# Warning! GFAP is the target gene, score is set to 0 for ASO TCTCAGTTGCAATCTCTGTG
# Warning! GFAP is the target gene, score is set to 0 for ASO AGAGAGTGTGTATTAGGATC
# Warning! GFAP is the target gene, score is set to 0 for ASO TTGCCTTAACTCATTACTAAWarning! GFAP is the target gene, score is set to 0 for ASO AGGTCTGCAAACTTGGAGCG
#
# Warning! GFAP is the target gene, score is set to 0 for ASO ATTACATTCAGTTTCCTTGC
# Warning! GFAP is the target gene, score is set to 0 for ASO AGAGTTGGAAGTGAAAGCTA
# Warning! GFAP is the target gene, score is set to 0 for ASO AAACGGAATTACATTCAGTT
# Warning! GFAP is the target gene, score is set to 0 for ASO GGTGAGAGAAGCGGTACCAG
# Warning! GFAP is the target gene, score is set to 0 for ASO GCTCTCTCATCTGTCAAAGA
# Warning! GFAP is the target gene, score is set to 0 for ASO TCTCTCAGTTGCAATCTCTG
# Warning! GFAP is the target gene, score is set to 0 for ASO TGAAGGCACACATGCATGTC
# Warning! GFAP is the target gene, score is set to 0 for ASO ACTAACTTTAATTCTCTTTC
# Warning! GFAP is the target gene, score is set to 0 for ASO GGTGAGATAACACTGGGAAA
# Warning! GFAP is the target gene, score is set to 0 for ASO GCAGTAATAATAATGGGTAC
# Warning! GFAP is the target gene, score is set to 0 for ASO CCTTAGAACAGCCTATGGAG
# Warning! GFAP is the target gene, score is set to 0 for ASO CAGGGCTTAGAACAGAACAG
# Warning! GFAP is the target gene, score is set to 0 for ASO TACTTTTGAAAGCAATAGTG
# Warning! GFAP is the target gene, score is set to 0 for ASO ACAGAAAACACTCAGAAGGG
# Warning! GFAP is the target gene, score is set to 0 for ASO CTCTCATCTGTCAAAGAACA
# Warning! GFAP is the target gene, score is set to 0 for ASO CTTAGAACAGAACAGTATCA
# Warning! GFAP is the target gene, score is set to 0 for ASO ACAGTTTCCATAACAACAGG
# Warning! GFAP is the target gene, score is set to 0 for ASO TAATCCATGAAAAGCACAGG
# Warning! GFAP is the target gene, score is set to 0 for ASO CTTACTTTTCTTGATAGTAA
# Warning! GFAP is the target gene, score is set to 0 for ASO TGGTAGAGGCTCAGTAACCC
# Warning! GFAP is the target gene, score is set to 0 for ASO CTCATCTGTCAAAGAACAGC
# Warning! GFAP is the target gene, score is set to 0 for ASO TCGGCTCTCTCATCTGTCAA
# Warning! GFAP is the target gene, score is set to 0 for ASO GCCTTAACTCATTACTAAGG
# Warning! GFAP is the target gene, score is set to 0 for ASO GCAACAGTTTCCATAACAAC
# Warning! GFAP is the target gene, score is set to 0 for ASO CTGTCAAAGAACAGCACCTA
# Warning! GFAP is the target gene, score is set to 0 for ASO GGTACTTTTGAAAGCAATAG
# Warning! GFAP is the target gene, score is set to 0 for ASO CACACTACATATAAGCTCTG
# Warning! GFAP is the target gene, score is set to 0 for ASO AGAGTTGGAAATCCAACTCT
# Warning! GFAP is the target gene, score is set to 0 for ASO GGCTTAGAACAGAACAGTAT
# Warning! GFAP is the target gene, score is set to 0 for ASO ATCAGCTACTACTAATAATA
# Warning! GFAP is the target gene, score is set to 0 for ASO ATCCATTCAGTCATCAAACA
# Warning! GFAP is the target gene, score is set to 0 for ASO CAACTCTACCACTTAGGAGC
# Warning! GFAP is the target gene, score is set to 0 for ASO GAGGCTCAGTAACCCAAAAC
# Warning! GFAP is the target gene, score is set to 0 for ASO GTGAGGAGTCCAATCTTGGC
# Warning! GFAP is the target gene, score is set to 0 for ASO GTTTCCATAACAACAGGAAT
# Warning! GFAP is the target gene, score is set to 0 for ASO CAGTAACCCAAAACAGACTG
# Warning! GFAP is the target gene, score is set to 0 for ASO GTGGACTGAGACACTTGAGT
# Warning! GFAP is the target gene, score is set to 0 for ASO CGCAGGTCAAGGACTGCAAC
# Warning! GFAP is the target gene, score is set to 0 for ASO GGTGAAGAAAGTTCCAAGGA
# Warning! GFAP is the target gene, score is set to 0 for ASO CTGGCAACAGTTTCCATAAC
# Warning! GFAP is the target gene, score is set to 0 for ASO GCAAGCGAATGAATGAACAG
# Warning! GFAP is the target gene, score is set to 0 for ASO ATCTTCAAGAGGATGAGTCA
# Warning! GFAP is the target gene, score is set to 0 for ASO GGTATGACACAGCAAGGAAGWarning! GFAP is the target gene, score is set to 0 for ASO CCAAAAGACAAAACAAGCCT
#
# Warning! GFAP is the target gene, score is set to 0 for ASO AAACTCAAAGGCACAGTTCC
# Warning! GFAP is the target gene, score is set to 0 for ASO GTTTCTTGTTAGTTGGAGTT
# Warning! GFAP is the target gene, score is set to 0 for ASO CAGCTACTACTAATAATAGC
# Warning! GFAP is the target gene, score is set to 0 for ASO GCCTCAGTTTTACAATTGTA
# Warning! GFAP is the target gene, score is set to 0 for ASO TTGTGTGTGAGTAAGAAGGG
# Warning! GFAP is the target gene, score is set to 0 for ASO GTCAGCAAGCGAATGAATGA
# Warning! GFAP is the target gene, score is set to 0 for ASO TAAATATTCTAGTCCAGAAG
# Warning! GFAP is the target gene, score is set to 0 for ASO CAAGGCTGAAAAAGACTCAG
# Warning! GFAP is the target gene, score is set to 0 for ASO GCCTCACATCACATCCTTGT
# Warning! GFAP is the target gene, score is set to 0 for ASO CGCAGCATTTGTCTTTATTT
# Warning! GFAP is the target gene, score is set to 0 for ASO TAACCCAAAACAGACTGGCA
# Warning! GFAP is the target gene, score is set to 0 for ASO AGTCATCAAACATCTAGTGA
# Warning! GFAP is the target gene, score is set to 0 for ASO GTATTACCTCTACTAGTCAG
# Warning! GFAP is the target gene, score is set to 0 for ASO CAGGAAAGTCTAACTCCATC
# Warning! GFAP is the target gene, score is set to 0 for ASO TATTCTAGTCCAGAAGAAGA
# Warning! GFAP is the target gene, score is set to 0 for ASO GACACTTGAGTCATCGCTCA
# Warning! GFAP is the target gene, score is set to 0 for ASO CCATTCAGTCATCAAACATC
# Warning! GFAP is the target gene, score is set to 0 for ASO AGGCTTTTGAGATATCTTGT
# Warning! GFAP is the target gene, score is set to 0 for ASO CAAGTGCTGAGAATCAAGCTWarning! GFAP is the target gene, score is set to 0 for ASO GTGAAGAAAGTTCCAAGGAG
#
# Warning! GFAP is the target gene, score is set to 0 for ASO TTACCTCTACTAGTCAGCCT
# Warning! GFAP is the target gene, score is set to 0 for ASO GGCGCATGTCTATCTGAAGG
# Warning! GFAP is the target gene, score is set to 0 for ASO TTGTGAGGCTTTTGAGATAT
# Warning! GFAP is the target gene, score is set to 0 for ASO AAAGGCTGTTAAACATGTGG
# Warning! GFAP is the target gene, score is set to 0 for ASO CCTGTGACTATCTAGGATTT
# Warning! GFAP is the target gene, score is set to 0 for ASO ATCTGTCAAAGAACAGCACC
# Warning! GFAP is the target gene, score is set to 0 for ASO CACCTACTTCATAGTAAGGT
# Warning! GFAP is the target gene, score is set to 0 for ASO GGATCTGCACACAAGGCTGA
# Warning! GFAP is the target gene, score is set to 0 for ASO GTGTGTGAGTAAGAAGGGAC
# Warning! GFAP is the target gene, score is set to 0 for ASO TTTATCTGTGCTTTAGTGACWarning! GFAP is the target gene, score is set to 0 for ASO CAGCATTTGTCTTTATTTTT
#
# Warning! GFAP is the target gene, score is set to 0 for ASO TAGAGTTGGAAATCCAACTCWarning! GFAP is the target gene, score is set to 0 for ASO CTGAACTGAGTCAGCACTGA
#
# Warning! GFAP is the target gene, score is set to 0 for ASO GTTGGAAATCCAACTCTACC
# Warning! GFAP is the target gene, score is set to 0 for ASO ACGGTATTGAAATCAGGAGA
# Warning! GFAP is the target gene, score is set to 0 for ASO TGAGGCCTAATCAATATTGG
# Warning! GFAP is the target gene, score is set to 0 for ASO CAGAGCTCAAGAAGTCCCAA
# Warning! GFAP is the target gene, score is set to 0 for ASO TATTTAACATTAAGAGCAGG
# Warning! GFAP is the target gene, score is set to 0 for ASO AAACTTTATTCACTGCAAGA
# Warning! GFAP is the target gene, score is set to 0 for ASO AGGCTCAGTAACCCAAAACA
# Warning! GFAP is the target gene, score is set to 0 for ASO TGAGGCTTTTGAGATATCTT
# Warning! GFAP is the target gene, score is set to 0 for ASO GCGCAGCATTTGTCTTTATT
# Warning! GFAP is the target gene, score is set to 0 for ASO AATATTCTAGTCCAGAAGAA
# Warning! GFAP is the target gene, score is set to 0 for ASO TATTGTGAGGCTTTTGAGAT
# Warning! GFAP is the target gene, score is set to 0 for ASO GTATTGTGAGGCTTTTGAGA
# Warning! GFAP is the target gene, score is set to 0 for ASO TGACTATCTAGGATTTGGCA
# Warning! GFAP is the target gene, score is set to 0 for ASO GCTTTTGAGATATCTTGTGA
# Warning! GFAP is the target gene, score is set to 0 for ASO ATTTAACATTAAGAGCAGGG
# Warning! GFAP is the target gene, score is set to 0 for ASO GTTTAATGTACAGTTACTCT
# Warning! GFAP is the target gene, score is set to 0 for ASO TATTACCTCTACTAGTCAGC
# Warning! GFAP is the target gene, score is set to 0 for ASO ACGGAATTACATTCAGTTTC
# Warning! GFAP is the target gene, score is set to 0 for ASO CACTACCTAGAATACTGGGT
# Warning! GFAP is the target gene, score is set to 0 for ASO TTAGTGCTCAATACACATAG
# Warning! GFAP is the target gene, score is set to 0 for ASO ATGAGAACCTATGCAACCGAWarning! GFAP is the target gene, score is set to 0 for ASO GAATTTTGTTCCTTAGCTAA
#
# Warning! GFAP is the target gene, score is set to 0 for ASO CAGAAAACACTCAGAAGGGC
# Warning! GFAP is the target gene, score is set to 0 for ASO TGTTCCTTAGCTAAGAATCA
# Warning! GFAP is the target gene, score is set to 0 for ASO CATTTATCTGTGCTTTAGTG
# Warning! GFAP is the target gene, score is set to 0 for ASO AAGCTACTAACTTTAATTCT
# Warning! GFAP is the target gene, score is set to 0 for ASO GAGACATGCATATCTAGTGG
# Warning! GFAP is the target gene, score is set to 0 for ASO AGAAAACACTCAGAAGGGCA
# Warning! GFAP is the target gene, score is set to 0 for ASO TTTAACATTAAGAGCAGGGA
# Warning! GFAP is the target gene, score is set to 0 for ASO TGGCAGTATTACCTCTACTA
# Warning! GFAP is the target gene, score is set to 0 for ASO GGCTCAGAATAGGTGAGCTC
# Warning! GFAP is the target gene, score is set to 0 for ASO CGTTCCATTTACAATCTGGT
# Warning! GFAP is the target gene, score is set to 0 for ASO TATCTAGGATTTGGCAGTAT
# Warning! GFAP is the target gene, score is set to 0 for ASO AAGGCTGAAAAAGACTCAGT
# Warning! GFAP is the target gene, score is set to 0 for ASO CGGTATTGAAATCAGGAGAC
# Warning! GFAP is the target gene, score is set to 0 for ASO TAACTTTAATTCTCTTTCTC
# Warning! GFAP is the target gene, score is set to 0 for ASO GGTGGTGAGATAACACTGGG
# Warning! GFAP is the target gene, score is set to 0 for ASO GGAAACGGAATTACATTCAG
# Warning! GFAP is the target gene, score is set to 0 for ASO GTTCCATTTACAATCTGGTG
# Warning! GFAP is the target gene, score is set to 0 for ASO TTACCACTAACAAGCTCTGC
# Warning! GFAP is the target gene, score is set to 0 for ASO CAGTGCAACAGTTAGGAGTT
# Warning! GFAP is the target gene, score is set to 0 for ASO AGAGCAGGGAACATAAAACT
# Warning! GFAP is the target gene, score is set to 0 for ASO TCCATAACAACAGGAATCAG
# Warning! GFAP is the target gene, score is set to 0 for ASO TTACTTTTCTTGATAGTAAC
# Warning! GFAP is the target gene, score is set to 0 for ASO TGGCAACAGTTTCCATAACA
# Warning! GFAP is the target gene, score is set to 0 for ASO ACATAAAACTTTATTCACTG
# Warning! GFAP is the target gene, score is set to 0 for ASO GAGTATGAGAACCTATGCAA
# Warning! GFAP is the target gene, score is set to 0 for ASO AATTACATTCAGTTTCCTTG
# Warning! GFAP is the target gene, score is set to 0 for ASO GCACAGTGCAACAGTTAGGA
# Warning! GFAP is the target gene, score is set to 0 for ASO CTGTGCAAGTCAAAGTAACT
# Warning! GFAP is the target gene, score is set to 0 for ASO GCAGCATTTGTCTTTATTTT
# Warning! GFAP is the target gene, score is set to 0 for ASO GAACCTATGCAACCGAGCAG
# Warning! GFAP is the target gene, score is set to 0 for ASO ATGAATTTTATTATGACCAC
# Warning! GFAP is the target gene, score is set to 0 for ASO TACTAACTTTAATTCTCTTT
# Warning! GFAP is the target gene, score is set to 0 for ASO GAAAACACTCAGAAGGGCAG
# Warning! GFAP is the target gene, score is set to 0 for ASO ACTTGAAGGCACACATGCAT
# Warning! GFAP is the target gene, score is set to 0 for ASO TCCACAAGCATACACTCACT
# Warning! GFAP is the target gene, score is set to 0 for ASO GTGGTGAGATAACACTGGGA
# Warning! GFAP is the target gene, score is set to 0 for ASO AGCTACTAACTTTAATTCTC
# Warning! GFAP is the target gene, score is set to 0 for ASO AACAGAACAGTATCAGCTAC
# Warning! GFAP is the target gene, score is set to 0 for ASO AGTCAAAGTAACTTGATGGG
# Warning! GFAP is the target gene, score is set to 0 for ASO CTCTCTCAGTTGCAATCTCT
# Warning! GFAP is the target gene, score is set to 0 for ASO CCTTAACTCATTACTAAGGT
# Warning! GFAP is the target gene, score is set to 0 for ASO GTAAGGTAATCCATGAAAAG
# Warning! GFAP is the target gene, score is set to 0 for ASO GTTGGAAGTGAAAGCTACTA
# Warning! GFAP is the target gene, score is set to 0 for ASO TTGAAGGCACACATGCATGT
# Warning! GFAP is the target gene, score is set to 0 for ASO GGAAGTGAAAGCTACTAACT
# Warning! GFAP is the target gene, score is set to 0 for ASO GTCTTTCTGTTTGTCTTTCA
# Warning! GFAP is the target gene, score is set to 0 for ASO GTGAGTTTCTTGTTAGTTGG
# Warning! GFAP is the target gene, score is set to 0 for ASO TGGGTACTTTTGAAAGCAAT
# Warning! GFAP is the target gene, score is set to 0 for ASO CCTCATAAAAACCAAAAGAC
# Warning! GFAP is the target gene, score is set to 0 for ASO CATAACAACAGGAATCAGGG
# Warning! GFAP is the target gene, score is set to 0 for ASO TTCTCTTGTACAGAGCAAGA
# Warning! GFAP is the target gene, score is set to 0 for ASO TGAGATAACACTGGGAAAGC
# Warning! GFAP is the target gene, score is set to 0 for ASO CTGCCAATCTCTGTTTCTCT
# Warning! GFAP is the target gene, score is set to 0 for ASO GGCAGCATAGGGATATCCCA
# Warning! GFAP is the target gene, score is set to 0 for ASO CTTAGAACAGCCTATGGAGG
# Warning! GFAP is the target gene, score is set to 0 for ASO CAGAACAGTATCAGCTACTA
# Warning! GFAP is the target gene, score is set to 0 for ASO TAGGCAGCATAGGGATATCC
# Warning! GFAP is the target gene, score is set to 0 for ASO AGTTAGGAGTTCACACAGAC
# Warning! GFAP is the target gene, score is set to 0 for ASO ACTGAGACACTTGAGTCATC
# Warning! GFAP is the target gene, score is set to 0 for ASO TTTTGCCTTAACTCATTACT
# Warning! GFAP is the target gene, score is set to 0 for ASO CAGTATCAGCTACTACTAAT
# Warning! GFAP is the target gene, score is set to 0 for ASO TGGAAATCCAACTCTACCAC
# Warning! GFAP is the target gene, score is set to 0 for ASO GGACTGAGACACTTGAGTCA
# Warning! GFAP is the target gene, score is set to 0 for ASO GGGTGAGTTTCTTGTTAGTT
# Warning! GFAP is the target gene, score is set to 0 for ASO GGCATATGGTAGAGGCTCAG
# Warning! GFAP is the target gene, score is set to 0 for ASO TGGTGAGATAACACTGGGAA
# Warning! GFAP is the target gene, score is set to 0 for ASO GAGGCTTTTGAGATATCTTG
# Warning! GFAP is the target gene, score is set to 0 for ASO AAGGTAATCCATGAAAAGCA
# Warning! GFAP is the target gene, score is set to 0 for ASO TTCTCGAATCTGCAGGTTGG
# Warning! GFAP is the target gene, score is set to 0 for ASO AGAACAGTATCAGCTACTAC
# Warning! GFAP is the target gene, score is set to 0 for ASO GGCTCAGTAACCCAAAACAG
# Warning! GFAP is the target gene, score is set to 0 for ASO TAATGGGTACTTTTGAAAGC
# Warning! GFAP is the target gene, score is set to 0 for ASO AGTTTCCATAACAACAGGAA
# Warning! GFAP is the target gene, score is set to 0 for ASO ACAGTGCAACAGTTAGGAGT
# Warning! GFAP is the target gene, score is set to 0 for ASO ATTGTGAGGCTTTTGAGATA
# Warning! GFAP is the target gene, score is set to 0 for ASO GTTTCAGCATCTTCAAGAGG
# Warning! GFAP is the target gene, score is set to 0 for ASO TTTGCCTTAACTCATTACTA
# Warning! GFAP is the target gene, score is set to 0 for ASO GGAAATCCAACTCTACCACT
# Warning! GFAP is the target gene, score is set to 0 for ASO CTGTTTCAGCATCTTCAAGA
# Warning! GFAP is the target gene, score is set to 0 for ASO GGGCTTAGAACAGAACAGTA
# Warning! GFAP is the target gene, score is set to 0 for ASO CGGCTCTCTCATCTGTCAAA
# Warning! GFAP is the target gene, score is set to 0 for ASO GGCAACAGTTTCCATAACAAWarning! GFAP is the target gene, score is set to 0 for ASO CTTCATAGTAAGGTAATCCA
#
# Warning! GFAP is the target gene, score is set to 0 for ASO GCTCAGTAACCCAAAACAGA
# Warning! GFAP is the target gene, score is set to 0 for ASO AGCTACTACTAATAATAGCA
# Warning! GFAP is the target gene, score is set to 0 for ASO TGAGGAAACTCAAAGGCACAWarning! GFAP is the target gene, score is set to 0 for ASO CTGGTATGACACAGCAAGGA
#
# Warning! GFAP is the target gene, score is set to 0 for ASO TAGAGGCTCAGTAACCCAAA
# Warning! GFAP is the target gene, score is set to 0 for ASO ATTTTGTGTGTGAGTAAGAA
# Warning! GFAP is the target gene, score is set to 0 for ASO AGAAATGGGACAAAGTCATG
# Warning! GFAP is the target gene, score is set to 0 for ASO GGAAACTCAAAGGCACAGTT
# Warning! GFAP is the target gene, score is set to 0 for ASO CTACCTAGAATACTGGGTAC
# Warning! GFAP is the target gene, score is set to 0 for ASO TAGTGTCTTTCTGTTTGTCT
# Warning! GFAP is the target gene, score is set to 0 for ASO ATCTTAGACTGATCAGGGTC
# Warning! GFAP is the target gene, score is set to 0 for ASO CACTACATATAAGCTCTGAG
# Warning! GFAP is the target gene, score is set to 0 for ASO TTAACTCATTACTAAGGTGC
# Warning! GFAP is the target gene, score is set to 0 for ASO GCAGCATAGGGATATCCCAC
# Warning! GFAP is the target gene, score is set to 0 for ASO CTGAGACACTTGAGTCATCGWarning! GFAP is the target gene, score is set to 0 for ASO GAGTTTCTTGTTAGTTGGAG
#
# Warning! GFAP is the target gene, score is set to 0 for ASO GCCTAATCAATATTGGTTGA
# Warning! GFAP is the target gene, score is set to 0 for ASO AGGCCTTTAGAAATGGGACAWarning! GFAP is the target gene, score is set to 0 for ASO TCCTCATTCTAACGCAAGCT
#
# Warning! GFAP is the target gene, score is set to 0 for ASO GTATCAGCTACTACTAATAA
# Warning! GFAP is the target gene, score is set to 0 for ASO CCATTTACAATCTGGTGAGC
# Warning! GFAP is the target gene, score is set to 0 for ASO CCTGGGAAAATGACGCAGTC
# Warning! GFAP is the target gene, score is set to 0 for ASO TCCAACTCTACCACTTAGGA
# Warning! GFAP is the target gene, score is set to 0 for ASO CAGCATCTTCAAGAGGATGA
# Warning! GFAP is the target gene, score is set to 0 for ASO CGAATGAATGAACAGTGCCA
# Warning! GFAP is the target gene, score is set to 0 for ASO CTGAAGGAAGATGGAAAAGG
# Warning! GFAP is the target gene, score is set to 0 for ASO TATCAGCTACTACTAATAAT
# Warning! GFAP is the target gene, score is set to 0 for ASO CTCAGTAACCCAAAACAGAC
# Warning! GFAP is the target gene, score is set to 0 for ASO TTCAGCATCTTCAAGAGGAT
# Warning! GFAP is the target gene, score is set to 0 for ASO CTGCTCAGTCAAAGCAGAGT
# Warning! GFAP is the target gene, score is set to 0 for ASO CCAACTCTACCACTTAGGAG
# Warning! GFAP is the target gene, score is set to 0 for ASO CTCTGAACTGAGTCAGCACTWarning! GFAP is the target gene, score is set to 0 for ASO CACAGGCTCAGAATAGGTGA
#
# Warning! GFAP is the target gene, score is set to 0 for ASO TAATGTACAGTTACTCTGTA
# Warning! GFAP is the target gene, score is set to 0 for ASO TGGTATGACACAGCAAGGAA
# Warning! GFAP is the target gene, score is set to 0 for ASO ACCAAAAGACAAAACAAGCC
# Warning! GFAP is the target gene, score is set to 0 for ASO ACAAGGCTGAAAAAGACTCA
# Warning! GFAP is the target gene, score is set to 0 for ASO CAAGTCAAAGTAACTTGATG
# Warning! GFAP is the target gene, score is set to 0 for ASO ATAAAACTTTATTCACTGCA
# Warning! GFAP is the target gene, score is set to 0 for ASO TCAGTAACCCAAAACAGACT
# Warning! GFAP is the target gene, score is set to 0 for ASO CAACAGTTTCCATAACAACA
# Warning! GFAP is the target gene, score is set to 0 for ASO AGGGAGCAAGATGAGCTCTA
# Warning! GFAP is the target gene, score is set to 0 for ASO TTTTGTGTGTGAGTAAGAAG
# Warning! GFAP is the target gene, score is set to 0 for ASO CTTAGCTAAGAATCATTTCA
# Warning! GFAP is the target gene, score is set to 0 for ASO GAGGAAACTCAAAGGCACAG
# Warning! GFAP is the target gene, score is set to 0 for ASO CTGAAGGGAGCAAGATGAGC
# Warning! GFAP is the target gene, score is set to 0 for ASO GCCAGGAAAGTCTAACTCCAWarning! GFAP is the target gene, score is set to 0 for ASO TTAATGTACAGTTACTCTGT
#
# Warning! GFAP is the target gene, score is set to 0 for ASO TCCTAAATATTCTAGTCCAG
# Warning! GFAP is the target gene, score is set to 0 for ASO GGTGAGGAGTCCAATCTTGG
# Warning! GFAP is the target gene, score is set to 0 for ASO GCAGGGAACATAAAACTTTA
# Warning! GFAP is the target gene, score is set to 0 for ASO AAGTGCTGAGAATCAAGCTC
# Warning! GFAP is the target gene, score is set to 0 for ASO GTCACATTCACTAATATTTA
# Warning! GFAP is the target gene, score is set to 0 for ASO GCTACTACTAATAATAGCAA
# Warning! GFAP is the target gene, score is set to 0 for ASO CACAAGCATACACTCACTGT
# Warning! GFAP is the target gene, score is set to 0 for ASO AAATGGGACAAAGTCATGCC
# Warning! GFAP is the target gene, score is set to 0 for ASO TCTTAGACTGATCAGGGTCA
# Warning! GFAP is the target gene, score is set to 0 for ASO AAGTGGTGAAGAAAGTTCCA
# Warning! GFAP is the target gene, score is set to 0 for ASO GAGTATGCCTCTTAGTTTGG
# Warning! GFAP is the target gene, score is set to 0 for ASO TTCGGCTCTCTCATCTGTCA
# Warning! GFAP is the target gene, score is set to 0 for ASO TTTGGCAGTATTACCTCTAC
# Warning! GFAP is the target gene, score is set to 0 for ASO CATCATGACAACTTGAACGC
# Warning! GFAP is the target gene, score is set to 0 for ASO AGCAGGGAACATAAAACTTT
# Warning! GFAP is the target gene, score is set to 0 for ASO ATTTGTCTTTATTTTTCCTC
# Warning! GFAP is the target gene, score is set to 0 for ASO TGGTCAGCAAGCGAATGAAT
# Warning! GFAP is the target gene, score is set to 0 for ASO GTGGTGAAGAAAGTTCCAAG
# Warning! GFAP is the target gene, score is set to 0 for ASO GCAGTATTACCTCTACTAGT
# Warning! GFAP is the target gene, score is set to 0 for ASO CCACACTACATATAAGCTCT
# Warning! GFAP is the target gene, score is set to 0 for ASO AAGAGGCCTTTAGAAATGGG
# Warning! GFAP is the target gene, score is set to 0 for ASO TCAGTCATCAAACATCTAGT
# Warning! GFAP is the target gene, score is set to 0 for ASO GCTAAGAATCATTTCAGGGC
# Warning! GFAP is the target gene, score is set to 0 for ASO TGTGTGTGAGTAAGAAGGGA
# Warning! GFAP is the target gene, score is set to 0 for ASO TCTGAACTGAGTCAGCACTG
# Warning! GFAP is the target gene, score is set to 0 for ASO CTAAATATTCTAGTCCAGAA
# Warning! GFAP is the target gene, score is set to 0 for ASO CTCAGTTTTACAATTGTAAA
# Warning! GFAP is the target gene, score is set to 0 for ASO AAAACTTTATTCACTGCAAGWarning! GFAP is the target gene, score is set to 0 for ASO ACAATTGTAAAATAGGGCAC
#
# Warning! GFAP is the target gene, score is set to 0 for ASO AAGGCACACATGCATGTCCT
# Warning! GFAP is the target gene, score is set to 0 for ASO CCATCCATTCAGTCATCAAA
# Warning! GFAP is the target gene, score is set to 0 for ASO TTTGTTCCTTAGCTAAGAAT
# Warning! GFAP is the target gene, score is set to 0 for ASO AGCACGGTATTGAAATCAGG
# Warning! GFAP is the target gene, score is set to 0 for ASO GAAGGCACACATGCATGTCC
# Warning! GFAP is the target gene, score is set to 0 for ASO AGCTAAGAATCATTTCAGGG
# Warning! GFAP is the target gene, score is set to 0 for ASO GGCAGTATTACCTCTACTAG
# Warning! GFAP is the target gene, score is set to 0 for ASO CTGAGGACACTTGAATACCT
# Warning! GFAP is the target gene, score is set to 0 for ASO CTGATGCTGAATTAAGTCCT
# Warning! GFAP is the target gene, score is set to 0 for ASO AGTATGAGAACCTATGCAAC
# Warning! GFAP is the target gene, score is set to 0 for ASO ACTATCTAGGATTTGGCAGT
# Warning! GFAP is the target gene, score is set to 0 for ASO AATAATGGGTACTTTTGAAA
# Warning! GFAP is the target gene, score is set to 0 for ASO GAACTGAGTCAGCACTGAGC
# Warning! GFAP is the target gene, score is set to 0 for ASO CAGAAGAAGAGGAATTTTGT
# Warning! GFAP is the target gene, score is set to 0 for ASO TAAAGGCTGTTAAACATGTG
# Warning! GFAP is the target gene, score is set to 0 for ASO CTAACTTTAATTCTCTTTCT
# Warning! GFAP is the target gene, score is set to 0 for ASO AGTGCTCAATACACATAGGT
# Warning! GFAP is the target gene, score is set to 0 for ASO GAGGAAACGGAATTACATTC
# Warning! GFAP is the target gene, score is set to 0 for ASO TTCATAGTAAGGTAATCCAT
# Warning! GFAP is the target gene, score is set to 0 for ASO CCTTAGACAGAGGACTTGTC
# Warning! GFAP is the target gene, score is set to 0 for ASO CACAAGGCTGAAAAAGACTC
# Warning! GFAP is the target gene, score is set to 0 for ASO GTGAGGCTTTTGAGATATCT
# Warning! GFAP is the target gene, score is set to 0 for ASO TCATGGACATCAACCTTCTC
# Warning! GFAP is the target gene, score is set to 0 for ASO TGAGGGAAGAATCCTCTGAA
# Warning! GFAP is the target gene, score is set to 0 for ASO CACGGTATTGAAATCAGGAG
# Warning! GFAP is the target gene, score is set to 0 for ASO CCTTTCTGATGCTGAATTAA
# Warning! GFAP is the target gene, score is set to 0 for ASO TTTGTCTTTATTTTTCCTCA
# Warning! GFAP is the target gene, score is set to 0 for ASO ACATTAAGAGCAGGGAACAT
# Warning! GFAP is the target gene, score is set to 0 for ASO GCTACTAACTTTAATTCTCT
# Warning! GFAP is the target gene, score is set to 0 for ASO TGCCAGGAAAGTCTAACTCC
# Warning! GFAP is the target gene, score is set to 0 for ASO CAGCACGGTATTGAAATCAGWarning! GFAP is the target gene, score is set to 0 for ASO TTTTGAAAGCAATAGTGCCT
#
# Warning! GFAP is the target gene, score is set to 0 for ASO GTGACTATCTAGGATTTGGC
# Warning! GFAP is the target gene, score is set to 0 for ASO AGAACAGAACAGTATCAGCT
# Warning! GFAP is the target gene, score is set to 0 for ASO TAGAACAGAACAGTATCAGC
# Warning! GFAP is the target gene, score is set to 0 for ASO TAGTAAGGTAATCCATGAAA
# Warning! GFAP is the target gene, score is set to 0 for ASO GGTCTTACTTTTCTTGATAG
# Warning! GFAP is the target gene, score is set to 0 for ASO TACTTCATAGTAAGGTAATC
# Warning! GFAP is the target gene, score is set to 0 for ASO TCGAAAGCAGGCAAGCAAGC
# Warning! GFAP is the target gene, score is set to 0 for ASO CAGTATTACCTCTACTAGTC
# Warning! GFAP is the target gene, score is set to 0 for ASO CACAGGGCTTAGAACAGAAC
# Warning! GFAP is the target gene, score is set to 0 for ASO TGAGGACACTTGAATACCTG
# Warning! GFAP is the target gene, score is set to 0 for ASO GACTGAGGAAACGGAATTAC
# Warning! GFAP is the target gene, score is set to 0 for ASO AACGGAATTACATTCAGTTT
# Warning! GFAP is the target gene, score is set to 0 for ASO TCTCTCATCTGTCAAAGAAC
# Warning! GFAP is the target gene, score is set to 0 for ASO CAGGCTCAGAATAGGTGAGC
# Warning! GFAP is the target gene, score is set to 0 for ASO ATGGTAGAGGCTCAGTAACC
# Warning! GFAP is the target gene, score is set to 0 for ASO CCTATGCAACCGAGCAGAGA
# Warning! GFAP is the target gene, score is set to 0 for ASO CTGAGGAAACGGAATTACAT
# Warning! GFAP is the target gene, score is set to 0 for ASO AGCTGTGCAAGTCAAAGTAA
# Warning! GFAP is the target gene, score is set to 0 for ASO AAAGCTACTAACTTTAATTC
# Warning! GFAP is the target gene, score is set to 0 for ASO AAGCGAATGAATGAACAGTG
# Warning! GFAP is the target gene, score is set to 0 for ASO CTCTCTCATCTGTCAAAGAA
# Warning! GFAP is the target gene, score is set to 0 for ASO AGGGCAGATGTCAAGCTCTC
# Warning! GFAP is the target gene, score is set to 0 for ASO CCACCTTTTGAAATGAATTT
# Warning! GFAP is the target gene, score is set to 0 for ASO GCTAGAGTTGGAAGTGAAAG
# Warning! GFAP is the target gene, score is set to 0 for ASO GAGTTGGAAGTGAAAGCTACWarning! GFAP is the target gene, score is set to 0 for ASO TGCACTTGAAGGCACACATG
#
# Warning! GFAP is the target gene, score is set to 0 for ASO CAAGCTGGAAATGGAAAGCC
# Warning! GFAP is the target gene, score is set to 0 for ASO ATATGGTAGAGGCTCAGTAA
# Warning! GFAP is the target gene, score is set to 0 for ASO ATCCACAAGCATACACTCAC
# Warning! GFAP is the target gene, score is set to 0 for ASO GGTTTCTCGAATCTGCAGGT
# Warning! GFAP is the target gene, score is set to 0 for ASO AAAGAGAGAGTGTGTATTAG
# Warning! GFAP is the target gene, score is set to 0 for ASO GATAACACTGGGAAAGCATT
# Warning! GFAP is the target gene, score is set to 0 for ASO GTGAGATAACACTGGGAAAG
# Warning! GFAP is the target gene, score is set to 0 for ASO AACAGAAAACACTCAGAAGG
# Warning! GFAP is the target gene, score is set to 0 for ASO GCAGGAGGATTAAGGGTTGG
# Warning! GFAP is the target gene, score is set to 0 for ASO GAACAGAACAGTATCAGCTA
# Warning! GFAP is the target gene, score is set to 0 for ASO ACAGTTAGGAGTTCACACAG
# Warning! GFAP is the target gene, score is set to 0 for ASO AGCAAGCGAATGAATGAACA
# Warning! GFAP is the target gene, score is set to 0 for ASO AGTAAGGTAATCCATGAAAA
# Warning! GFAP is the target gene, score is set to 0 for ASO CAGTTTCCATAACAACAGGA
# Warning! GFAP is the target gene, score is set to 0 for ASO TCAGTTGCAATCTCTGTGTT
# Warning! GFAP is the target gene, score is set to 0 for ASO CTACTAACTTTAATTCTCTT
# Warning! GFAP is the target gene, score is set to 0 for ASO CAAAAGACAAAACAAGCCTC
# Warning! GFAP is the target gene, score is set to 0 for ASO CATTCTCTTGTACAGAGCAA
# Warning! GFAP is the target gene, score is set to 0 for ASO AGGGCTTAGAACAGAACAGT
# Warning! GFAP is the target gene, score is set to 0 for ASO GATCTGCACACAAGGCTGAA
# Warning! GFAP is the target gene, score is set to 0 for ASO TGCCTTAACTCATTACTAAG
# Warning! GFAP is the target gene, score is set to 0 for ASO GTCTTACTTTTCTTGATAGT
# Warning! GFAP is the target gene, score is set to 0 for ASO GAGGCCTAATCAATATTGGT
# Warning! GFAP is the target gene, score is set to 0 for ASO GGTAGAGGCTCAGTAACCCAWarning! GFAP is the target gene, score is set to 0 for ASO CTCCTCATTCTAACGCAAGC
#
# Warning! GFAP is the target gene, score is set to 0 for ASO AACAGTATCAGCTACTACTAWarning! GFAP is the target gene, score is set to 0 for ASO AGGCCTAATCAATATTGGTT
#
# Warning! GFAP is the target gene, score is set to 0 for ASO CTGAGGAAACTCAAAGGCAC
# Warning! GFAP is the target gene, score is set to 0 for ASO TAAGGTAATCCATGAAAAGC
# Warning! GFAP is the target gene, score is set to 0 for ASO GAGTTGGAAATCCAACTCTA
# Warning! GFAP is the target gene, score is set to 0 for ASO CGCATGTCTATCTGAAGGAA
# Warning! GFAP is the target gene, score is set to 0 for ASO GCATGTCTATCTGAAGGAAGWarning! GFAP is the target gene, score is set to 0 for ASO TGAGTTTCTTGTTAGTTGGA
#
# Warning! GFAP is the target gene, score is set to 0 for ASO ACACTACATATAAGCTCTGA
# Warning! GFAP is the target gene, score is set to 0 for ASO CATCTTAGACTGATCAGGGT
# Warning! GFAP is the target gene, score is set to 0 for ASO GTAGAGGCTCAGTAACCCAA
# Warning! GFAP is the target gene, score is set to 0 for ASO TCCTGAAAGAAAGCAGAGGG
# Warning! GFAP is the target gene, score is set to 0 for ASO ACAACAGGAATCAGGGATGT
# Warning! GFAP is the target gene, score is set to 0 for ASO AATCCATGAAAAGCACAGGG
# Warning! GFAP is the target gene, score is set to 0 for ASO GGGAGTATGCCTCTTAGTTT
# Warning! GFAP is the target gene, score is set to 0 for ASO GTAAAAAGTAATTTAGCTCC
# Warning! GFAP is the target gene, score is set to 0 for ASO GGCTCTCTCATCTGTCAAAG
# Warning! GFAP is the target gene, score is set to 0 for ASO CTGGTTTCTCGAATCTGCAG
# Warning! GFAP is the target gene, score is set to 0 for ASO AAAAGACAAAACAAGCCTCT
# Warning! GFAP is the target gene, score is set to 0 for ASO GCGGAGCAACTATCCTGCTT
# Warning! GFAP is the target gene, score is set to 0 for ASO AGAGGCCTTTAGAAATGGGA
# Warning! GFAP is the target gene, score is set to 0 for ASO AATTTTGTTCCTTAGCTAAG
# Warning! GFAP is the target gene, score is set to 0 for ASO CTGGGTTCTAATAGCCCTTT
# Warning! GFAP is the target gene, score is set to 0 for ASO CCTCATTCTAACGCAAGCTGWarning! GFAP is the target gene, score is set to 0 for ASO ATTTTGTTCCTTAGCTAAGA
#
# Warning! GFAP is the target gene, score is set to 0 for ASO GAAGAAGAGGAATTTTGTTC
# Warning! GFAP is the target gene, score is set to 0 for ASO GGTCAAGGACTGCAACTGGC
# Warning! GFAP is the target gene, score is set to 0 for ASO TGGTCCTAAATATTCTAGTC
# Warning! GFAP is the target gene, score is set to 0 for ASO GCGAATGAATGAACAGTGCC
# Warning! GFAP is the target gene, score is set to 0 for ASO CAATTGTAAAATAGGGCACT
# Warning! GFAP is the target gene, score is set to 0 for ASO GGTCCTAAATATTCTAGTCC
# Warning! GFAP is the target gene, score is set to 0 for ASO ATGCTGAATTAAGTCCTGAG
# Warning! GFAP is the target gene, score is set to 0 for ASO TTTCTGATGCTGAATTAAGT
# Warning! GFAP is the target gene, score is set to 0 for ASO TTTCAGCATCTTCAAGAGGA
# Warning! GFAP is the target gene, score is set to 0 for ASO GGATTTGGCAGTATTACCTC
# Warning! GFAP is the target gene, score is set to 0 for ASO TCAGCTACTACTAATAATAG
# Warning! GFAP is the target gene, score is set to 0 for ASO GATTTGGCAGTATTACCTCT
# Warning! GFAP is the target gene, score is set to 0 for ASO TAGGATTTGGCAGTATTACC
# Warning! GFAP is the target gene, score is set to 0 for ASO GCTGCAGGAATATGAGCCAGWarning! GFAP is the target gene, score is set to 0 for ASO CTTTTGAGATATCTTGTGAC
#
# Warning! GFAP is the target gene, score is set to 0 for ASO TGTGACTATCTAGGATTTGG
# Warning! GFAP is the target gene, score is set to 0 for ASO TTCTTGTTAGTTGGAGTTGC
# Warning! GFAP is the target gene, score is set to 0 for ASO AACTCTACCACTTAGGAGCT
# Warning! GFAP is the target gene, score is set to 0 for ASO GGCCTAATCAATATTGGTTGWarning! GFAP is the target gene, score is set to 0 for ASO GATGCTGAATTAAGTCCTGA
#
# Warning! GFAP is the target gene, score is set to 0 for ASO TGTGGCACATATTAGTGCTC
# Warning! GFAP is the target gene, score is set to 0 for ASO TGTGAGGCTTTTGAGATATC
# Warning! GFAP is the target gene, score is set to 0 for ASO GGTGAGTTTCTTGTTAGTTG
# Warning! GFAP is the target gene, score is set to 0 for ASO TATCTGTGCTTTAGTGACCT
# Warning! GFAP is the target gene, score is set to 0 for ASO GTAACCCAAAACAGACTGGC
# Warning! GFAP is the target gene, score is set to 0 for ASO GAAATGGGACAAAGTCATGC
# Warning! GFAP is the target gene, score is set to 0 for ASO CAGTTTAATGTACAGTTACT
# Warning! GFAP is the target gene, score is set to 0 for ASO CGTATTGTGAGGCTTTTGAG
# Warning! GFAP is the target gene, score is set to 0 for ASO GAAGAGGCCTTTAGAAATGG
# Warning! GFAP is the target gene, score is set to 0 for ASO ATTAGTGCTCAATACACATA
# Warning! GFAP is the target gene, score is set to 0 for ASO GCACCTACTTCATAGTAAGGWarning! GFAP is the target gene, score is set to 0 for ASO CTGTGACTATCTAGGATTTGWarning! GFAP is the target gene, score is set to 0 for ASO ATATTGGTTGAATCCATCCA
#
#
# Warning! GFAP is the target gene, score is set to 0 for ASO CATGTCTATCTGAAGGAAGA
# Warning! GFAP is the target gene, score is set to 0 for ASO AACAGTTTCCATAACAACAG
# Warning! GFAP is the target gene, score is set to 0 for ASO CCTGAGGAAACTCAAAGGCA
# Warning! GFAP is the target gene, score is set to 0 for ASO AGTGCTGAGAATCAAGCTCC
# Warning! GFAP is the target gene, score is set to 0 for ASO CACCTCATAAAAACCAAAAG
# Warning! GFAP is the target gene, score is set to 0 for ASO TTATCTGTGCTTTAGTGACC
# Warning! GFAP is the target gene, score is set to 0 for ASO AGTTGGAAATCCAACTCTAC
# Warning! GFAP is the target gene, score is set to 0 for ASO TTTGTGTGTGAGTAAGAAGG
# Warning! GFAP is the target gene, score is set to 0 for ASO AGCATTTGTCTTTATTTTTC
# Warning! GFAP is the target gene, score is set to 0 for ASO CATATTAGTGCTCAATACAC
# Warning! GFAP is the target gene, score is set to 0 for ASO AGAGGCTCAGTAACCCAAAAWarning! GFAP is the target gene, score is set to 0 for ASO TTAACATTAAGAGCAGGGAA
#
# Warning! GFAP is the target gene, score is set to 0 for ASO CATTAAGAGCAGGGAACATA
# Warning! GFAP is the target gene, score is set to 0 for ASO AAGGGAGCAAGATGAGCTCT
# Warning! GFAP is the target gene, score is set to 0 for ASO CCATCTTAGACTGATCAGGG
# Warning! GFAP is the target gene, score is set to 0 for ASO CCTTAGCTAAGAATCATTTCWarning! GFAP is the target gene, score is set to 0 for ASO GCTGAATTAAGTCCTGAGAC
#
# Warning! GFAP is the target gene, score is set to 0 for ASO CATTTGTCTTTATTTTTCCT
# Warning! GFAP is the target gene, score is set to 0 for ASO CGTCACATTCACTAATATTT
# Warning! GFAP is the target gene, score is set to 0 for ASO TCAGCAAGCGAATGAATGAAWarning! GFAP is the target gene, score is set to 0 for ASO GTCCTAAATATTCTAGTCCA
#
# Warning! GFAP is the target gene, score is set to 0 for ASO AGGTGAGGAGTCCAATCTTG
# Warning! GFAP is the target gene, score is set to 0 for ASO AGGCTGTTAAACATGTGGCA
# Warning! GFAP is the target gene, score is set to 0 for ASO GAAAGTGGTGAAGAAAGTTC
# Warning! GFAP is the target gene, score is set to 0 for ASO AAGAGAGAGTGTGTATTAGG
# Warning! GFAP is the target gene, score is set to 0 for ASO TGAGAACCTATGCAACCGAG
# Warning! GFAP is the target gene, score is set to 0 for ASO CCATCATGACAACTTGAACGWarning! GFAP is the target gene, score is set to 0 for ASO ATTTGGCAGTATTACCTCTA
#
# Warning! GFAP is the target gene, score is set to 0 for ASO TTCCATTTACAATCTGGTGA
# Warning! GFAP is the target gene, score is set to 0 for ASO AGCCATGAATGAAACACAGG
# Warning! GFAP is the target gene, score is set to 0 for ASO TCATCAAACATCTAGTGACT
# Warning! GFAP is the target gene, score is set to 0 for ASO GCACTACCTAGAATACTGGGWarning! GFAP is the target gene, score is set to 0 for ASO AAGTGAAAGCTACTAACTTT
#
# Warning! GFAP is the target gene, score is set to 0 for ASO AGTGAAAGCTACTAACTTTA
# Warning! GFAP is the target gene, score is set to 0 for ASO TTAGCTAAGAATCATTTCAGWarning! GFAP is the target gene, score is set to 0 for ASO GACTATCTAGGATTTGGCAG
#
# Warning! GFAP is the target gene, score is set to 0 for ASO TAACATTAAGAGCAGGGAACWarning! GFAP is the target gene, score is set to 0 for ASO TCTATCTGAAGGAAGATGGA
#
# Warning! GFAP is the target gene, score is set to 0 for ASO CCTAAATATTCTAGTCCAGAWarning! GFAP is the target gene, score is set to 0 for ASO ACTTTATTCACTGCAAGAGC
#
# Warning! GFAP is the target gene, score is set to 0 for ASO GTGATCCTGAAAGAAAGCAG
# Warning! GFAP is the target gene, score is set to 0 for ASO AAATGAATTTTATTATGACC
# Warning! GFAP is the target gene, score is set to 0 for ASO AGATAACACTGGGAAAGCAT
# Warning! GFAP is the target gene, score is set to 0 for ASO TAGTGCTCAATACACATAGG
# Warning! GFAP is the target gene, score is set to 0 for ASO ATATTCTAGTCCAGAAGAAG
# Warning! GFAP is the target gene, score is set to 0 for ASO CAAGCATACACTCACTGTTG
# Warning! GFAP is the target gene, score is set to 0 for ASO TTCTTGATAGTAACCACAGC
# Warning! GFAP is the target gene, score is set to 0 for ASO TTGGCAGTATTACCTCTACT
# Warning! GFAP is the target gene, score is set to 0 for ASO TCCATTTACAATCTGGTGAG
# Warning! GFAP is the target gene, score is set to 0 for ASO CGAGGGCTTTATGAAGGAGT
# Warning! GFAP is the target gene, score is set to 0 for ASO ATTACCTCTACTAGTCAGCC
# Warning! GFAP is the target gene, score is set to 0 for ASO GGCTTTTGAGATATCTTGTG
# Warning! GFAP is the target gene, score is set to 0 for ASO TGCCAGTTTAATGTACAGTT
# Warning! GFAP is the target gene, score is set to 0 for ASO GACATGCATATCTAGTGGTC
# Warning! GFAP is the target gene, score is set to 0 for ASO GCCATGAATGAAACACAGGG
# Warning! GFAP is the target gene, score is set to 0 for ASO ATTTATCTGTGCTTTAGTGAWarning! GFAP is the target gene, score is set to 0 for ASO TCTTTCTGTTTGTCTTTCAT
#
# ...
# Warning! AGT is the target gene, score is set to 0 for ASO GCAGCACACTTAGACC
# Warning! AGT is the target gene, score is set to 0 for ASO AAATTCAGGTGCTTGC
# Warning! AGT is the target gene, score is set to 0 for ASO TGCAGCACACTTAGAC
# Warning! AGT is the target gene, score is set to 0 for ASO GGTTCAGCTCGGTGTGCAGA
# Warning! AGT is the target gene, score is set to 0 for ASO CCGAGAAGTTGTCCTG
# Warning! AGT is the target gene, score is set to 0 for ASO ATGCAGCACACTTAGA
# Warning! AGT is the target gene, score is set to 0 for ASO GCAGGTTCAGCTCGGTGTGC
# Warning! AGT is the target gene, score is set to 0 for ASO TCACCGAGAAGTTGTC
# Warning! AGT is the target gene, score is set to 0 for ASO CATGCAGCACACTTAG
# Warning! AGT is the target gene, score is set to 0 for ASO GAGTCACCGAGAAGTT
# Warning! AGT is the target gene, score is set to 0 for ASO CCATGCAGCACACTTA
# Warning! AGT is the target gene, score is set to 0 for ASO CACATCGCTGATTTGTCCGG
# Warning! AGT is the target gene, score is set to 0 for ASO CTTGAGTCACCGAGAA
# Warning! AGT is the target gene, score is set to 0 for ASO TCCATGCAGCACACTT
# Warning! AGT is the target gene, score is set to 0 for ASO ACACATCGCTGATTTGTCCG
# Warning! AGT is the target gene, score is set to 0 for ASO GCACTTGAGTCACCGA
# Warning! AGT is the target gene, score is set to 0 for ASO TCAATTTTTGCAGGTTCAGC
# Warning! AGT is the target gene, score is set to 0 for ASO CTCCATGCAGCACACT
# Warning! AGT is the target gene, score is set to 0 for ASO AGGGCACTTGAGTCAC
# Warning! AGT is the target gene, score is set to 0 for ASO TCCGCATTCAAACAGA
# Warning! AGT is the target gene, score is set to 0 for ASO ACTCCATGCAGCACAC
# Warning! AGT is the target gene, score is set to 0 for ASO TGCTCAATTTTTGCAGGTTC
# Warning! AGT is the target gene, score is set to 0 for ASO TGAAGGGCACTTGAGT
# Warning! AGT is the target gene, score is set to 0 for ASO TTCCGCATTCAAACAG
# Warning! AGT is the target gene, score is set to 0 for ASO CACTCCATGCAGCACA
# Warning! AGT is the target gene, score is set to 0 for ASO CATTGCTCAATTTTTGCAGG
# Warning! AGT is the target gene, score is set to 0 for ASO CAGTGAAGGGCACTTG
# Warning! AGT is the target gene, score is set to 0 for ASO GTTCCGCATTCAAACA
# Warning! AGT is the target gene, score is set to 0 for ASO TCGGTTGGAATTCTTTTTGG
# Warning! AGT is the target gene, score is set to 0 for ASO TCACTCCATGCAGCAC
# Warning! AGT is the target gene, score is set to 0 for ASO TCTCAGTGAAGGGCACWarning! AGT is the target gene, score is set to 0 for ASO GGTCATTGCTCAATTTTTGC
#
# Warning! AGT is the target gene, score is set to 0 for ASO GGTTCCGCATTCAAAC
# Warning! AGT is the target gene, score is set to 0 for ASO AGCTGGTCGGTTGGAATTCT
# Warning! AGT is the target gene, score is set to 0 for ASO CGCTCTCAGTGAAGGG
# Warning! AGT is the target gene, score is set to 0 for ASO TGCGGTCATTGCTCAATTTT
# Warning! AGT is the target gene, score is set to 0 for ASO TCACAAACAAGCTGGTCGGT
# Warning! AGT is the target gene, score is set to 0 for ASO TGATGCGGTCATTGCTCAAT
# Warning! AGT is the target gene, score is set to 0 for ASO GCTGGATCAGCAGCAG
# Warning! APOE is the target gene, score is set to 0 for ASO GAGTCGGTTTAATCACTT
# Warning! AGT is the target gene, score is set to 0 for ASO GAGGCTGGATCAGCAG
# Warning! AGT is the target gene, score is set to 0 for ASO AGTGAGGCTGGATCAG
# Warning! APOE is the target gene, score is set to 0 for ASO CACAAATGCTTCTTTGGA
# Warning! AGT is the target gene, score is set to 0 for ASO CATAGTGAGGCTGGAT
# Warning! APOE is the target gene, score is set to 0 for ASO ACACAGAAGGTGCTCCAC
# Warning! AGT is the target gene, score is set to 0 for ASO AGGCATAGTGAGGCTG
# Warning! APOE is the target gene, score is set to 0 for ASO GGCATCTAGTACCTAGGG
# Warning! APOE is the target gene, score is set to 0 for ASO AGTTCAAGGTGGGTCAGG
# Warning! AGT is the target gene, score is set to 0 for ASO GTGCATTTGTGCCGCT
# Warning! AGT is the target gene, score is set to 0 for ASO GGTGCATTTGTGCCGC
# Warning! AGT is the target gene, score is set to 0 for ASO AAAAAATGCTGTTCAGCACC
# Warning! AGT is the target gene, score is set to 0 for ASO AGGTGCATTTGTGCCG
# Warning! AGT is the target gene, score is set to 0 for ASO GAGGTGCATTTGTGCC
# Warning! APOE is the target gene, score is set to 0 for ASO CAAGACTTAGCGACAGGG
# Warning! AGT is the target gene, score is set to 0 for ASO GGAGGTGCATTTGTGC
# Warning! AGT is the target gene, score is set to 0 for ASO GGGAGGTGCATTTGTG
# Warning! AGT is the target gene, score is set to 0 for ASO TGGGAGGTGCATTTGT
# Warning! APOE is the target gene, score is set to 0 for ASO AAGCTAGAACCAGCAGAG
# Warning! AGT is the target gene, score is set to 0 for ASO CTGGGAGGTGCATTTG
# Warning! AGT is the target gene, score is set to 0 for ASO CCGCTTCAAGCTCAAAAAAA
# Warning! AGT is the target gene, score is set to 0 for ASO ACTGGGAGGTGCATTT
# Warning! APOE is the target gene, score is set to 0 for ASO GCTAAAGCCAGGAGTCAG
# Warning! AGT is the target gene, score is set to 0 for ASO CATCCGCTTCAAGCTCAAAA
# Warning! AGT is the target gene, score is set to 0 for ASO AACTGGGAGGTGCATT
# Warning! APOE is the target gene, score is set to 0 for ASO AGAGAATTCCAGAGAGCT
# Warning! AGT is the target gene, score is set to 0 for ASO TCTCATCCGCTTCAAGCTCA
# Warning! AGT is the target gene, score is set to 0 for ASO AAACTGGGAGGTGCAT
# Warning! AGT is the target gene, score is set to 0 for ASO CAAACTGGGAGGTGCA
# Warning! AGT is the target gene, score is set to 0 for ASO CTCTCTCATCCGCTTCAAGC
# Warning! AGT is the target gene, score is set to 0 for ASO TTATTGTGGCAAGACG
# Warning! APOE is the target gene, score is set to 0 for ASO TCAGAAGGGAAGAGAGAG
# Warning! AGT is the target gene, score is set to 0 for ASO GCAAACTGGGAGGTGC
# Warning! APOE is the target gene, score is set to 0 for ASO GTGTGAGAGACTGAGTCA
# Warning! AGT is the target gene, score is set to 0 for ASO AGCAAACTGGGAGGTG
# Warning! AGT is the target gene, score is set to 0 for ASO GGCTTATTGTGGCAAG
# Warning! APOE is the target gene, score is set to 0 for ASO TAGGGAAGGACAGAGACA
# Warning! AGT is the target gene, score is set to 0 for ASO AGGCTTATTGTGGCAA
# Warning! APOE is the target gene, score is set to 0 for ASO AGGAGCCGTTACGCAGTTGC
# Warning! AGT is the target gene, score is set to 0 for ASO GAGGCTTATTGTGGCA
# Warning! AGT is the target gene, score is set to 0 for ASO GGAGGCTTATTGTGGC
# Warning! AGT is the target gene, score is set to 0 for ASO CTGTTGGGTAGACTCTGTGG
# Warning! APOE is the target gene, score is set to 0 for ASO AGACGAAGAAGGAGCTAG
# Warning! AGT is the target gene, score is set to 0 for ASO AAGCTGTTGGGTAGACTCTG
# Warning! AGT is the target gene, score is set to 0 for ASO GTTAAGCTGTTGGGTAGACT
# Warning! APOE is the target gene, score is set to 0 for ASO CACTTCTGCAGGTCATCGGC
# Warning! APOE is the target gene, score is set to 0 for ASO GCAGAGAGCAGATGCAGA
# Warning! AGT is the target gene, score is set to 0 for ASO CTTGTTAAGCTGTTGGGTAG
# Warning! APOE is the target gene, score is set to 0 for ASO CGAGAGAAGGAGACAGAG
# Warning! APOE is the target gene, score is set to 0 for ASO CCAGGCACTTCTGCAGGTCA
# Warning! AGT is the target gene, score is set to 0 for ASO AGGCTTGTTAAGCTGTTGGG
# Warning! AGT is the target gene, score is set to 0 for ASO CTCAGGCTTGTTAAGCTGTT
# Warning! APOE is the target gene, score is set to 0 for ASO CGTTCAGTGATTGTCGCT
# Warning! AGT is the target gene, score is set to 0 for ASO CGCTAAACACTGGTTC
# Warning! AGT is the target gene, score is set to 0 for ASO ACAGGAATGGGCGGTTCAGG
# Warning! AGT is the target gene, score is set to 0 for ASO GCGCTAAACACTGGTT
# Warning! AGT is the target gene, score is set to 0 for ASO CAAACAGGAATGGGCGGTTC
# Warning! AGT is the target gene, score is set to 0 for ASO CGCGCTAAACACTGGT
# Warning! AGT is the target gene, score is set to 0 for ASO CCGCGCTAAACACTGG
# Warning! AGT is the target gene, score is set to 0 for ASO CAGCAAACAGGAATGGGCGG
# Warning! AGT is the target gene, score is set to 0 for ASO ACACAGCAAACAGGAATGGG
# Warning! AGT is the target gene, score is set to 0 for ASO GATCATACACAGCAAACAGG
# Warning! AGT is the target gene, score is set to 0 for ASO CGCTTTGATCATACACAGCA
# Warning! AGT is the target gene, score is set to 0 for ASO TGGAACAGTAGTCCCG
# Warning! AGT is the target gene, score is set to 0 for ASO TTGGAACAGTAGTCCC
# Warning! AGT is the target gene, score is set to 0 for ASO TTTGGAACAGTAGTCC
# Warning! AGT is the target gene, score is set to 0 for ASO CGGTTGGAATTCTTTT
# Warning! AGT is the target gene, score is set to 0 for ASO TCGGTTGGAATTCTTT
# Warning! AGT is the target gene, score is set to 0 for ASO GTCGGTTGGAATTCTT
# Warning! AGT is the target gene, score is set to 0 for ASO GGTCGGTTGGAATTCT
# Warning! AGT is the target gene, score is set to 0 for ASO TGGTCGGTTGGAATTC
# Warning! AGT is the target gene, score is set to 0 for ASO CTGGTCGGTTGGAATT
# Warning! AGT is the target gene, score is set to 0 for ASO GCTGGTCGGTTGGAAT
# Warning! AGT is the target gene, score is set to 0 for ASO AGCTGGTCGGTTGGAA
# Warning! AGT is the target gene, score is set to 0 for ASO AAGCTGGTCGGTTGGA
# Warning! AGT is the target gene, score is set to 0 for ASO CAAGCTGGTCGGTTGG
# Warning! AGT is the target gene, score is set to 0 for ASO ACAAGCTGGTCGGTTG
# Warning! APOE is the target gene, score is set to 0 for ASO GCTGAGTAGGACTCAAGG
# Warning! AGT is the target gene, score is set to 0 for ASO CCAAGGAGAAACGGCTGCTT
# Warning! AGT is the target gene, score is set to 0 for ASO AACAAGCTGGTCGGTT
# Warning! APOE is the target gene, score is set to 0 for ASO GGGCTGAGTAGGACTCAA
# Warning! AGT is the target gene, score is set to 0 for ASO AGACCAAGGAGAAACGGCTG
# Warning! AGT is the target gene, score is set to 0 for ASO AAACAAGCTGGTCGGT
# Warning! AGT is the target gene, score is set to 0 for ASO CTTAGACCAAGGAGAAACGG
# Warning! AGT is the target gene, score is set to 0 for ASO CAAACAAGCTGGTCGG
# Warning! AGT is the target gene, score is set to 0 for ASO ACACTTAGACCAAGGAGAAA
# Warning! AGT is the target gene, score is set to 0 for ASO ACAAACAAGCTGGTCG
# Warning! AGT is the target gene, score is set to 0 for ASO AGCACACTTAGACCAAGGAG
# Warning! AGT is the target gene, score is set to 0 for ASO TGCAGCACACTTAGACCAAG
# Warning! AGT is the target gene, score is set to 0 for ASO CCATGCAGCACACTTAGACC
# Warning! AGT is the target gene, score is set to 0 for ASO ACTCCATGCAGCACACTTAG
# Warning! AGT is the target gene, score is set to 0 for ASO CTCACTCCATGCAGCACACT
# Warning! AGT is the target gene, score is set to 0 for ASO AGGGAACACTTTTTTG
# Warning! AGT is the target gene, score is set to 0 for ASO TCGCTGATTTGTCCGG
# Warning! AGT is the target gene, score is set to 0 for ASO TCGCTGATTTGTCCGG
# Warning! AGT is the target gene, score is set to 0 for ASO TCGCTGATTTGTCCGG
# Warning! APOE is the target gene, score is set to 0 for ASO CACAGAACCTTCATCTTC
# Warning! AGT is the target gene, score is set to 0 for ASO TCGCTGATTTGTCCGG
# Warning! AGT is the target gene, score is set to 0 for ASO CCCAATTTTTGTTCTC
# Warning! AGT is the target gene, score is set to 0 for ASO TGGGAGGTGCATTTGTGCCG
# Warning! AGT is the target gene, score is set to 0 for ASO ACCCAATTTTTGTTCT
# Warning! AGT is the target gene, score is set to 0 for ASO AACTGGGAGGTGCATTTGTG
# Warning! AGT is the target gene, score is set to 0 for ASO AACCCAATTTTTGTTC
# Warning! AGT is the target gene, score is set to 0 for ASO GCAAACTGGGAGGTGCATTT
# Warning! AGT is the target gene, score is set to 0 for ASO CCAGCAAACTGGGAGGTGCA
# Warning! AGT is the target gene, score is set to 0 for ASO TTCCAAGGAACACCCA
# Warning! AGT is the target gene, score is set to 0 for ASO GTCCTTCCAAGGAACA
# Warning! APOE is the target gene, score is set to 0 for ASO ATGTGACCAGCAACGCAG
# Warning! APOE is the target gene, score is set to 0 for ASO AGGAATGTGACCAGCAAC
# Warning! APOE is the target gene, score is set to 0 for ASO CCAGGAATGTGACCAGCA
# Warning! AGT is the target gene, score is set to 0 for ASO TTCTCTAAAATAAACCCAGC
# Warning! AGT is the target gene, score is set to 0 for ASO CCATTCTCTAAAATAAACCC
# Warning! AGT is the target gene, score is set to 0 for ASO GGTGCAGTTCTTGTCC
# Warning! AGT is the target gene, score is set to 0 for ASO GGAGGTGCAGTTCTTG
# Warning! AGT is the target gene, score is set to 0 for ASO CCGCGCTAAACACTGGTTCT
# Warning! AGT is the target gene, score is set to 0 for ASO CTTTTTGGAACAGTAGTCCC
# Warning! AGT is the target gene, score is set to 0 for ASO ATTCTTTTTGGAACAGTAGT
# Warning! APOB is the target gene, score is set to 0 for ASO GATGCCTTACTTGGACAGAC
# Warning! AGT is the target gene, score is set to 0 for ASO GGAATTCTTTTTGGAACAGT
# Warning! AGT is the target gene, score is set to 0 for ASO GTTGGAATTCTTTTTGGAAC
# Warning! APOB is the target gene, score is set to 0 for ASO GTCGCATCTTCTAACGTGGG
# Warning! AGT is the target gene, score is set to 0 for ASO TCGGTTGGAATTCTTTTTGG
# Warning! AGT is the target gene, score is set to 0 for ASO TGGTCGGTTGGAATTCTTTT
# Warning! APOB is the target gene, score is set to 0 for ASO TGGCTCATGTCTACCATATT
# Warning! AGT is the target gene, score is set to 0 for ASO AGCTGGTCGGTTGGAATTCT
# Warning! APOB is the target gene, score is set to 0 for ASO CAGTTGAAATGCAGCTAATG
# Warning! AGT is the target gene, score is set to 0 for ASO ACAAGCTGGTCGGTTGGAAT
# Warning! APOB is the target gene, score is set to 0 for ASO TGCAGACTAGGAGTGAAAGT
# Warning! AGT is the target gene, score is set to 0 for ASO CAAACAAGCTGGTCGGTTGG
# Warning! APOB is the target gene, score is set to 0 for ASO AGGAGGATGTCCTTTTATTG
# Warning! AGT is the target gene, score is set to 0 for ASO TCACAAACAAGCTGGTCGGT
# Warning! APOB is the target gene, score is set to 0 for ASO ATCAGAGCACCAAAGGGAAT
# Warning! AGT is the target gene, score is set to 0 for ASO GTTTCACAAACAAGCTGGTC
# Warning! APOB is the target gene, score is set to 0 for ASO CCAGCTCAACCTGAGAATTC
# Warning! AGT is the target gene, score is set to 0 for ASO TTTGTTTCACAAACAAGCTG
# Warning! AGT is the target gene, score is set to 0 for ASO GAAAAGGGAACACTTTTTTG
# Warning! AGT is the target gene, score is set to 0 for ASO TCTCAACTTGAAAAGGGAAC
# Warning! AGT is the target gene, score is set to 0 for ASO TGTTCTCAACTTGAAAAGGG
# Warning! AGT is the target gene, score is set to 0 for ASO AATTTTTGTTCTCAACTTGA
# Warning! APOB is the target gene, score is set to 0 for ASO TCTGATCACCATACATTACA
# Warning! AGT is the target gene, score is set to 0 for ASO CCCAATTTTTGTTCTCAACT
# Warning! AGT is the target gene, score is set to 0 for ASO AAACCCAATTTTTGTTCTCA
# Warning! AGT is the target gene, score is set to 0 for ASO TTAAAACCCAATTTTTGTTC
# Warning! APOB is the target gene, score is set to 0 for ASO GTTGGACAGTCATTCTTTTG
# Warning! APOB is the target gene, score is set to 0 for ASO CACTTGTTGGACAGTCATTC
# Warning! AGT is the target gene, score is set to 0 for ASO GACACATCGCTGATTTGTCC
# Warning! APOB is the target gene, score is set to 0 for ASO CCAGTATTTCACGCCAATCC
# Warning! AGT is the target gene, score is set to 0 for ASO GACACATCGCTGATTTGTCC
# Warning! AGT is the target gene, score is set to 0 for ASO GACACATCGCTGATTTGTCC
# Warning! AGT is the target gene, score is set to 0 for ASO GACACATCGCTGATTTGTCC
# Warning! LCK is the target gene, score is set to 0 for ASO TGTCCAAGACATACATGCAC
# Warning! LCK is the target gene, score is set to 0 for ASO CTATGGCACAAGAACTCCAT
# Warning! LCK is the target gene, score is set to 0 for ASO GTACCTTGTACAGTGTCCAA
# Warning! LCK is the target gene, score is set to 0 for ASO CATATGTGCATAGGCCATGT
# Warning! LCK is the target gene, score is set to 0 for ASO CAGAAGCTTCTGTCAATCCC
# Warning! LCK is the target gene, score is set to 0 for ASO CGATAACCAGGTTGTCTTGC
# Warning! LCK is the target gene, score is set to 0 for ASO ACGATGAATATAATTCCGCT
# Warning! LCK is the target gene, score is set to 0 for ASO GCAGAGTCCATATGTGCATA
# Warning! LCK is the target gene, score is set to 0 for ASO GGAGGAGCACACAGAGGTAT
# Warning! LCK is the target gene, score is set to 0 for ASO AGTCTGCAATCTTGCAGCTC
# Warning! LCK is the target gene, score is set to 0 for ASO GTACAGACACAAGGTGCATA
# Warning! LCK is the target gene, score is set to 0 for ASO TTTATTGAACTCCTGATGTG
# Warning! LCK is the target gene, score is set to 0 for ASO AGGACACGTGTACAGACACAWarning! LCK is the target gene, score is set to 0 for ASO TCCCGTAGTTAATGGCTTCT
#
# Saved feature: off_target_score_specific_ARTM_n200_c1200
