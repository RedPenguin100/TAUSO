# %% [markdown]
# Imports

# %%
import pandas as pd

# %% [markdown]
# Configuration

# %%
df = pd.read_csv("aso_inhibitions_with_canonical_gene.csv")
col1 = "target_gene"
col2 = "Canonical Gene Name"

# %% [markdown]
# Check unfound canonical genes

# %%
not_found = df[df[col2].isna()]

print(f"{len(not_found)} RNA contexts were not found in the genome")

not_found.to_csv("rna_contexts_not_found.csv", index=False)
# Out:
# 0 RNA contexts were not found in the genome

# %% [markdown]
# Find targets with multiple possible genes

# %%
multi_gene_mask = (
    df["Canonical Gene Name"]
    .notna()
    & df["Canonical Gene Name"].str.contains(";", regex=False)
)

count_multi = multi_gene_mask.sum()

print(f"{count_multi} rows have more than one canonical gene")
# Out:
# 785 rows have more than one canonical gene

# %%
df[multi_gene_mask]
# Out:
#          aso_sequence_5_to_3  inhibition_percent  \
# 15286   TCGTCCCCGGGCTTCCGCGG                31.0
# 15287   AAACGAGTCTCCGTCGCCGT                48.0
# 15288   AGCAGGCTCGCAGGGCCTCG                 0.0
# 15289   GTGGCGATGCCCGGGTACGG                33.0
# 15290   GGCCTGGGCCAGCCGTTCTC                52.0
# ...                      ...                 ...
# 137094      TGAATCCTGGACTCCG                92.0
# 137095      CAGATCTGAATCCTGG                82.0
# 137096      CCAGATCTGAATCCTG                90.0
# 137097      TCGATTCTGAAACCAG                93.0
# 141396  GGTTCAAGCGATTCTCCTGC                46.0
#
#                                                 chemistry  \
# 15286   length=20 modifications=[Modification(modifica...
# 15287   length=20 modifications=[Modification(modifica...
# 15288   length=20 modifications=[Modification(modifica...
# 15289   length=20 modifications=[Modification(modifica...
# 15290   length=20 modifications=[Modification(modifica...
# ...                                                   ...
# 137094  length=16 modifications=[Modification(modifica...
# 137095  length=16 modifications=[Modification(modifica...
# 137096  length=16 modifications=[Modification(modifica...
# 137097  length=16 modifications=[Modification(modifica...
# 141396  length=20 modifications=[Modification(modifica...
#
#                                                 custom_id target_mrna  \
# 15286   patent-scrape-v2/data/inhibition_tables/US2024...        DUX4
# 15287   patent-scrape-v2/data/inhibition_tables/US2024...        DUX4
# 15288   patent-scrape-v2/data/inhibition_tables/US2024...        DUX4
# 15289   patent-scrape-v2/data/inhibition_tables/US2024...        DUX4
# 15290   patent-scrape-v2/data/inhibition_tables/US2024...        DUX4
# ...                                                   ...         ...
# 137094  patent-scrape-v2/data/inhibition_tables/US2024...        DUX4
# 137095  patent-scrape-v2/data/inhibition_tables/US2024...        DUX4
# 137096  patent-scrape-v2/data/inhibition_tables/US2024...        DUX4
# 137097  patent-scrape-v2/data/inhibition_tables/US2024...        DUX4
# 141396  patent-scrape-v2/data/inhibition_tables/US2004...    IAP-like
#
#        target_gene cell_line cell_line_species  dosage  cells_per_well  \
# 15286         DUX4      54-2             human   100.0          6000.0
# 15287         DUX4      54-2             human   100.0          6000.0
# 15288         DUX4      54-2             human   100.0          6000.0
# 15289         DUX4      54-2             human   100.0          6000.0
# 15290         DUX4      54-2             human   100.0          6000.0
# ...            ...       ...               ...     ...             ...
# 137094        DUX4      54-2             human   200.0         10000.0
# 137095        DUX4      54-2             human   200.0         10000.0
# 137096        DUX4      54-2             human   200.0         10000.0
# 137097        DUX4      54-2             human   200.0         10000.0
# 141396        NAIP      A549             human     NaN             NaN
#
#        transfection_method  steric_blocking  \
# 15286          Lipofection            False
# 15287          Lipofection            False
# 15288          Lipofection            False
# 15289          Lipofection            False
# 15290          Lipofection            False
# ...                    ...              ...
# 137094         Lipofection            False
# 137095         Lipofection            False
# 137096         Lipofection            False
# 137097         Lipofection            False
# 141396               Other            False
#
#                                               rna_context  \
# 15286   AUGGCCCUCCCGACACCCUCGGACAGCACCCUCCCCGCGGAAGCCC...
# 15287   AUGGCCCUCCCGACACCCUCGGACAGCACCCUCCCCGCGGAAGCCC...
# 15288   AUGGCCCUCCCGACACCCUCGGACAGCACCCUCCCCGCGGAAGCCC...
# 15289   CAGCACCCUCCCCGCGGAAGCCCGGGGACGAGGACGGCGACGGAGA...
# 15290   CGGGGACGAGGACGGCGACGGAGACUCGUUUGGACCCCGAGCCAAA...
# ...                                                   ...
# 137094  GUCACCGGAUCCCAGACCGCCCUGCUCCUCCGAGCCUUUGAGAAGG...
# 137095  GGAUCCCAGACCGCCCUGCUCCUCCGAGCCUUUGAGAAGGAUCGCU...
# 137096  GAUCCCAGACCGCCCUGCUCCUCCGAGCCUUUGAGAAGGAUCGCUU...
# 137097  CCCUGCUCCUCCGAGCCUUUGAGAAGGAUCGCUUUCCAGGCAUCGC...
# 141396  GCCUGGCCAAUAUGGUGAAACUCUGUCUCUACUAAAAAUACAAAGA...
#
#                                                sugar_mods  \
# 15286   ['MOE', 'MOE', 'MOE', 'MOE', 'MOE', 'DNA', 'DN...
# 15287   ['MOE', 'MOE', 'MOE', 'MOE', 'MOE', 'DNA', 'DN...
# 15288   ['MOE', 'MOE', 'MOE', 'MOE', 'MOE', 'DNA', 'DN...
# 15289   ['MOE', 'MOE', 'MOE', 'MOE', 'MOE', 'DNA', 'DN...
# 15290   ['MOE', 'MOE', 'MOE', 'MOE', 'MOE', 'DNA', 'DN...
# ...                                                   ...
# 137094  ['CET', 'CET', 'CET', 'DNA', 'DNA', 'DNA', 'DN...
# 137095  ['CET', 'CET', 'CET', 'DNA', 'DNA', 'DNA', 'DN...
# 137096  ['CET', 'CET', 'CET', 'DNA', 'DNA', 'DNA', 'DN...
# 137097  ['CET', 'CET', 'CET', 'DNA', 'DNA', 'DNA', 'DN...
# 141396  ['MOE', 'MOE', 'MOE', 'MOE', 'MOE', 'DNA', 'DN...
#
#                                             backbone_mods  \
# 15286   ['PS', 'PS', 'PS', 'PS', 'PS', 'PS', 'PS', 'PS...
# 15287   ['PS', 'PS', 'PS', 'PS', 'PS', 'PS', 'PS', 'PS...
# 15288   ['PS', 'PS', 'PS', 'PS', 'PS', 'PS', 'PS', 'PS...
# 15289   ['PS', 'PS', 'PS', 'PS', 'PS', 'PS', 'PS', 'PS...
# 15290   ['PS', 'PS', 'PS', 'PS', 'PS', 'PS', 'PS', 'PS...
# ...                                                   ...
# 137094  ['PS', 'PS', 'PS', 'PS', 'PS', 'PS', 'PS', 'PS...
# 137095  ['PS', 'PS', 'PS', 'PS', 'PS', 'PS', 'PS', 'PS...
# 137096  ['PS', 'PS', 'PS', 'PS', 'PS', 'PS', 'PS', 'PS...
# 137097  ['PS', 'PS', 'PS', 'PS', 'PS', 'PS', 'PS', 'PS...
# 141396  ['PS', 'PS', 'PS', 'PS', 'PS', 'PS', 'PS', 'PS...
#
#                                       Canonical Gene Name
# 15286   DUX4L8;DUX4;DUX4L2;DUX4L3;DUX4L6;DUX4L1;DUX4L5...
# 15287   DUX4L8;DUX4;DUX4L2;DUX4L3;DUX4L6;DUX4L1;DUX4L5...
# 15288   DUX4L8;DUX4;DUX4L2;DUX4L3;DUX4L6;DUX4L1;DUX4L5...
# 15289   DUX4L8;DUX4;DUX4L2;DUX4L3;DUX4L6;DUX4L1;DUX4L5...
# 15290   DUX4L8;DUX4;DUX4L2;DUX4L3;DUX4L6;DUX4L1;DUX4L5...
# ...                                                   ...
# 137094  DUX4L8;DUX4;DUX4L2;DUX4L3;DUX4L6;DUX4L1;DUX4L5...
# 137095  DUX4L8;DUX4;DUX4L2;DUX4L3;DUX4L6;DUX4L1;DUX4L5...
# 137096  DUX4L8;DUX4;DUX4L2;DUX4L3;DUX4L6;DUX4L1;DUX4L5...
# 137097  DUX4L8;DUX4;DUX4L2;DUX4L3;DUX4L6;DUX4L1;DUX4L5...
# 141396                   NAIPP3;NAIPP1;NAIPP2;NAIPP4;NAIP
#
# [785 rows x 16 columns]

# %%
fixed_df = df.copy()

multi_gene_mask = (
        fixed_df[col2].notna()
        & fixed_df[col2].str.contains(";", regex=False)
)

print(f"Fixing {multi_gene_mask.sum()} rows with multiple canonical genes")

# Replace Canonical Gene Name with target_gene where ambiguous
fixed_df.loc[multi_gene_mask, col2] = fixed_df.loc[multi_gene_mask, col1]

# Save fixed version
fixed_df.to_csv(
    "aso_inhibitions_with_canonical_gene_fixed.csv",
    index=False
)

print("Saved aso_inhibitions_with_canonical_gene_fixed.csv")
# Out:
# Fixing 785 rows with multiple canonical genes
# Saved aso_inhibitions_with_canonical_gene_fixed.csv

# %% [markdown]
# function that checks for mismatches between targets and canonical gene names

# %%
def check_baddies(df, col_1, col_2):
    baddies = df[df[col_1] != df[col_2]][col_1].unique()
    canonical = df[df[col_1] != df[col_2]][col_2].unique()
    new_df = pd.DataFrame()
    new_df["baddies"] = baddies
    new_df["canonical"] = canonical
    return new_df

# %% [markdown]
# execution

# %%
new = check_baddies(df, col1, col2)
new.to_csv("canonical_baddies.csv", index=False)

# %%
new
# Out:
#    baddies                                          canonical
# 0      CFB                                         AL645922.1
# 1     DUX4  DUX4L8;DUX4;DUX4L2;DUX4L3;DUX4L6;DUX4L1;DUX4L5...
# 2     PAK1                                         AP003680.1
# 3   NOTCH2               NOTCH2NLC;NOTCH2;NOTCH2NLA;NOTCH2NLB
# 4    DUSP6                                         AC024909.1
# 5  PPP2R1A                                            MIR6801
# 6  EIF2AK2                                          ARL14EPP1
# 7     NAIP                   NAIPP3;NAIPP1;NAIPP2;NAIPP4;NAIP
# 8     IGF2                                            IGF2-AS

# %% [markdown]
# find cell line for baddies
